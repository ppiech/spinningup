# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import os.path as osp
import numpy as np
from spinup.utils.plot import get_datasets, get_all_datasets, plot_data
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
datasets, configs = get_all_datasets(['/Users/ppiech/openaigym/spindata/ppo/data-1/ppo-bench_pendulum-v0_ste4800/'])

# Show a sample of the data
pd.concat(datasets, ignore_index=True)
# Out:
# Plotting from...
# ==================================================
#
# /Users/ppiech/openaigym/spindata/ppo/data-1/ppo-bench_pendulum-v0_ste4800/
#
# ==================================================
#       Epoch  AverageEpRet    StdEpRet     MaxEpRet    MinEpRet  EpLen  \
# 0         0   -1528.92740  175.235920 -1314.743000 -1905.27650  200.0
# 1         1   -1431.89030  137.193120 -1157.944100 -1711.15150  200.0
# 2         2   -1441.21290  192.631090 -1177.771100 -1816.65340  200.0
# 3         3   -1414.70280  165.544770 -1072.256200 -1777.42460  200.0
# 4         4   -1427.56700  204.541060 -1101.933300 -1875.41830  200.0
# 5         5   -1332.35550  160.405080 -1094.117600 -1716.49110  200.0
# 6         6   -1335.92640  137.075940 -1155.407600 -1605.01060  200.0
# 7         7   -1388.86670  208.051090 -1077.124800 -1767.76590  200.0
# 8         8   -1400.04630  191.274570 -1133.745000 -1733.20500  200.0
# 9         9   -1403.21250  172.343120 -1148.998800 -1706.17980  200.0
# 10       10   -1307.34830  147.207570 -1084.214200 -1727.98510  200.0
# 11       11   -1370.31430  211.359120 -1011.726140 -1811.72120  200.0
# 12       12   -1354.76510  144.882950 -1127.666700 -1653.54200  200.0
# 13       13   -1374.19740  186.636610 -1018.587160 -1640.19100  200.0
# 14       14   -1336.82750  168.860630 -1047.543000 -1686.60340  200.0
# 15       15   -1369.90760  148.095780 -1166.265400 -1639.58260  200.0
# 16       16   -1382.96670  108.093056 -1188.241000 -1637.38600  200.0
# 17       17   -1324.99620  121.480540 -1096.992100 -1509.21420  200.0
# 18       18   -1389.95460  165.246900 -1110.514200 -1751.37780  200.0
# 19       19   -1344.72840  123.181854 -1117.139000 -1600.19740  200.0
# 20       20   -1381.70560  138.859990 -1100.139000 -1583.93680  200.0
# 21       21   -1338.19810  136.643520 -1017.971000 -1606.30730  200.0
# 22       22   -1320.15340  141.824200 -1102.477000 -1603.63650  200.0
# 23       23   -1338.79300  109.616280 -1160.896100 -1528.11620  200.0
# 24       24   -1351.96010  135.324190 -1110.162600 -1603.37670  200.0
# 25       25   -1329.63000  152.854400 -1117.370600 -1649.77260  200.0
# 26       26   -1378.07460   98.999670 -1228.079800 -1576.31460  200.0
# 27       27   -1350.18290  152.666530 -1115.930700 -1579.98500  200.0
# 28       28   -1364.32970  150.314800 -1214.341900 -1774.39950  200.0
# 29       29   -1350.31920  124.463500 -1170.280800 -1572.38600  200.0
# ...     ...           ...         ...          ...         ...    ...
# 4770    770    -174.22066  105.563800    -0.101336  -366.00992  200.0
# 4771    771    -148.91148   70.284090    -1.009809  -359.87480  200.0
# 4772    772    -183.20000  104.733955    -0.225279  -375.54694  200.0
# 4773    773    -164.37857  101.397770    -0.079161  -405.10037  200.0
# 4774    774    -202.03880  103.112940    -0.162896  -377.88965  200.0
# 4775    775    -207.24452   94.023480    -0.340824  -363.00974  200.0
# 4776    776    -190.58496   87.218765    -1.218004  -376.52875  200.0
# 4777    777    -183.91194  116.924324    -0.274753  -472.18005  200.0
# 4778    778    -177.99524  116.270820    -0.013273  -406.71510  200.0
# 4779    779    -187.97966   89.036990    -0.900135  -424.08942  200.0
# 4780    780    -201.17674   98.805060    -0.363720  -368.92050  200.0
# 4781    781    -205.74187  129.609820    -0.106494  -552.69560  200.0
# 4782    782    -188.19289  114.031790    -0.615521  -443.13180  200.0
# 4783    783    -164.59122   91.436005    -1.306860  -392.89560  200.0
# 4784    784    -170.74474   89.569070    -0.315623  -393.08770  200.0
# 4785    785    -164.30992   91.790450    -0.090727  -366.93927  200.0
# 4786    786    -159.58405   76.418500    -0.259208  -362.75912  200.0
# 4787    787    -166.23314  106.585335    -0.079048  -387.16540  200.0
# 4788    788    -168.94975  100.965520    -0.149285  -391.15427  200.0
# 4789    789    -177.44893   84.482910    -0.773376  -395.62958  200.0
# 4790    790    -151.11171   91.971214    -0.603326  -335.28885  200.0
# 4791    791    -187.43060  105.259890    -0.545720  -424.08078  200.0
# 4792    792    -151.15417   99.233740    -0.263305  -371.88004  200.0
# 4793    793    -177.59221   77.740380    -1.655624  -364.51923  200.0
# 4794    794    -200.53471  105.761790    -1.236790  -441.94476  200.0
# 4795    795    -205.51910   78.658960  -117.351210  -389.72473  200.0
# 4796    796    -192.17346  102.359440    -0.529060  -381.38663  200.0
# 4797    797    -151.22755  135.279750    -0.027502  -391.85535  200.0
# 4798    798    -180.08319  124.751976    -0.106292  -502.77707  200.0
# 4799    799    -180.51184   98.765045    -1.226698  -440.43185  200.0
#
#       AverageVVals    StdVVals    MaxVVals    MinVVals     ...       \
# 0         0.052812    0.233913    0.499440   -0.836971     ...
# 1        -5.862782    2.607771   -1.666755  -17.874577     ...
# 2       -32.578228   13.144202   -5.467690  -91.215370     ...
# 3      -108.229360   37.350166  -14.712350 -265.089400     ...
# 4      -229.096560   79.139120  -25.046833 -551.129150     ...
# 5      -352.488280  123.322160  -40.916775 -777.256000     ...
# 6      -353.719020  106.399540  -60.408527 -734.797060     ...
# 7      -348.825740   92.420960  -33.718464 -706.792970     ...
# 8      -380.184020   83.174050  -43.266110 -691.652040     ...
# 9      -390.458440   69.414600  -72.717540 -665.369700     ...
# 10     -394.722350   78.558685  -59.902670 -633.019400     ...
# 11     -371.841830   66.226620  -61.069660 -575.375400     ...
# 12     -390.876040   54.082745  -71.608820 -564.745600     ...
# 13     -386.879850   56.502132  -70.579720 -545.243300     ...
# 14     -390.064760   58.554546  -79.614050 -543.509800     ...
# 15     -388.359830   41.745426 -115.048470 -524.281100     ...
# 16     -394.335240   31.617777 -143.979030 -508.961270     ...
# 17     -394.821440   45.109135 -110.948425 -518.289700     ...
# 18     -386.739780   34.400547 -125.387250 -500.499760     ...
# 19     -401.539980   36.179550 -139.464400 -522.209530     ...
# 20     -390.856800   29.772818 -146.771450 -520.009160     ...
# 21     -404.961460   33.615036 -156.227100 -521.563350     ...
# 22     -387.748700   39.261810 -165.532750 -506.951800     ...
# 23     -390.661700   27.729710 -192.274780 -507.867200     ...
# 24     -390.815640   28.369452 -198.660260 -509.133800     ...
# 25     -393.536070   33.176994 -207.193420 -509.590800     ...
# 26     -388.858860   20.600758 -235.477520 -494.057560     ...
# 27     -401.711180   29.969020 -235.326640 -521.680500     ...
# 28     -397.611450   21.216711 -247.756970 -508.909360     ...
# 29     -395.128300   24.565432 -255.476230 -505.677100     ...
# ...            ...         ...         ...         ...     ...
# 4770    -15.505684   45.126420    6.514638 -312.986630     ...
# 4771    -12.487024   39.349050    3.990942 -309.193630     ...
# 4772    -16.203684   44.131120    5.704182 -270.782840     ...
# 4773    -14.138835   42.295788    4.255214 -297.437040     ...
# 4774    -17.849092   48.887268    5.925802 -302.414670     ...
# 4775    -19.310257   49.654938    5.854919 -269.862030     ...
# 4776    -17.629768   48.596256    5.410598 -296.932300     ...
# 4777    -16.012308   47.094600    7.758691 -280.025900     ...
# 4778    -16.037933   44.265064    5.340327 -301.296840     ...
# 4779    -17.004667   46.183544    4.347083 -306.819760     ...
# 4780    -19.685024   50.559692    5.637138 -301.612270     ...
# 4781    -20.151657   54.875164    4.573220 -301.389860     ...
# 4782    -16.799390   48.885307    8.203144 -315.143650     ...
# 4783    -14.338047   41.450497    6.266946 -297.834000     ...
# 4784    -13.987526   42.421020    4.026103 -299.795780     ...
# 4785    -14.046734   40.585316    6.739965 -286.992200     ...
# 4786    -13.272692   38.404892    7.244537 -265.870850     ...
# 4787    -15.285325   42.138300   14.306649 -289.280100     ...
# 4788    -15.362374   45.327908    8.206579 -322.520260     ...
# 4789    -15.342827   42.112150    7.370569 -286.564970     ...
# 4790    -12.137316   38.559180    7.110534 -297.551150     ...
# 4791    -16.846529   45.359580    6.223539 -280.640140     ...
# 4792    -12.299766   38.164646    8.076348 -272.150820     ...
# 4793    -15.582230   43.681637    5.271800 -320.879240     ...
# 4794    -18.237944   48.072460    8.208851 -294.362670     ...
# 4795    -18.578218   49.275974    7.056948 -319.084560     ...
# 4796    -17.073444   46.681503    4.680015 -285.664580     ...
# 4797    -14.868279   47.269543    5.475031 -311.873780     ...
# 4798    -17.245878   48.450270    4.678860 -293.151580     ...
# 4799    -15.910280   44.294556    5.532493 -337.490080     ...
#
#         DeltaLossV   Entropy        KL  ClipFrac  StopIter        Time  Unit  \
# 0     -5018.367000  0.908507  0.004733  0.053542      79.0    1.437035     0
# 1    -22650.678000  0.920098  0.005306  0.047292      79.0    3.657335     0
# 2    -51374.887000  0.895332  0.002570  0.026875      79.0    4.258538     0
# 3    -56051.215000  0.884559  0.003778  0.022708      79.0    4.751462     0
# 4    -24468.396000  0.898414  0.006589  0.037083      79.0    5.250535     0
# 5     -2831.643300  0.876267  0.005024  0.020833      79.0    5.747513     0
# 6     -2762.462200  0.855216  0.006371  0.039167      79.0    6.239697     0
# 7     -3897.753200  0.870240  0.006012  0.039167      79.0    6.739472     0
# 8     -2327.503200  0.855602  0.004299  0.036667      79.0    7.233267     0
# 9     -1040.392600  0.845760  0.005228  0.028958      79.0    7.738430     0
# 10    -1561.760100  0.862856  0.006486  0.041458      79.0    8.386405     0
# 11    -1180.372100  0.822425  0.004181  0.028542      79.0    8.883032     0
# 12     -367.992200  0.839826  0.007200  0.035625      79.0   11.225471     0
# 13     -380.025050  0.841826  0.002782  0.041250      79.0   13.133658     0
# 14     -531.732100  0.840789  0.004598  0.027708      79.0   16.016075     0
# 15     -256.904940  0.875272  0.004978  0.046667      79.0   18.445891     0
# 16     -143.534840  0.853834  0.005784  0.057917      79.0   20.494112     0
# 17     -597.285460  0.834382  0.006688  0.066875      79.0   22.898110     0
# 18     -377.458650  0.787516  0.007514  0.060000      79.0   23.388327     0
# 19     -490.083980  0.778111  0.007364  0.063125      79.0   23.879914     0
# 20     -214.619140  0.750280  0.005524  0.059583      79.0   24.536579     0
# 21     -366.594730  0.732720  0.006065  0.040000      79.0   25.033516     0
# 22     -396.175780  0.757972  0.007513  0.049583      79.0   25.530909     0
# 23      -99.870120  0.729095  0.006520  0.068333      79.0   27.591815     0
# 24     -138.086910  0.711909  0.007043  0.048333      79.0   28.090773     0
# 25     -219.406570  0.703375  0.007070  0.052708      79.0   28.582813     0
# 26     -225.164380  0.705495  0.006978  0.049375      79.0   29.076255     0
# 27     -361.525730  0.705434  0.005842  0.057083      79.0   29.575217     0
# 28     -105.224610  0.673314  0.009154  0.062083      79.0   30.080976     0
# 29     -200.785810  0.663418  0.006749  0.036042      79.0   30.573354     0
# ...            ...       ...       ...       ...       ...         ...   ...
# 4770     -4.823822 -2.503836  0.008116  0.083542       5.0  640.097316     5
# 4771    -28.415604 -2.499111  0.008494  0.091875       3.0  640.471191     5
# 4772    -15.698891 -2.484343  0.028056  0.374375       1.0  640.842530     5
# 4773    -25.147697 -2.487354  0.088526  0.606250       1.0  641.213681     5
# 4774     -6.818642 -2.485341  0.011331  0.043333      16.0  641.609903     5
# 4775     -3.716754 -2.515158  0.028721  0.408542       2.0  641.983576     5
# 4776    -43.844480 -2.506814  0.010984  0.176458      11.0  642.368798     5
# 4777    -11.903462 -2.485900  0.005598  0.036250       1.0  642.739837     5
# 4778    -59.101580 -2.494012  0.055509  0.469583       1.0  643.111299     5
# 4779     -9.517849 -2.498998  0.058056  0.518542       1.0  643.486286     5
# 4780    -22.005068 -2.482717  0.012973  0.051250       5.0  644.602964     5
# 4781    -15.735107 -2.499649  0.011601  0.072708      56.0  645.047534     5
# 4782     -3.893264 -2.499240  0.018326  0.234167       1.0  646.219800     5
# 4783    -26.094606 -2.501270  0.033015  0.100000       1.0  647.460140     5
# 4784     -2.233009 -2.522476  0.046422  0.294167       1.0  649.011817     5
# 4785     -3.233895 -2.512493  0.010290  0.063333       9.0  650.576201     5
# 4786    -40.214046 -2.501210  0.003071  0.033750       1.0  651.883349     5
# 4787    -51.304690 -2.513387  0.028505  0.121458       1.0  652.257391     5
# 4788    -21.189367 -2.535819  0.030268  0.082083       1.0  652.628799     5
# 4789    -17.757528 -2.510741  0.018666  0.160625       2.0  653.001691     5
# 4790     -6.747721 -2.502717  0.015250  0.150417       4.0  654.126371     5
# 4791    -30.133528 -2.490413  0.012562  0.090208       1.0  654.497926     5
# 4792    -11.957111 -2.494158  0.031717  0.407917       1.0  654.868939     5
# 4793    -12.129954 -2.501333  0.042152  0.433958       1.0  655.241117     5
# 4794    -14.029396 -2.524591  0.013986  0.096667       1.0  655.615756     5
# 4795    -12.550107 -2.519898  0.004012  0.045417       1.0  655.988957     5
# 4796     -7.480729 -2.528880  0.021555  0.308333       1.0  656.364304     5
# 4797     -7.291996 -2.507528  0.011047  0.065000       1.0  656.735868     5
# 4798    -25.361750 -2.498286  0.014814  0.182083       1.0  658.473900     5
# 4799    -20.301958 -2.518085  0.030128  0.092500       1.0  660.531090     5
#
#                          Condition1                       Condition2  \
# 0     ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 1     ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 2     ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 3     ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 4     ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 5     ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 6     ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 7     ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 8     ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 9     ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 10    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 11    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 12    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 13    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 14    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 15    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 16    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 17    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 18    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 19    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 20    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 21    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 22    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 23    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 24    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 25    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 26    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 27    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 28    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# 29    ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-0
# ...                             ...                              ...
# 4770  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4771  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4772  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4773  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4774  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4775  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4776  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4777  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4778  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4779  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4780  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4781  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4782  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4783  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4784  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4785  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4786  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4787  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4788  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4789  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4790  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4791  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4792  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4793  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4794  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4795  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4796  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4797  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4798  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
# 4799  ppo-bench_pendulum-v0_ste4800  ppo-bench_pendulum-v0_ste4800-5
#
#       Performance
# 0     -1528.92740
# 1     -1431.89030
# 2     -1441.21290
# 3     -1414.70280
# 4     -1427.56700
# 5     -1332.35550
# 6     -1335.92640
# 7     -1388.86670
# 8     -1400.04630
# 9     -1403.21250
# 10    -1307.34830
# 11    -1370.31430
# 12    -1354.76510
# 13    -1374.19740
# 14    -1336.82750
# 15    -1369.90760
# 16    -1382.96670
# 17    -1324.99620
# 18    -1389.95460
# 19    -1344.72840
# 20    -1381.70560
# 21    -1338.19810
# 22    -1320.15340
# 23    -1338.79300
# 24    -1351.96010
# 25    -1329.63000
# 26    -1378.07460
# 27    -1350.18290
# 28    -1364.32970
# 29    -1350.31920
# ...           ...
# 4770   -174.22066
# 4771   -148.91148
# 4772   -183.20000
# 4773   -164.37857
# 4774   -202.03880
# 4775   -207.24452
# 4776   -190.58496
# 4777   -183.91194
# 4778   -177.99524
# 4779   -187.97966
# 4780   -201.17674
# 4781   -205.74187
# 4782   -188.19289
# 4783   -164.59122
# 4784   -170.74474
# 4785   -164.30992
# 4786   -159.58405
# 4787   -166.23314
# 4788   -168.94975
# 4789   -177.44893
# 4790   -151.11171
# 4791   -187.43060
# 4792   -151.15417
# 4793   -177.59221
# 4794   -200.53471
# 4795   -205.51910
# 4796   -192.17346
# 4797   -151.22755
# 4798   -180.08319
# 4799   -180.51184
#
# [4800 rows x 24 columns]

# %%
# Show table of parameters used in the experiment, used as guide to graph legends

def config_values(config, paths):
    values = []
    for path in paths:
        value = config
        for name in path.split(':'):
            value = value[name]
        values.append(value)
    return values

columns = ['exp_name', 
           'steps_per_epoch',
#           'use_reward_discount',
#           'goal_octaves', 
#            'goal_discount_rate', 
#           'no_step_reward', 
#           'finish_action_path_on_new_goal', 
#            'ac_kwargs:hidden_sizes', 
#            'ac_kwargs:activation', 
#            'inverse_kwargs:hidden_sizes', 
#            'inverse_kwargs:activation', 
#            'inverse_kwargs:goals_output_activation'
          ]

data = list(map(lambda config: config_values(config, columns), configs))
df = pd.DataFrame(data=data, columns=columns)
df.drop_duplicates()
# Out:
#                         exp_name  steps_per_epoch
# 0  ppo-bench_pendulum-v0_ste4800             4800

# %%
plt.figure(figsize=(20, 15), dpi=150)

# To show individual runs, add arguments: units='Condition2, estimator=None
# To compare runs with different epoch lengts, use:xaxis='TotalEnvInteracts'

plot_data(datasets, smooth=5, condition='Condition2')
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityGoalError', smooth=1, show_legend=False, estimator='mean')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a5018ff13977> in <module>
#       1 plt.figure(figsize=(14, 8), dpi=150)
# ----> 2 plot_data(datasets, value='StabilityGoalError', smooth=1, show_legend=False, estimator='mean')
#       3 plt.show()
#
# ~/openaigym/spinningup/spinup/utils/plot.py in plot_data(data, xaxis, value, condition, smooth, show_legend, **kwargs)
#      32     sns.set(style="darkgrid", font_scale=1.5)
#      33     # sns.tsplot(data=data, time=xaxis, value=value, unit="Unit", condition=condition, ci='sd', **kwargs)
# ---> 34     sns.lineplot(data=data, x=xaxis, y=value, hue=condition, legend=show_legend, **kwargs)
#      35     """
#      36     If you upgrade to any version of Seaborn greater than 0.8.1, switch from
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend)
#     661
#     662         plot_data = self.establish_variables(
# --> 663             x, y, hue, size, style, units, data
#     664         )
#     665
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     140                 if isinstance(var, string_types):
#     141                     err = "Could not interpret input '{}'".format(var)
# --> 142                     raise ValueError(err)
#     143
#     144             # Extract variable names
#
# ValueError: Could not interpret input 'StabilityGoalError'

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityActionError', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalDiscount', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalsEntropy', smooth=1, show_legend=False)
plt.show()

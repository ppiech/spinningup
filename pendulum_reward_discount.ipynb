# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import os.path as osp
import numpy as np
from spinup.utils.plot import get_datasets, get_all_datasets, plot_data
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
datasets, configs = get_all_datasets(['/Users/ppiech/openaigym/spindata/reward_discount/'])

# Show a sample of the data
pd.concat(datasets, ignore_index=True)
# Out:
# Plotting from...
# ==================================================
#
# /Users/ppiech/openaigym/spindata/reward_discount/
#
# ==================================================
#       Epoch  AverageEpRet    StdEpRet  EpLen  GoalPathLen  StabilityReward  \
# 0         0  -1282.826300  231.227720  200.0     1.020143         0.448347
# 1         1  -1377.292000  186.267410  200.0     1.019081         0.454174
# 2         2  -1362.590600  232.501110  200.0     1.020357         0.448265
# 3         3  -1367.805500  247.939480  200.0     1.018230         0.459948
# 4         4  -1383.737300  260.395700  200.0     1.020361         0.462540
# 5         5  -1334.297700  290.525760  200.0     1.019081         0.443624
# 6         6  -1377.852500  277.653000  200.0     1.019722         0.456164
# 7         7  -1278.532000  174.236360  200.0     1.022274         0.465545
# 8         8  -1399.423800  238.244700  200.0     1.017379         0.439361
# 9         9  -1299.872200  195.769970  200.0     1.024625         0.458771
# 10       10  -1350.925900  221.876970  200.0     1.026021         0.455197
# 11       11  -1267.265600  225.210620  200.0     1.021849         0.460469
# 12       12  -1353.986000  254.341980  200.0     1.026984         0.443327
# 13       13  -1358.334100  228.550370  200.0     1.028269         0.436895
# 14       14  -1356.301300  189.532520  200.0     1.029231         0.440755
# 15       15  -1277.017200  200.549620  200.0     1.030412         0.448089
# 16       16  -1317.127400  232.948800  200.0     1.024096         0.442260
# 17       17  -1360.378800  244.379380  200.0     1.029664         0.464612
# 18       18  -1332.060700  230.275130  200.0     1.033103         0.472930
# 19       19  -1313.063500  206.596400  200.0     1.036667         0.467814
# 20       20  -1259.661900  206.174070  200.0     1.040456         0.486905
# 21       21  -1401.280300  299.725400  200.0     1.034948         0.463282
# 22       22  -1380.736300  244.515580  200.0     1.034721         0.477391
# 23       23  -1423.543800  243.206220  200.0     1.041742         0.472172
# 24       24  -1350.083400  261.073700  200.0     1.036766         0.480397
# 25       25  -1403.412600  235.913240  200.0     1.040886         0.483994
# 26       26  -1363.608500  226.158260  200.0     1.048622         0.487173
# 27       27  -1356.294800  301.620820  200.0     1.047304         0.491108
# 28       28  -1386.780300  269.990900  200.0     1.048428         0.453481
# 29       29  -1374.712400  241.647170  200.0     1.052677         0.472722
# ...     ...           ...         ...    ...          ...              ...
# 3920    370   -198.673510  130.174290  200.0     1.642427         0.748851
# 3921    371   -190.662610  138.553730  200.0     1.585821         0.777822
# 3922    372   -200.782230  132.470900  200.0     1.617765         0.761790
# 3923    373   -194.546590   75.854470  200.0     1.533817         0.799972
# 3924    374   -219.986650  240.649440  200.0     1.613827         0.803016
# 3925    375   -294.866000  277.011300  200.0     1.770148         0.813197
# 3926    376   -188.722950  171.651950  200.0     1.533910         0.788402
# 3927    377   -182.241290  108.278015  200.0     1.524080         0.768730
# 3928    378   -227.214070  106.641410  200.0     1.648893         0.785139
# 3929    379   -220.939740  126.308040  200.0     1.692197         0.759001
# 3930    380   -200.621380  156.578740  200.0     1.590790         0.752834
# 3931    381   -193.049640  135.282270  200.0     1.612645         0.763477
# 3932    382   -203.060290  165.836000  200.0     1.598385         0.768801
# 3933    383   -127.720985   92.032234  200.0     1.368772         0.756889
# 3934    384   -189.632640   89.890150  200.0     1.482291         0.769686
# 3935    385   -218.576950  167.079440  200.0     1.623594         0.794019
# 3936    386   -214.591350  137.750370  200.0     1.643173         0.835710
# 3937    387   -179.789410  133.798370  200.0     1.527697         0.810360
# 3938    388   -225.707950  125.004616  200.0     1.614916         0.812697
# 3939    389   -171.046510  118.880760  200.0     1.485316         0.808635
# 3940    390   -205.848630  149.198350  200.0     1.584854         0.814042
# 3941    391   -205.883220  121.625534  200.0     1.542447         0.835072
# 3942    392   -224.196240  167.315380  200.0     1.608597         0.828917
# 3943    393   -165.864580  100.117200  200.0     1.530353         0.839457
# 3944    394   -220.776410  111.062340  200.0     1.675578         0.834888
# 3945    395   -242.527830  126.748930  200.0     1.717444         0.840643
# 3946    396   -191.396900   61.808250  200.0     1.547060         0.831067
# 3947    397   -221.949630  149.017210  200.0     1.734548         0.830962
# 3948    398   -245.522520  181.794430  200.0     1.845103         0.846812
# 3949    399   -180.764700   92.823690  200.0     1.576551         0.839256
#
#       StabilityActionError  StabilityGoalError  ForwardPreictionError  \
# 0                 0.448392            0.569375               0.631964
# 1                 0.398747            0.557025               0.486984
# 2                 0.375543            0.558613               0.430865
# 3                 0.282015            0.549369               0.369615
# 4                 0.242350            0.538756               0.313480
# 5                 0.221134            0.568307               0.272940
# 6                 0.212638            0.555391               0.219799
# 7                 0.239175            0.537936               0.214125
# 8                 0.519581            0.572233               0.175651
# 9                 0.195916            0.549395               0.166646
# 10                0.162200            0.549844               0.149073
# 11                0.198594            0.544668               0.158291
# 12                0.207746            0.562741               0.135896
# 13                0.425256            0.570482               0.107166
# 14                0.610297            0.568769               0.106900
# 15                0.279284            0.561120               0.113271
# 16                0.399985            0.569583               0.097956
# 17                0.196920            0.546270               0.100066
# 18                0.186260            0.536550               0.093254
# 19                0.166212            0.537181               0.090446
# 20                0.249435            0.517292               0.094681
# 21                0.218045            0.542552               0.076812
# 22                0.169916            0.527858               0.063344
# 23                0.202245            0.535371               0.058728
# 24                0.207151            0.520911               0.063871
# 25                0.173639            0.519896               0.064618
# 26                0.582756            0.513568               0.067766
# 27                0.139638            0.507305               0.067060
# 28                0.194825            0.550046               0.054285
# 29                0.118019            0.528913               0.068414
# ...                    ...                 ...                    ...
# 3920              0.004153            0.248971               0.000891
# 3921              0.004893            0.219147               0.000837
# 3922              0.004616            0.236257               0.000810
# 3923              0.003630            0.197402               0.000821
# 3924              0.006766            0.192962               0.000865
# 3925              0.006244            0.182214               0.000789
# 3926              0.003881            0.208991               0.000728
# 3927              0.003199            0.229141               0.000916
# 3928              0.003852            0.213346               0.000907
# 3929              0.003355            0.238737               0.000912
# 3930              0.001960            0.246055               0.000913
# 3931              0.002750            0.234473               0.000878
# 3932              0.001868            0.230378               0.000893
# 3933              0.001564            0.242077               0.000578
# 3934              0.001719            0.229538               0.000859
# 3935              0.001756            0.204974               0.000820
# 3936              0.002900            0.163392               0.000787
# 3937              0.001920            0.188346               0.000793
# 3938              0.002056            0.185840               0.000916
# 3939              0.001967            0.190241               0.000826
# 3940              0.003548            0.183691               0.000775
# 3941              0.002491            0.163346               0.000753
# 3942              0.004018            0.168587               0.000717
# 3943              0.002055            0.159154               0.000690
# 3944              0.003507            0.162467               0.000884
# 3945              0.003780            0.156914               0.001082
# 3946              0.003603            0.166660               0.000831
# 3947              0.006886            0.166165               0.001047
# 3948              0.005956            0.150449               0.001027
# 3949              0.003443            0.158796               0.000727
#
#       GoalDiscount     ...       ActionsClipFrac  ActionsStopIter  \
# 0         0.491174     ...              0.046250             79.0
# 1         0.489128     ...              0.050208             79.0
# 2         0.483654     ...              0.069375             79.0
# 3         0.487272     ...              0.079583             79.0
# 4         0.481222     ...              0.088958             79.0
# 5         0.473587     ...              0.103750             79.0
# 6         0.468925     ...              0.096875             79.0
# 7         0.467992     ...              0.093958             79.0
# 8         0.473675     ...              0.102500             79.0
# 9         0.467078     ...              0.107708             79.0
# 10        0.467014     ...              0.120625             79.0
# 11        0.472087     ...              0.123542             79.0
# 12        0.482105     ...              0.116042             79.0
# 13        0.487719     ...              0.124792             79.0
# 14        0.495937     ...              0.126667             79.0
# 15        0.491339     ...              0.125833             79.0
# 16        0.496906     ...              0.116667             79.0
# 17        0.507930     ...              0.151042             79.0
# 18        0.511672     ...              0.136875             79.0
# 19        0.509099     ...              0.132708             79.0
# 20        0.491302     ...              0.134375             79.0
# 21        0.490976     ...              0.148542             79.0
# 22        0.479302     ...              0.143542             79.0
# 23        0.467034     ...              0.161458             79.0
# 24        0.461719     ...              0.149792             79.0
# 25        0.464412     ...              0.153125             79.0
# 26        0.455807     ...              0.157292             79.0
# 27        0.450484     ...              0.166250             79.0
# 28        0.463963     ...              0.165208             79.0
# 29        0.445682     ...              0.163750             79.0
# ...            ...     ...                   ...              ...
# 3920      0.488702     ...              0.099792             79.0
# 3921      0.493116     ...              0.092917             75.0
# 3922      0.487611     ...              0.084583             79.0
# 3923      0.495791     ...              0.081875             79.0
# 3924      0.491988     ...              0.077917             79.0
# 3925      0.478369     ...              0.100000             79.0
# 3926      0.499226     ...              0.080417             79.0
# 3927      0.500912     ...              0.082292             79.0
# 3928      0.499410     ...              0.082500             79.0
# 3929      0.493498     ...              0.102500             79.0
# 3930      0.491733     ...              0.119375             79.0
# 3931      0.490299     ...              0.094375             79.0
# 3932      0.490837     ...              0.083542             79.0
# 3933      0.493137     ...              0.098542             79.0
# 3934      0.492139     ...              0.081250             79.0
# 3935      0.492221     ...              0.083333             79.0
# 3936      0.493919     ...              0.080000             66.0
# 3937      0.495267     ...              0.080000             79.0
# 3938      0.494246     ...              0.071458             79.0
# 3939      0.491675     ...              0.087292             79.0
# 3940      0.491277     ...              0.077500             33.0
# 3941      0.494909     ...              0.081250             79.0
# 3942      0.494442     ...              0.085833             76.0
# 3943      0.498380     ...              0.077500             39.0
# 3944      0.498315     ...              0.075833             79.0
# 3945      0.496905     ...              0.083542             79.0
# 3946      0.495193     ...              0.086042             79.0
# 3947      0.494046     ...              0.094167             79.0
# 3948      0.492425     ...              0.116250             79.0
# 3949      0.492959     ...              0.108542             79.0
#
#       LossActionInverse  DeltaLossActionInverse  LossGoalInverse  \
# 0              0.408965               -0.127392         0.205549
# 1              0.395765               -0.012704         0.161630
# 2              0.376918               -0.014792         0.126830
# 3              0.365503               -0.018468         0.102122
# 4              0.355980               -0.019621         0.084127
# 5              0.356105               -0.011961         0.072576
# 6              0.335736               -0.021335         0.062616
# 7              0.340206               -0.011095         0.042990
# 8              0.322992               -0.016694         0.048608
# 9              0.326183               -0.006869         0.033202
# 10             0.331655                0.000477         0.035396
# 11             0.325611               -0.001821         0.032431
# 12             0.337208                0.011155         0.030823
# 13             0.335052                0.007818         0.025178
# 14             0.308100               -0.011507         0.023757
# 15             0.312929               -0.001531         0.022750
# 16             0.292477               -0.013391         0.022073
# 17             0.285461               -0.011571         0.022104
# 18             0.268712               -0.017121         0.020883
# 19             0.250786               -0.022146         0.019913
# 20             0.250719               -0.011367         0.020005
# 21             0.254484               -0.000536         0.019584
# 22             0.235984               -0.009033         0.018243
# 23             0.216443               -0.015616         0.017685
# 24             0.215822               -0.007266         0.017998
# 25             0.191826               -0.019819         0.017509
# 26             0.189473               -0.012562         0.017356
# 27             0.165647               -0.021833         0.018025
# 28             0.170483               -0.007653         0.017081
# 29             0.144542               -0.020353         0.016985
# ...                 ...                     ...              ...
# 3920           0.003987               -0.000847         0.010112
# 3921           0.005242                0.000268         0.010296
# 3922           0.005474                0.000406         0.009795
# 3923           0.006544                0.001104         0.009880
# 3924           0.006205                0.000358         0.009900
# 3925           0.008098                0.001628         0.009465
# 3926           0.006378                0.000047         0.010510
# 3927           0.004702               -0.001143         0.010807
# 3928           0.006202                0.000273         0.010599
# 3929           0.004655               -0.000911         0.010600
# 3930           0.004213               -0.000955         0.010642
# 3931           0.004338               -0.000554         0.010544
# 3932           0.005292                0.000138         0.010506
# 3933           0.003381               -0.001289         0.011303
# 3934           0.004325               -0.000143         0.010597
# 3935           0.007214                0.001841         0.009971
# 3936           0.005827                0.000413         0.009921
# 3937           0.004489               -0.000661         0.010545
# 3938           0.005679                0.000262         0.010358
# 3939           0.004898               -0.000361         0.010694
# 3940           0.007341                0.001357         0.010189
# 3941           0.006556                0.000508         0.010134
# 3942           0.006943                0.000802         0.010060
# 3943           0.003355               -0.001908         0.010191
# 3944           0.004888               -0.000239         0.009774
# 3945           0.004116               -0.000651         0.009636
# 3946           0.004066               -0.000464         0.010104
# 3947           0.004437               -0.000126         0.009820
# 3948           0.004993                0.000211         0.009486
# 3949           0.003200               -0.001070         0.010286
#
#       DeltaLossGoalInverse  Unit                       Condition1  \
# 0                -0.057730     5  reward-discount_pendulum-v0_use
# 1                -0.044256     5  reward-discount_pendulum-v0_use
# 2                -0.033957     5  reward-discount_pendulum-v0_use
# 3                -0.024092     5  reward-discount_pendulum-v0_use
# 4                -0.017039     5  reward-discount_pendulum-v0_use
# 5                -0.011443     5  reward-discount_pendulum-v0_use
# 6                -0.009016     5  reward-discount_pendulum-v0_use
# 7                -0.014762     5  reward-discount_pendulum-v0_use
# 8                -0.003198     5  reward-discount_pendulum-v0_use
# 9                -0.009271     5  reward-discount_pendulum-v0_use
# 10               -0.002670     5  reward-discount_pendulum-v0_use
# 11               -0.002177     5  reward-discount_pendulum-v0_use
# 12               -0.001300     5  reward-discount_pendulum-v0_use
# 13               -0.003570     5  reward-discount_pendulum-v0_use
# 14               -0.002521     5  reward-discount_pendulum-v0_use
# 15               -0.001638     5  reward-discount_pendulum-v0_use
# 16               -0.001014     5  reward-discount_pendulum-v0_use
# 17               -0.000284     5  reward-discount_pendulum-v0_use
# 18               -0.000633     5  reward-discount_pendulum-v0_use
# 19               -0.000785     5  reward-discount_pendulum-v0_use
# 20               -0.000188     5  reward-discount_pendulum-v0_use
# 21               -0.000195     5  reward-discount_pendulum-v0_use
# 22               -0.000868     5  reward-discount_pendulum-v0_use
# 23               -0.000832     5  reward-discount_pendulum-v0_use
# 24               -0.000183     5  reward-discount_pendulum-v0_use
# 25               -0.000333     5  reward-discount_pendulum-v0_use
# 26               -0.000231     5  reward-discount_pendulum-v0_use
# 27                0.000400     5  reward-discount_pendulum-v0_use
# 28               -0.000274     5  reward-discount_pendulum-v0_use
# 29               -0.000181     5  reward-discount_pendulum-v0_use
# ...                    ...   ...                              ...
# 3920             -0.000251     9      reward-discount_pendulum-v0
# 3921             -0.000053     9      reward-discount_pendulum-v0
# 3922             -0.000411     9      reward-discount_pendulum-v0
# 3923             -0.000251     9      reward-discount_pendulum-v0
# 3924             -0.000166     9      reward-discount_pendulum-v0
# 3925             -0.000478     9      reward-discount_pendulum-v0
# 3926              0.000387     9      reward-discount_pendulum-v0
# 3927              0.000475     9      reward-discount_pendulum-v0
# 3928              0.000198     9      reward-discount_pendulum-v0
# 3929              0.000141     9      reward-discount_pendulum-v0
# 3930              0.000100     9      reward-discount_pendulum-v0
# 3931             -0.000007     9      reward-discount_pendulum-v0
# 3932             -0.000017     9      reward-discount_pendulum-v0
# 3933              0.000548     9      reward-discount_pendulum-v0
# 3934             -0.000126     9      reward-discount_pendulum-v0
# 3935             -0.000553     9      reward-discount_pendulum-v0
# 3936             -0.000442     9      reward-discount_pendulum-v0
# 3937              0.000118     9      reward-discount_pendulum-v0
# 3938             -0.000061     9      reward-discount_pendulum-v0
# 3939              0.000191     9      reward-discount_pendulum-v0
# 3940             -0.000233     9      reward-discount_pendulum-v0
# 3941             -0.000210     9      reward-discount_pendulum-v0
# 3942             -0.000222     9      reward-discount_pendulum-v0
# 3943             -0.000071     9      reward-discount_pendulum-v0
# 3944             -0.000342     9      reward-discount_pendulum-v0
# 3945             -0.000326     9      reward-discount_pendulum-v0
# 3946              0.000086     9      reward-discount_pendulum-v0
# 3947             -0.000120     9      reward-discount_pendulum-v0
# 3948             -0.000339     9      reward-discount_pendulum-v0
# 3949              0.000310     9      reward-discount_pendulum-v0
#
#                               Condition2  Performance
# 0     reward-discount_pendulum-v0_use-40 -1282.826300
# 1     reward-discount_pendulum-v0_use-40 -1377.292000
# 2     reward-discount_pendulum-v0_use-40 -1362.590600
# 3     reward-discount_pendulum-v0_use-40 -1367.805500
# 4     reward-discount_pendulum-v0_use-40 -1383.737300
# 5     reward-discount_pendulum-v0_use-40 -1334.297700
# 6     reward-discount_pendulum-v0_use-40 -1377.852500
# 7     reward-discount_pendulum-v0_use-40 -1278.532000
# 8     reward-discount_pendulum-v0_use-40 -1399.423800
# 9     reward-discount_pendulum-v0_use-40 -1299.872200
# 10    reward-discount_pendulum-v0_use-40 -1350.925900
# 11    reward-discount_pendulum-v0_use-40 -1267.265600
# 12    reward-discount_pendulum-v0_use-40 -1353.986000
# 13    reward-discount_pendulum-v0_use-40 -1358.334100
# 14    reward-discount_pendulum-v0_use-40 -1356.301300
# 15    reward-discount_pendulum-v0_use-40 -1277.017200
# 16    reward-discount_pendulum-v0_use-40 -1317.127400
# 17    reward-discount_pendulum-v0_use-40 -1360.378800
# 18    reward-discount_pendulum-v0_use-40 -1332.060700
# 19    reward-discount_pendulum-v0_use-40 -1313.063500
# 20    reward-discount_pendulum-v0_use-40 -1259.661900
# 21    reward-discount_pendulum-v0_use-40 -1401.280300
# 22    reward-discount_pendulum-v0_use-40 -1380.736300
# 23    reward-discount_pendulum-v0_use-40 -1423.543800
# 24    reward-discount_pendulum-v0_use-40 -1350.083400
# 25    reward-discount_pendulum-v0_use-40 -1403.412600
# 26    reward-discount_pendulum-v0_use-40 -1363.608500
# 27    reward-discount_pendulum-v0_use-40 -1356.294800
# 28    reward-discount_pendulum-v0_use-40 -1386.780300
# 29    reward-discount_pendulum-v0_use-40 -1374.712400
# ...                                  ...          ...
# 3920      reward-discount_pendulum-v0-49  -198.673510
# 3921      reward-discount_pendulum-v0-49  -190.662610
# 3922      reward-discount_pendulum-v0-49  -200.782230
# 3923      reward-discount_pendulum-v0-49  -194.546590
# 3924      reward-discount_pendulum-v0-49  -219.986650
# 3925      reward-discount_pendulum-v0-49  -294.866000
# 3926      reward-discount_pendulum-v0-49  -188.722950
# 3927      reward-discount_pendulum-v0-49  -182.241290
# 3928      reward-discount_pendulum-v0-49  -227.214070
# 3929      reward-discount_pendulum-v0-49  -220.939740
# 3930      reward-discount_pendulum-v0-49  -200.621380
# 3931      reward-discount_pendulum-v0-49  -193.049640
# 3932      reward-discount_pendulum-v0-49  -203.060290
# 3933      reward-discount_pendulum-v0-49  -127.720985
# 3934      reward-discount_pendulum-v0-49  -189.632640
# 3935      reward-discount_pendulum-v0-49  -218.576950
# 3936      reward-discount_pendulum-v0-49  -214.591350
# 3937      reward-discount_pendulum-v0-49  -179.789410
# 3938      reward-discount_pendulum-v0-49  -225.707950
# 3939      reward-discount_pendulum-v0-49  -171.046510
# 3940      reward-discount_pendulum-v0-49  -205.848630
# 3941      reward-discount_pendulum-v0-49  -205.883220
# 3942      reward-discount_pendulum-v0-49  -224.196240
# 3943      reward-discount_pendulum-v0-49  -165.864580
# 3944      reward-discount_pendulum-v0-49  -220.776410
# 3945      reward-discount_pendulum-v0-49  -242.527830
# 3946      reward-discount_pendulum-v0-49  -191.396900
# 3947      reward-discount_pendulum-v0-49  -221.949630
# 3948      reward-discount_pendulum-v0-49  -245.522520
# 3949      reward-discount_pendulum-v0-49  -180.764700
#
# [3950 rows x 42 columns]

# %%
# Show table of parameters used in the experiment, used as guide to graph legends

def config_values(config, paths):
    values = []
    for path in paths:
        value = config
        for name in path.split(':'):
            value = value[name]
        values.append(value)
    return values

columns = ['exp_name', 
           'steps_per_epoch',
           'use_reward_discount',
           'goal_octaves', 
            'goal_discount_rate', 
#           'no_step_reward', 
#           'finish_action_path_on_new_goal', 
#            'ac_kwargs:hidden_sizes', 
#            'ac_kwargs:activation', 
#            'inverse_kwargs:hidden_sizes', 
#            'inverse_kwargs:activation', 
#            'inverse_kwargs:goals_output_activation'
          ]

data = list(map(lambda config: config_values(config, columns), configs))
df = pd.DataFrame(data=data, columns=columns)
df.drop_duplicates()
# Out:
#                           exp_name  steps_per_epoch  use_reward_discount  \
# 0  reward-discount_pendulum-v0_use             4800                 True
# 5      reward-discount_pendulum-v0             4800                False
#
#    goal_octaves  goal_discount_rate
# 0             6                0.01
# 5             6                0.01

# %%
plt.figure(figsize=(20, 15), dpi=150)

# To show individual runs, add arguments: units='Condition2, estimator=None
# To compare runs with different epoch lengts, use:xaxis='TotalEnvInteracts'

plot_data(datasets, smooth=5, xaxis='TotalEnvInteracts')
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityGoalError', smooth=1, show_legend=False, estimator='mean')
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityActionError', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalDiscount', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-469ac8f2fb4e> in <module>
#       1 plt.figure(figsize=(14, 8), dpi=150)
# ----> 2 plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
#       3 plt.show()
#
# ~/openaigym/spinningup/spinup/utils/plot.py in plot_data(data, xaxis, value, condition, smooth, show_legend, **kwargs)
#      32     sns.set(style="darkgrid", font_scale=1.5)
#      33     # sns.tsplot(data=data, time=xaxis, value=value, unit="Unit", condition=condition, ci='sd', **kwargs)
# ---> 34     sns.lineplot(data=data, x=xaxis, y=value, hue=condition, legend=show_legend, **kwargs)
#      35     """
#      36     If you upgrade to any version of Seaborn greater than 0.8.1, switch from
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend)
#     661
#     662         plot_data = self.establish_variables(
# --> 663             x, y, hue, size, style, units, data
#     664         )
#     665
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     140                 if isinstance(var, string_types):
#     141                     err = "Could not interpret input '{}'".format(var)
# --> 142                     raise ValueError(err)
#     143
#     144             # Extract variable names
#
# ValueError: Could not interpret input 'ActionsEntropy'

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalsEntropy', smooth=1, show_legend=False)
plt.show()

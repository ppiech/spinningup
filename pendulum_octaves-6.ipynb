# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import os.path as osp
import numpy as np
from spinup.utils.plot import get_datasets, get_all_datasets, plot_data
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
datasets, configs = get_all_datasets(['/Users/ppiech/openaigym/spindata/octaves/octaves-6/'])

# Show a sample of the data
pd.concat(datasets, ignore_index=True)
# Out:
# Plotting from...
# ==================================================
#
# /Users/ppiech/openaigym/spindata/octaves/octaves-6/
#
# ==================================================
#        Epoch  AverageEpRet    StdEpRet  EpLen  GoalPathLen  StabilityReward  \
# 0          0   -1312.47730  262.532620  200.0     1.096901         0.364993
# 1          1   -1306.82410  183.335280  200.0     1.073930         0.339403
# 2          2   -1528.47360  249.743940  200.0     1.078389         0.441687
# 3          3   -1359.65220  279.129460  200.0     1.077156         0.449198
# 4          4   -1298.73490  210.212800  200.0     1.107503         0.429910
# 5          5   -1332.35830  209.667740  200.0     1.111111         0.413372
# 6          6   -1246.61770  209.812900  200.0     1.104340         0.445167
# 7          7   -1267.82950  332.252440  200.0     1.094636         0.434164
# 8          8   -1263.98570  229.678680  200.0     1.122846         0.441344
# 9          9   -1195.04820  131.595780  200.0     1.097422         0.430966
# 10        10   -1510.00890  304.724760  200.0     1.129246         0.406091
# 11        11   -1185.01780  203.336150  200.0     1.147687         0.403442
# 12        12   -1340.22420  275.290300  200.0     1.133186         0.433876
# 13        13   -1379.16560  240.485030  200.0     1.164722         0.420468
# 14        14   -1130.93070  130.573820  200.0     1.218025         0.435044
# 15        15   -1201.81880  174.453140  200.0     1.167190         0.441172
# 16        16   -1217.79150  236.867310  200.0     1.167190         0.441775
# 17        17   -1218.07970  237.877270  200.0     1.171685         0.438393
# 18        18   -1295.48690  185.169970  200.0     1.162926         0.450110
# 19        19   -1111.85410  267.353970  200.0     1.158341         0.430485
# 20        20   -1362.50300  278.616180  200.0     1.149844         0.459885
# 21        21   -1190.80460  197.512530  200.0     1.151069         0.456561
# 22        22   -1192.30870  135.107160  200.0     1.205467         0.470807
# 23        23    -946.49660   75.699230  200.0     1.298410         0.486010
# 24        24   -1031.11150  227.596540  200.0     1.217213         0.488333
# 25        25   -1091.55500  276.227700  200.0     1.233165         0.497156
# 26        26   -1200.24280  251.127240  200.0     1.337264         0.496773
# 27        27   -1173.73050  158.982760  200.0     1.341016         0.530911
# 28        28   -1123.42540  121.926780  200.0     1.329251         0.517436
# 29        29   -1257.29800  351.033700  200.0     1.383089         0.564577
# ...      ...           ...         ...    ...          ...              ...
# 15970   1570   -1105.53560   25.285654  200.0     3.169536         0.901946
# 15971   1571   -1067.75990   62.160004  200.0     3.340864         0.917429
# 15972   1572    -895.79755  265.682200  200.0     7.737211         0.917106
# 15973   1573   -1130.10390   62.527252  200.0     3.186508         0.894119
# 15974   1574    -997.94574  244.467500  200.0     4.029550         0.888619
# 15975   1575   -1115.52050   87.542145  200.0     3.381963         0.894869
# 15976   1576   -1085.67350   76.702660  200.0     3.318514         0.894452
# 15977   1577    -972.80390  216.732270  200.0     5.105978         0.925385
# 15978   1578   -1078.34510  118.794090  200.0     3.672252         0.923295
# 15979   1579   -1029.32040  235.882020  200.0     3.855698         0.921136
# 15980   1580   -1081.24760  104.041695  200.0     3.517103         0.931874
# 15981   1581    -924.32160  220.239960  200.0     4.617787         0.932851
# 15982   1582   -1143.61290   77.970810  200.0     3.385705         0.944555
# 15983   1583   -1090.33970  105.547530  200.0     3.559299         0.928766
# 15984   1584   -1009.73860  222.930270  200.0     3.717568         0.918867
# 15985   1585   -1032.31640  192.117400  200.0     3.780175         0.914443
# 15986   1586    -950.40870  245.461790  200.0     3.889189         0.923419
# 15987   1587    -988.57720  156.640760  200.0     4.085811         0.917319
# 15988   1588   -1047.73250  157.833970  200.0     4.909153         0.911021
# 15989   1589   -1056.82470  146.450530  200.0     3.609805         0.937191
# 15990   1590   -1083.46730  102.978195  200.0     3.757556         0.917981
# 15991   1591    -974.80470  219.074080  200.0     3.956433         0.926800
# 15992   1592   -1000.88450  254.109220  200.0     4.109993         0.923481
# 15993   1593   -1118.50230   62.911583  200.0     3.323097         0.929535
# 15994   1594   -1066.66490  245.880080  200.0     5.582996         0.938405
# 15995   1595   -1188.78040   31.448723  200.0     3.352037         0.948401
# 15996   1596    -911.22095  218.282260  200.0     4.210239         0.942875
# 15997   1597   -1049.82680  248.656300  200.0     4.759511         0.949899
# 15998   1598   -1070.91550   58.176170  200.0     3.408939         0.958780
# 15999   1599   -1055.06710  167.926330  200.0     5.460263         0.952783
#
#        StabilityActionError  StabilityGoalError  ForwardPreictionError  \
# 0                  0.337969            0.672500               0.342736
# 1                  0.254261            0.689271               0.313349
# 2                  0.217286            0.569583               0.241971
# 3                  0.654983            0.559792               0.233067
# 4                  0.192850            0.573229               0.230104
# 5                  0.203418            0.606875               0.201008
# 6                  0.282695            0.560312               0.182220
# 7                  0.243111            0.579479               0.165435
# 8                  0.231864            0.579583               0.145701
# 9                  0.230842            0.585833               0.138307
# 10                 0.106602            0.609479               0.112092
# 11                 0.334106            0.611771               0.136951
# 12                 0.154090            0.577396               0.110627
# 13                 0.385078            0.592396               0.098912
# 14                 0.137401            0.585729               0.130435
# 15                 0.204262            0.590625               0.116316
# 16                 0.145156            0.590208               0.120095
# 17                 0.218506            0.560417               0.087927
# 18                 0.252316            0.548958               0.071966
# 19                 0.263105            0.570521               0.085419
# 20                 0.281771            0.542917               0.066045
# 21                 0.254346            0.550104               0.064593
# 22                 0.473702            0.521979               0.054887
# 23                 0.237105            0.510000               0.063309
# 24                 0.258980            0.495104               0.052724
# 25                 0.250207            0.499167               0.045829
# 26                 0.290532            0.486979               0.038993
# 27                 0.241022            0.446042               0.034989
# 28                 0.438746            0.456875               0.031562
# 29                 0.199007            0.404271               0.026971
# ...                     ...                 ...                    ...
# 15970              0.000520            0.097708               0.000170
# 15971              0.000500            0.082187               0.000124
# 15972              0.002628            0.080521               0.000164
# 15973              0.001420            0.104688               0.000125
# 15974              0.001397            0.110312               0.000097
# 15975              0.000711            0.104583               0.000198
# 15976              0.000749            0.105104               0.000642
# 15977              0.001723            0.073333               0.000474
# 15978              0.000841            0.076042               0.000422
# 15979              0.002115            0.076979               0.000299
# 15980              0.000967            0.067292               0.000120
# 15981              0.002319            0.065000               0.000272
# 15982              0.000966            0.054688               0.000531
# 15983              0.001260            0.070521               0.000351
# 15984              0.001540            0.080521               0.000192
# 15985              0.002329            0.083542               0.000159
# 15986              0.001789            0.075000               0.000058
# 15987              0.001591            0.081250               0.000087
# 15988              0.004434            0.085417               0.000055
# 15989              0.001163            0.061875               0.000049
# 15990              0.000925            0.081250               0.000376
# 15991              0.000976            0.072500               0.000419
# 15992              0.001568            0.075417               0.000349
# 15993              0.003880            0.067917               0.000906
# 15994              0.001187            0.060729               0.000946
# 15995              0.001384            0.050729               0.001094
# 15996              0.001646            0.055729               0.001207
# 15997              0.001993            0.048229               0.000564
# 15998              0.002845            0.038958               0.000345
# 15999              0.001730            0.045625               0.000887
#
#        GoalDiscount  RewardDiscount  GoalsStepReward  ActionsReward  \
# 0          0.458912        0.761470         0.213874      -6.161236
# 1          0.451111        0.556554         0.189632      -6.192802
# 2          0.457263        0.895543         0.238596      -7.181637
# 3          0.442973        0.884969         0.235155      -6.325372
# 4          0.421141        0.764984         0.226574      -6.030989
# 5          0.425571        0.720276         0.225751      -6.200293
# 6          0.440121        0.620533         0.245672      -5.736869
# 7          0.453158        0.342014         0.241325      -5.878666
# 8          0.436903        0.533095         0.248071      -5.840282
# 9          0.440862        0.156593         0.236382      -5.506637
# 10         0.408747        0.460705         0.222079      -7.100554
# 11         0.403458        0.678124         0.218777      -5.444385
# 12         0.432276        0.631110         0.246098      -6.193333
# 13         0.411086        0.877973         0.247712      -6.368622
# 14         0.396617        0.529455         0.251736      -5.076653
# 15         0.423059        0.052995         0.244554      -5.456204
# 16         0.440477        0.115739         0.251312      -5.561552
# 17         0.422515        0.133060         0.255293      -5.586584
# 18         0.433570        0.167588         0.248271      -6.004959
# 19         0.456727        0.043593         0.261402      -5.023651
# 20         0.479624        0.298491         0.281717      -6.326521
# 21         0.461736        0.189049         0.290226      -5.440063
# 22         0.436243        0.024405         0.289957      -5.413185
# 23         0.375720        0.017051         0.293277      -3.997443
# 24         0.448731        0.023849         0.330351      -4.541322
# 25         0.435572        0.049102         0.329127      -4.828877
# 26         0.410788        0.109114         0.340725      -5.384320
# 27         0.483972        0.029832         0.442976      -5.161170
# 28         0.394023        0.028419         0.359291      -4.913031
# 29         0.469543        0.099410         0.506581      -5.549777
# ...             ...             ...              ...            ...
# 15970      0.481056        0.016493         1.442233      -4.486931
# 15971      0.475304        0.016347         1.510628      -4.285079
# 15972      0.450200        0.019593         3.560491      -3.587079
# 15973      0.475924        0.019061         1.402654      -4.612344
# 15974      0.470167        0.019732         1.829626      -4.013634
# 15975      0.471264        0.019431         1.462599      -4.502099
# 15976      0.472163        0.017397         1.423250      -4.323007
# 15977      0.468723        0.016101         2.201447      -3.797009
# 15978      0.469436        0.018756         1.615594      -4.280921
# 15979      0.464187        0.018412         1.720636      -4.058162
# 15980      0.470143        0.016958         1.539903      -4.268193
# 15981      0.469255        0.018895         2.092662      -3.537928
# 15982      0.462499        0.022490         1.439219      -4.548503
# 15983      0.471023        0.018629         1.567761      -4.300312
# 15984      0.467373        0.016861         1.637190      -3.926709
# 15985      0.468877        0.016697         1.694425      -4.042084
# 15986      0.468874        0.016574         1.742272      -3.633570
# 15987      0.470380        0.016001         1.831243      -3.849178
# 15988      0.469750        0.019045         2.188772      -4.189574
# 15989      0.468289        0.019313         1.616656      -4.138532
# 15990      0.469747        0.017220         1.690669      -4.307628
# 15991      0.467421        0.016939         1.768632      -3.789426
# 15992      0.465319        0.019329         1.870107      -3.915625
# 15993      0.471405        0.017508         1.481733      -4.485167
# 15994      0.469337        0.018013         2.472207      -4.284462
# 15995      0.472898        0.020413         1.497143      -4.835543
# 15996      0.465599        0.015640         1.887567      -3.495390
# 15997      0.468172        0.020134         2.100829      -4.170443
# 15998      0.470905        0.016367         1.541033      -4.186593
# 15999      0.467222        0.020598         2.371706      -4.193905
#
#        TotalEnvInteracts  Unit             Condition1  \
# 0                   1200     0  octaves-6_pendulum-v0
# 1                   2400     0  octaves-6_pendulum-v0
# 2                   3600     0  octaves-6_pendulum-v0
# 3                   4800     0  octaves-6_pendulum-v0
# 4                   6000     0  octaves-6_pendulum-v0
# 5                   7200     0  octaves-6_pendulum-v0
# 6                   8400     0  octaves-6_pendulum-v0
# 7                   9600     0  octaves-6_pendulum-v0
# 8                  10800     0  octaves-6_pendulum-v0
# 9                  12000     0  octaves-6_pendulum-v0
# 10                 13200     0  octaves-6_pendulum-v0
# 11                 14400     0  octaves-6_pendulum-v0
# 12                 15600     0  octaves-6_pendulum-v0
# 13                 16800     0  octaves-6_pendulum-v0
# 14                 18000     0  octaves-6_pendulum-v0
# 15                 19200     0  octaves-6_pendulum-v0
# 16                 20400     0  octaves-6_pendulum-v0
# 17                 21600     0  octaves-6_pendulum-v0
# 18                 22800     0  octaves-6_pendulum-v0
# 19                 24000     0  octaves-6_pendulum-v0
# 20                 25200     0  octaves-6_pendulum-v0
# 21                 26400     0  octaves-6_pendulum-v0
# 22                 27600     0  octaves-6_pendulum-v0
# 23                 28800     0  octaves-6_pendulum-v0
# 24                 30000     0  octaves-6_pendulum-v0
# 25                 31200     0  octaves-6_pendulum-v0
# 26                 32400     0  octaves-6_pendulum-v0
# 27                 33600     0  octaves-6_pendulum-v0
# 28                 34800     0  octaves-6_pendulum-v0
# 29                 36000     0  octaves-6_pendulum-v0
# ...                  ...   ...                    ...
# 15970            1885200     9  octaves-6_pendulum-v0
# 15971            1886400     9  octaves-6_pendulum-v0
# 15972            1887600     9  octaves-6_pendulum-v0
# 15973            1888800     9  octaves-6_pendulum-v0
# 15974            1890000     9  octaves-6_pendulum-v0
# 15975            1891200     9  octaves-6_pendulum-v0
# 15976            1892400     9  octaves-6_pendulum-v0
# 15977            1893600     9  octaves-6_pendulum-v0
# 15978            1894800     9  octaves-6_pendulum-v0
# 15979            1896000     9  octaves-6_pendulum-v0
# 15980            1897200     9  octaves-6_pendulum-v0
# 15981            1898400     9  octaves-6_pendulum-v0
# 15982            1899600     9  octaves-6_pendulum-v0
# 15983            1900800     9  octaves-6_pendulum-v0
# 15984            1902000     9  octaves-6_pendulum-v0
# 15985            1903200     9  octaves-6_pendulum-v0
# 15986            1904400     9  octaves-6_pendulum-v0
# 15987            1905600     9  octaves-6_pendulum-v0
# 15988            1906800     9  octaves-6_pendulum-v0
# 15989            1908000     9  octaves-6_pendulum-v0
# 15990            1909200     9  octaves-6_pendulum-v0
# 15991            1910400     9  octaves-6_pendulum-v0
# 15992            1911600     9  octaves-6_pendulum-v0
# 15993            1912800     9  octaves-6_pendulum-v0
# 15994            1914000     9  octaves-6_pendulum-v0
# 15995            1915200     9  octaves-6_pendulum-v0
# 15996            1916400     9  octaves-6_pendulum-v0
# 15997            1917600     9  octaves-6_pendulum-v0
# 15998            1918800     9  octaves-6_pendulum-v0
# 15999            1920000     9  octaves-6_pendulum-v0
#
#                     Condition2  Performance
# 0      octaves-6_pendulum-v0-0  -1312.47730
# 1      octaves-6_pendulum-v0-0  -1306.82410
# 2      octaves-6_pendulum-v0-0  -1528.47360
# 3      octaves-6_pendulum-v0-0  -1359.65220
# 4      octaves-6_pendulum-v0-0  -1298.73490
# 5      octaves-6_pendulum-v0-0  -1332.35830
# 6      octaves-6_pendulum-v0-0  -1246.61770
# 7      octaves-6_pendulum-v0-0  -1267.82950
# 8      octaves-6_pendulum-v0-0  -1263.98570
# 9      octaves-6_pendulum-v0-0  -1195.04820
# 10     octaves-6_pendulum-v0-0  -1510.00890
# 11     octaves-6_pendulum-v0-0  -1185.01780
# 12     octaves-6_pendulum-v0-0  -1340.22420
# 13     octaves-6_pendulum-v0-0  -1379.16560
# 14     octaves-6_pendulum-v0-0  -1130.93070
# 15     octaves-6_pendulum-v0-0  -1201.81880
# 16     octaves-6_pendulum-v0-0  -1217.79150
# 17     octaves-6_pendulum-v0-0  -1218.07970
# 18     octaves-6_pendulum-v0-0  -1295.48690
# 19     octaves-6_pendulum-v0-0  -1111.85410
# 20     octaves-6_pendulum-v0-0  -1362.50300
# 21     octaves-6_pendulum-v0-0  -1190.80460
# 22     octaves-6_pendulum-v0-0  -1192.30870
# 23     octaves-6_pendulum-v0-0   -946.49660
# 24     octaves-6_pendulum-v0-0  -1031.11150
# 25     octaves-6_pendulum-v0-0  -1091.55500
# 26     octaves-6_pendulum-v0-0  -1200.24280
# 27     octaves-6_pendulum-v0-0  -1173.73050
# 28     octaves-6_pendulum-v0-0  -1123.42540
# 29     octaves-6_pendulum-v0-0  -1257.29800
# ...                        ...          ...
# 15970  octaves-6_pendulum-v0-9  -1105.53560
# 15971  octaves-6_pendulum-v0-9  -1067.75990
# 15972  octaves-6_pendulum-v0-9   -895.79755
# 15973  octaves-6_pendulum-v0-9  -1130.10390
# 15974  octaves-6_pendulum-v0-9   -997.94574
# 15975  octaves-6_pendulum-v0-9  -1115.52050
# 15976  octaves-6_pendulum-v0-9  -1085.67350
# 15977  octaves-6_pendulum-v0-9   -972.80390
# 15978  octaves-6_pendulum-v0-9  -1078.34510
# 15979  octaves-6_pendulum-v0-9  -1029.32040
# 15980  octaves-6_pendulum-v0-9  -1081.24760
# 15981  octaves-6_pendulum-v0-9   -924.32160
# 15982  octaves-6_pendulum-v0-9  -1143.61290
# 15983  octaves-6_pendulum-v0-9  -1090.33970
# 15984  octaves-6_pendulum-v0-9  -1009.73860
# 15985  octaves-6_pendulum-v0-9  -1032.31640
# 15986  octaves-6_pendulum-v0-9   -950.40870
# 15987  octaves-6_pendulum-v0-9   -988.57720
# 15988  octaves-6_pendulum-v0-9  -1047.73250
# 15989  octaves-6_pendulum-v0-9  -1056.82470
# 15990  octaves-6_pendulum-v0-9  -1083.46730
# 15991  octaves-6_pendulum-v0-9   -974.80470
# 15992  octaves-6_pendulum-v0-9  -1000.88450
# 15993  octaves-6_pendulum-v0-9  -1118.50230
# 15994  octaves-6_pendulum-v0-9  -1066.66490
# 15995  octaves-6_pendulum-v0-9  -1188.78040
# 15996  octaves-6_pendulum-v0-9   -911.22095
# 15997  octaves-6_pendulum-v0-9  -1049.82680
# 15998  octaves-6_pendulum-v0-9  -1070.91550
# 15999  octaves-6_pendulum-v0-9  -1055.06710
#
# [16000 rows x 18 columns]

# %%
# Show table of parameters used in the experiment, used as guide to graph legends

def config_values(config, paths):
    values = []
    for path in paths:
        value = config
        for name in path.split(':'):
            value = value[name]
        values.append(value)
    return values

columns = ['exp_name', 
           'steps_per_epoch',
#           'use_reward_discount',
           'goal_octaves', 
#            'goal_discount_rate', 
#           'no_step_reward', 
#           'finish_action_path_on_new_goal', 
#            'ac_kwargs:hidden_sizes', 
#            'ac_kwargs:activation', 
#            'inverse_kwargs:hidden_sizes', 
#            'inverse_kwargs:activation', 
#            'inverse_kwargs:goals_output_activation'
          ]

data = list(map(lambda config: config_values(config, columns), configs))
df = pd.DataFrame(data=data, columns=columns)
df.drop_duplicates()
# Out:
#                 exp_name  steps_per_epoch  goal_octaves
# 0  octaves-6_pendulum-v0             1200             4

# %%
plt.figure(figsize=(20, 15), dpi=150)

# To show individual runs, add arguments: units='Condition2, estimator=None
# To compare runs with different epoch lengts, use:xaxis='TotalEnvInteracts'

plot_data(datasets, smooth=5, condition='Condition2')
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityGoalError', smooth=1, show_legend=False, estimator='mean')
plt.show()
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityActionError', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalDiscount', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-469ac8f2fb4e> in <module>
#       1 plt.figure(figsize=(14, 8), dpi=150)
# ----> 2 plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
#       3 plt.show()
#
# ~/openaigym/spinningup/spinup/utils/plot.py in plot_data(data, xaxis, value, condition, smooth, show_legend, **kwargs)
#      32     sns.set(style="darkgrid", font_scale=1.5)
#      33     # sns.tsplot(data=data, time=xaxis, value=value, unit="Unit", condition=condition, ci='sd', **kwargs)
# ---> 34     sns.lineplot(data=data, x=xaxis, y=value, hue=condition, legend=show_legend, **kwargs)
#      35     """
#      36     If you upgrade to any version of Seaborn greater than 0.8.1, switch from
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend)
#     661
#     662         plot_data = self.establish_variables(
# --> 663             x, y, hue, size, style, units, data
#     664         )
#     665
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     140                 if isinstance(var, string_types):
#     141                     err = "Could not interpret input '{}'".format(var)
# --> 142                     raise ValueError(err)
#     143
#     144             # Extract variable names
#
# ValueError: Could not interpret input 'ActionsEntropy'

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalsEntropy', smooth=1, show_legend=False)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import os.path as osp
import numpy as np
from spinup.utils.plot import get_datasets, get_all_datasets, plot_data

# %%
datasets, configs = get_all_datasets(['/Users/ppiech/openaigym/spindata/octaves/'])

# Show a sample of the data
pd.concat(datasets, ignore_index=True)
# Out:
# Plotting from...
# ==================================================
#
# /Users/ppiech/openaigym/spindata/octaves/
#
# ==================================================
#        Epoch  AverageEpRet    StdEpRet  EpLen  GoalPathLen  StabilityReward  \
# 0          0   -1365.64800  106.242990  200.0     1.410557         0.284741
# 1          1   -1220.65930   29.293737  200.0     1.502740         0.381165
# 2          2   -1367.38230  199.003940  200.0     1.353846         0.454308
# 3          3   -1256.44010   59.623333  200.0     1.450490         0.488997
# 4          4   -1277.14660   73.180595  200.0     1.477250         0.514698
# 5          5   -1302.71250  232.744960  200.0     1.390361         0.496530
# 6          6   -1350.14010  233.650620  200.0     1.595443         0.546127
# 7          7   -1262.49870   77.041410  200.0     1.765836         0.611833
# 8          8   -1288.06380  219.113050  200.0     1.586880         0.519431
# 9          9   -1171.76670   84.055920  200.0     1.651507         0.459458
# 10        10   -1206.45140   77.831280  200.0     1.645473         0.614629
# 11        11   -1223.16370  220.746350  200.0     1.851175         0.639355
# 12        12   -1148.06050  113.817460  200.0     1.761806         0.644584
# 13        13   -1273.93910  127.836160  200.0     1.778238         0.635022
# 14        14   -1446.53610  211.902280  200.0     1.756450         0.625979
# 15        15   -1213.84190   90.459610  200.0     1.692621         0.617915
# 16        16   -1206.70740  299.478550  200.0     2.002641         0.654031
# 17        17   -1347.53660  242.456220  200.0     1.875263         0.640910
# 18        18   -1330.55710  268.447900  200.0     1.850660         0.669501
# 19        19   -1252.88760  302.349640  200.0     1.942297         0.650498
# 20        20   -1445.10680  290.202500  200.0     2.190776         0.634651
# 21        21   -1374.78370  229.453220  200.0     1.996275         0.641368
# 22        22   -1237.22170  296.284330  200.0     2.315703         0.642243
# 23        23   -1222.85030  240.608150  200.0     2.756368         0.627691
# 24        24   -1408.30680  298.829900  200.0     1.998935         0.632631
# 25        25   -1248.09770  289.822880  200.0     2.070734         0.588195
# 26        26   -1133.87760   60.576714  200.0     2.282320         0.641233
# 27        27   -1499.73110  299.841980  200.0     2.014965         0.644809
# 28        28   -1361.09630  366.621120  200.0     2.051513         0.640210
# 29        29   -1423.68460  248.420240  200.0     1.943760         0.645473
# ...      ...           ...         ...    ...          ...              ...
# 23883   1570    -976.54395   93.557310  200.0     5.520359         0.947078
# 23884   1571   -1059.60580  103.148500  200.0     5.443306         0.915234
# 23885   1572   -1078.99890   35.094456  200.0     5.386722         0.924019
# 23886   1573   -1101.53210   54.147410  200.0     5.188436         0.904211
# 23887   1574    -813.66130  377.907600  200.0     4.671027         0.937681
# 23888   1575    -926.40480  329.839360  200.0     5.229278         0.904987
# 23889   1576   -1010.00006  103.796590  200.0     5.643694         0.927247
# 23890   1577    -956.80840  137.007860  200.0     5.254929         0.921954
# 23891   1578   -1091.74120  121.152140  200.0     5.321601         0.910405
# 23892   1579    -866.34570  396.231080  200.0     4.717093         0.941963
# 23893   1580   -1000.63135   73.315140  200.0     5.713887         0.957456
# 23894   1581    -982.54376   92.768295  200.0     5.585450         0.957216
# 23895   1582    -720.43000  405.720100  200.0     4.236111         0.851133
# 23896   1583    -736.38070  393.663240  200.0     4.248412         0.901988
# 23897   1584    -821.49176  374.339260  200.0     4.198860         0.901306
# 23898   1585    -923.06180  223.629530  200.0     5.223561         0.942241
# 23899   1586   -1011.62250   82.403110  200.0     5.587312         0.935409
# 23900   1587    -887.43360   15.519827  200.0     5.664843         0.950207
# 23901   1588   -1080.17330  116.424060  200.0     5.357191         0.911184
# 23902   1589    -974.31396  168.360140  200.0     5.630969         0.935887
# 23903   1590    -811.73970  298.457180  200.0     4.727619         0.880387
# 23904   1591    -802.15700  397.735350  200.0     4.621039         0.904479
# 23905   1592    -849.42110  263.635770  200.0     5.092531         0.876542
# 23906   1593   -1069.76620  115.267410  200.0     5.741403         0.936940
# 23907   1594    -879.81150  375.740400  200.0     3.889513         0.814650
# 23908   1595    -917.33417  258.016940  200.0     4.856769         0.887059
# 23909   1596    -985.42975  162.099000  200.0     5.559838         0.940291
# 23910   1597   -1131.01090  125.621310  200.0     5.526316         0.935085
# 23911   1598    -929.47850  319.491240  200.0     5.235217         0.938626
# 23912   1599    -975.99220  328.552150  200.0     5.385486         0.933931
#
#        StabilityActionError  StabilityGoalError  ForwardPreictionError  \
# 0                  0.306994            0.759583               0.547088
# 1                  0.608216            0.664583               0.315458
# 2                  0.190485            0.555417               0.270873
# 3                  0.152470            0.514167               0.407518
# 4                  0.219493            0.474167               0.341177
# 5                  0.215312            0.497083               0.200498
# 6                  0.269829            0.439167               0.185371
# 7                  0.448261            0.360417               0.178223
# 8                  0.173909            0.470417               0.144001
# 9                  0.335352            0.538750               0.148016
# 10                 0.211035            0.355833               0.122414
# 11                 0.321821            0.332917               0.110078
# 12                 0.211380            0.325417               0.109664
# 13                 0.304765            0.333333               0.104016
# 14                 0.119877            0.345833               0.093799
# 15                 0.153009            0.358333               0.095928
# 16                 0.769513            0.283333               0.071801
# 17                 0.085028            0.335417               0.085923
# 18                 0.170520            0.297500               0.074168
# 19                 0.131452            0.321667               0.067968
# 20                 0.168752            0.335833               0.058755
# 21                 0.081641            0.345000               0.065789
# 22                 0.116400            0.335833               0.059007
# 23                 0.145613            0.336667               0.055766
# 24                 0.371983            0.353333               0.048232
# 25                 0.158070            0.392500               0.049894
# 26                 0.463409            0.324583               0.052015
# 27                 0.175722            0.315000               0.040237
# 28                 0.107527            0.322917               0.039464
# 29                 0.121241            0.317500               0.040699
# ...                     ...                 ...                    ...
# 23883              0.003078            0.050794               0.000153
# 23884              0.008875            0.082240               0.000560
# 23885              0.037226            0.072526               0.002205
# 23886              0.003881            0.095436               0.003669
# 23887              0.002553            0.060677               0.003025
# 23888              0.002629            0.093854               0.000703
# 23889              0.002617            0.071230               0.000361
# 23890              0.003862            0.075215               0.000232
# 23891              0.003054            0.088457               0.000119
# 23892              0.002823            0.055710               0.000051
# 23893              0.002225            0.040723               0.000023
# 23894              0.003418            0.040677               0.000012
# 23895              0.010880            0.142923               0.000016
# 23896              0.005277            0.094414               0.000015
# 23897              0.006122            0.093607               0.000011
# 23898              0.005293            0.053424               0.000012
# 23899              0.014114            0.058900               0.000013
# 23900              0.005450            0.044727               0.000008
# 23901              0.005317            0.084740               0.000008
# 23902              0.003004            0.062044               0.000015
# 23903              0.005285            0.115072               0.000010
# 23904              0.006856            0.090592               0.000011
# 23905              0.008422            0.116758               0.000007
# 23906              0.003542            0.060326               0.000017
# 23907              0.006777            0.179922               0.000023
# 23908              0.004447            0.110137               0.000008
# 23909              0.003173            0.057598               0.000009
# 23910              0.002491            0.063815               0.000016
# 23911              0.003198            0.059076               0.000008
# 23912              0.002926            0.064089               0.000009
#
#        GoalDiscount  RewardDiscount  GoalsStepReward  ActionsReward  \
# 0          0.356954        0.521850         0.249371      -6.469288
# 1          0.330040        0.484472         0.303841      -5.667916
# 2          0.344225        0.486529         0.276271      -6.384411
# 3          0.317367        0.469082         0.291009      -5.816892
# 4          0.301833        0.458664         0.300110      -5.873075
# 5          0.320599        0.450003         0.291537      -5.958775
# 6          0.312522        0.454487         0.347221      -6.129598
# 7          0.311755        0.461208         0.432869      -5.560804
# 8          0.353279        0.439611         0.388736      -5.747214
# 9          0.399451        0.396203         0.453815      -5.263286
# 10         0.349943        0.359534         0.425805      -5.224933
# 11         0.394604        0.310276         0.606477      -5.381261
# 12         0.391619        0.261224         0.593012      -4.932559
# 13         0.370232        0.228415         0.576169      -5.612304
# 14         0.374531        0.260314         0.542686      -6.529601
# 15         0.376800        0.276689         0.559632      -5.365252
# 16         0.465962        0.250747         0.902355      -5.241970
# 17         0.296020        0.258494         0.467336      -5.955439
# 18         0.373649        0.292352         0.592856      -5.800357
# 19         0.345404        0.279739         0.650857      -5.450142
# 20         0.384765        0.325233         0.996738      -6.615421
# 21         0.376703        0.388328         0.701797      -6.000809
# 22         0.358478        0.396242         0.917123      -5.347439
# 23         0.349399        0.363761         0.913478      -5.315307
# 24         0.385297        0.378849         0.686022      -6.291300
# 25         0.366999        0.380821         0.757514      -5.525322
# 26         0.331057        0.337162         0.712391      -4.715726
# 27         0.310114        0.377223         0.552974      -6.853809
# 28         0.292297        0.469788         0.538015      -6.043483
# 29         0.280459        0.496750         0.482653      -6.315271
# ...             ...             ...              ...            ...
# 23883      0.483388        0.015725         2.708141      -3.888539
# 23884      0.486787        0.020805         2.717943      -4.298196
# 23885      0.484799        0.016137         2.699738      -4.356050
# 23886      0.488936        0.020745         2.568262      -4.512611
# 23887      0.498270        0.016646         2.388440      -2.890589
# 23888      0.507079        0.019097         2.757828      -3.520628
# 23889      0.486446        0.017242         2.792094      -4.057075
# 23890      0.484989        0.020308         2.599120      -3.839768
# 23891      0.484615        0.020716         2.616300      -4.480692
# 23892      0.498250        0.015286         2.416819      -3.123009
# 23893      0.478468        0.015359         2.778924      -3.977541
# 23894      0.478888        0.015178         2.799070      -3.834600
# 23895      0.503968        0.027591         2.256456      -2.516786
# 23896      0.501209        0.020189         2.224359      -2.497161
# 23897      0.501797        0.016394         2.205648      -2.919950
# 23898      0.493181        0.018427         2.678857      -3.465993
# 23899      0.481841        0.017514         2.791376      -4.017669
# 23900      0.485206        0.014727         2.853908      -3.352768
# 23901      0.490191        0.020157         2.661261      -4.360248
# 23902      0.486213        0.017463         2.819862      -3.777952
# 23903      0.495170        0.016032         2.492973      -2.921181
# 23904      0.513953        0.018235         2.511017      -2.763127
# 23905      0.486084        0.014853         2.583424      -3.179312
# 23906      0.495572        0.022160         2.906026      -4.297421
# 23907      0.499839        0.028332         1.967025      -3.390747
# 23908      0.502278        0.022000         2.497928      -3.436833
# 23909      0.491230        0.020505         2.818796      -3.799671
# 23910      0.500191        0.021026         2.848240      -4.571741
# 23911      0.495022        0.018894         2.725964      -3.437370
# 23912      0.496858        0.016493         2.770994      -3.629001
#
#        TotalEnvInteracts  Unit                        Condition1  \
# 0                   1200     5  octaves_pendulum-v0_ste1200_goa2
# 1                   2400     5  octaves_pendulum-v0_ste1200_goa2
# 2                   3600     5  octaves_pendulum-v0_ste1200_goa2
# 3                   4800     5  octaves_pendulum-v0_ste1200_goa2
# 4                   6000     5  octaves_pendulum-v0_ste1200_goa2
# 5                   7200     5  octaves_pendulum-v0_ste1200_goa2
# 6                   8400     5  octaves_pendulum-v0_ste1200_goa2
# 7                   9600     5  octaves_pendulum-v0_ste1200_goa2
# 8                  10800     5  octaves_pendulum-v0_ste1200_goa2
# 9                  12000     5  octaves_pendulum-v0_ste1200_goa2
# 10                 13200     5  octaves_pendulum-v0_ste1200_goa2
# 11                 14400     5  octaves_pendulum-v0_ste1200_goa2
# 12                 15600     5  octaves_pendulum-v0_ste1200_goa2
# 13                 16800     5  octaves_pendulum-v0_ste1200_goa2
# 14                 18000     5  octaves_pendulum-v0_ste1200_goa2
# 15                 19200     5  octaves_pendulum-v0_ste1200_goa2
# 16                 20400     5  octaves_pendulum-v0_ste1200_goa2
# 17                 21600     5  octaves_pendulum-v0_ste1200_goa2
# 18                 22800     5  octaves_pendulum-v0_ste1200_goa2
# 19                 24000     5  octaves_pendulum-v0_ste1200_goa2
# 20                 25200     5  octaves_pendulum-v0_ste1200_goa2
# 21                 26400     5  octaves_pendulum-v0_ste1200_goa2
# 22                 27600     5  octaves_pendulum-v0_ste1200_goa2
# 23                 28800     5  octaves_pendulum-v0_ste1200_goa2
# 24                 30000     5  octaves_pendulum-v0_ste1200_goa2
# 25                 31200     5  octaves_pendulum-v0_ste1200_goa2
# 26                 32400     5  octaves_pendulum-v0_ste1200_goa2
# 27                 33600     5  octaves_pendulum-v0_ste1200_goa2
# 28                 34800     5  octaves_pendulum-v0_ste1200_goa2
# 29                 36000     5  octaves_pendulum-v0_ste1200_goa2
# ...                  ...   ...                               ...
# 23883            1885200     9               octaves_pendulum-v0
# 23884            1886400     9               octaves_pendulum-v0
# 23885            1887600     9               octaves_pendulum-v0
# 23886            1888800     9               octaves_pendulum-v0
# 23887            1890000     9               octaves_pendulum-v0
# 23888            1891200     9               octaves_pendulum-v0
# 23889            1892400     9               octaves_pendulum-v0
# 23890            1893600     9               octaves_pendulum-v0
# 23891            1894800     9               octaves_pendulum-v0
# 23892            1896000     9               octaves_pendulum-v0
# 23893            1897200     9               octaves_pendulum-v0
# 23894            1898400     9               octaves_pendulum-v0
# 23895            1899600     9               octaves_pendulum-v0
# 23896            1900800     9               octaves_pendulum-v0
# 23897            1902000     9               octaves_pendulum-v0
# 23898            1903200     9               octaves_pendulum-v0
# 23899            1904400     9               octaves_pendulum-v0
# 23900            1905600     9               octaves_pendulum-v0
# 23901            1906800     9               octaves_pendulum-v0
# 23902            1908000     9               octaves_pendulum-v0
# 23903            1909200     9               octaves_pendulum-v0
# 23904            1910400     9               octaves_pendulum-v0
# 23905            1911600     9               octaves_pendulum-v0
# 23906            1912800     9               octaves_pendulum-v0
# 23907            1914000     9               octaves_pendulum-v0
# 23908            1915200     9               octaves_pendulum-v0
# 23909            1916400     9               octaves_pendulum-v0
# 23910            1917600     9               octaves_pendulum-v0
# 23911            1918800     9               octaves_pendulum-v0
# 23912            1920000     9               octaves_pendulum-v0
#
#                                 Condition2  Performance
# 0      octaves_pendulum-v0_ste1200_goa2-41  -1365.64800
# 1      octaves_pendulum-v0_ste1200_goa2-41  -1220.65930
# 2      octaves_pendulum-v0_ste1200_goa2-41  -1367.38230
# 3      octaves_pendulum-v0_ste1200_goa2-41  -1256.44010
# 4      octaves_pendulum-v0_ste1200_goa2-41  -1277.14660
# 5      octaves_pendulum-v0_ste1200_goa2-41  -1302.71250
# 6      octaves_pendulum-v0_ste1200_goa2-41  -1350.14010
# 7      octaves_pendulum-v0_ste1200_goa2-41  -1262.49870
# 8      octaves_pendulum-v0_ste1200_goa2-41  -1288.06380
# 9      octaves_pendulum-v0_ste1200_goa2-41  -1171.76670
# 10     octaves_pendulum-v0_ste1200_goa2-41  -1206.45140
# 11     octaves_pendulum-v0_ste1200_goa2-41  -1223.16370
# 12     octaves_pendulum-v0_ste1200_goa2-41  -1148.06050
# 13     octaves_pendulum-v0_ste1200_goa2-41  -1273.93910
# 14     octaves_pendulum-v0_ste1200_goa2-41  -1446.53610
# 15     octaves_pendulum-v0_ste1200_goa2-41  -1213.84190
# 16     octaves_pendulum-v0_ste1200_goa2-41  -1206.70740
# 17     octaves_pendulum-v0_ste1200_goa2-41  -1347.53660
# 18     octaves_pendulum-v0_ste1200_goa2-41  -1330.55710
# 19     octaves_pendulum-v0_ste1200_goa2-41  -1252.88760
# 20     octaves_pendulum-v0_ste1200_goa2-41  -1445.10680
# 21     octaves_pendulum-v0_ste1200_goa2-41  -1374.78370
# 22     octaves_pendulum-v0_ste1200_goa2-41  -1237.22170
# 23     octaves_pendulum-v0_ste1200_goa2-41  -1222.85030
# 24     octaves_pendulum-v0_ste1200_goa2-41  -1408.30680
# 25     octaves_pendulum-v0_ste1200_goa2-41  -1248.09770
# 26     octaves_pendulum-v0_ste1200_goa2-41  -1133.87760
# 27     octaves_pendulum-v0_ste1200_goa2-41  -1499.73110
# 28     octaves_pendulum-v0_ste1200_goa2-41  -1361.09630
# 29     octaves_pendulum-v0_ste1200_goa2-41  -1423.68460
# ...                                    ...          ...
# 23883               octaves_pendulum-v0-73   -976.54395
# 23884               octaves_pendulum-v0-73  -1059.60580
# 23885               octaves_pendulum-v0-73  -1078.99890
# 23886               octaves_pendulum-v0-73  -1101.53210
# 23887               octaves_pendulum-v0-73   -813.66130
# 23888               octaves_pendulum-v0-73   -926.40480
# 23889               octaves_pendulum-v0-73  -1010.00006
# 23890               octaves_pendulum-v0-73   -956.80840
# 23891               octaves_pendulum-v0-73  -1091.74120
# 23892               octaves_pendulum-v0-73   -866.34570
# 23893               octaves_pendulum-v0-73  -1000.63135
# 23894               octaves_pendulum-v0-73   -982.54376
# 23895               octaves_pendulum-v0-73   -720.43000
# 23896               octaves_pendulum-v0-73   -736.38070
# 23897               octaves_pendulum-v0-73   -821.49176
# 23898               octaves_pendulum-v0-73   -923.06180
# 23899               octaves_pendulum-v0-73  -1011.62250
# 23900               octaves_pendulum-v0-73   -887.43360
# 23901               octaves_pendulum-v0-73  -1080.17330
# 23902               octaves_pendulum-v0-73   -974.31396
# 23903               octaves_pendulum-v0-73   -811.73970
# 23904               octaves_pendulum-v0-73   -802.15700
# 23905               octaves_pendulum-v0-73   -849.42110
# 23906               octaves_pendulum-v0-73  -1069.76620
# 23907               octaves_pendulum-v0-73   -879.81150
# 23908               octaves_pendulum-v0-73   -917.33417
# 23909               octaves_pendulum-v0-73   -985.42975
# 23910               octaves_pendulum-v0-73  -1131.01090
# 23911               octaves_pendulum-v0-73   -929.47850
# 23912               octaves_pendulum-v0-73   -975.99220
#
# [23913 rows x 18 columns]

# %%
# Show table of parameters used in the experiment, used as guide to graph legends

def config_values(config, paths):
    values = []
    for path in paths:
        value = config
        for name in path.split(':'):
            value = value[name]
        values.append(value)
    return values

columns = ['exp_name', 
           'steps_per_epoch',
#           'use_reward_discount',
           'goal_octaves', 
#            'goal_discount_rate', 
#           'no_step_reward', 
#           'finish_action_path_on_new_goal', 
#            'ac_kwargs:hidden_sizes', 
#            'ac_kwargs:activation', 
#            'inverse_kwargs:hidden_sizes', 
#            'inverse_kwargs:activation', 
#            'inverse_kwargs:goals_output_activation'
          ]

data = list(map(lambda config: config_values(config, columns), configs))
df = pd.DataFrame(data=data, columns=columns)
df.drop_duplicates()
# Out:
#                             exp_name  steps_per_epoch  goal_octaves
# 0   octaves_pendulum-v0_ste1200_goa2             1200             2
# 5   octaves_pendulum-v0_ste1200_goa4             1200             4
# 10  octaves_pendulum-v0_ste4800_goa6             4800             6
# 14  octaves_pendulum-v0_ste4800_goa2             4800             2
# 19  octaves_pendulum-v0_ste4800_goa4             4800             4
# 23             octaves-6_pendulum-v0             1200             6
# 28               octaves_pendulum-v0             1200             8

# %%
plt.figure(figsize=(20, 15), dpi=150)

# To show individual runs, add arguments: units='Condition2, estimator=None
# To compare runs with different epoch lengts, use:xaxis='TotalEnvInteracts'

plot_data(datasets, smooth=5, xaxis='TotalEnvInteracts')
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityGoalError', smooth=1, show_legend=False, estimator='mean')
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityActionError', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalDiscount', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalsEntropy', smooth=1, show_legend=False)
plt.show()

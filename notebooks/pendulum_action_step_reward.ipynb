# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import os.path as osp
import numpy as np
from spinup.utils.plot import get_datasets, get_all_datasets, plot_data
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
datasets, configs = get_all_datasets(['/Users/ppiech/openaigym/spindata/action_step_reward/'])

# Show a sample of the data
pd.concat(datasets, ignore_index=True)
# Out:
# Plotting from...
# ==================================================
#
# /Users/ppiech/openaigym/spindata/action_step_reward/
#
# ==================================================
#       Epoch  AverageEpRet   StdEpRet  EpLen  GoalPathLen  StabilityReward  \
# 0         0   -1209.13880  282.07416  200.0     1.018975         0.351017
# 1         1   -1315.25650  263.87582  200.0     1.017699         0.357714
# 2         2   -1272.75430  312.27110  200.0     1.023669         0.332308
# 3         3   -1448.40900  325.64624  200.0     1.017274         0.313848
# 4         4   -1296.96090  277.81314  200.0     1.020464         0.299281
# 5         5   -1288.89390  218.51810  200.0     1.024524         0.291538
# 6         6   -1500.04900  335.69818  200.0     1.020038         0.251566
# 7         7   -1138.53080  274.45554  200.0     1.021744         0.318641
# 8         8   -1271.67540  356.96980  200.0     1.023241         0.292793
# 9         9   -1348.81460  329.33688  200.0     1.030085         0.297340
# 10       10   -1404.12550  298.06800  200.0     1.030740         0.277971
# 11       11   -1424.68260  276.44427  200.0     1.032895         0.270118
# 12       12   -1320.11230  266.04926  200.0     1.033737         0.314066
# 13       13   -1331.17080  304.00146  200.0     1.031396         0.286033
# 14       14   -1420.02150  148.01505  200.0     1.028378         0.293772
# 15       15   -1354.56410  221.28860  200.0     1.030740         0.315810
# 16       16   -1295.14840  299.06354  200.0     1.045454         0.324487
# 17       17   -1201.01800  243.93715  200.0     1.048963         0.359969
# 18       18   -1288.23990  359.85483  200.0     1.037644         0.305791
# 19       19   -1297.57420  327.66350  200.0     1.036541         0.307210
# 20       20   -1304.98250  348.94710  200.0     1.040868         0.307333
# 21       21   -1292.94580  285.46143  200.0     1.046765         0.339791
# 22       22   -1393.08640  344.91140  200.0     1.045445         0.318554
# 23       23   -1302.10410  227.43547  200.0     1.049818         0.337245
# 24       24   -1206.96890  373.38278  200.0     1.056867         0.339237
# 25       25   -1171.13230  301.98578  200.0     1.084309         0.347233
# 26       26   -1256.18080  359.21298  200.0     1.075777         0.347927
# 27       27   -1148.68770  248.76318  200.0     1.072786         0.356476
# 28       28   -1301.50010  238.22089  200.0     1.073914         0.338090
# 29       29   -1298.78040  236.84453  200.0     1.073371         0.332335
# ...     ...           ...        ...    ...          ...              ...
# 4529    370    -639.90405  377.94920  200.0    20.526619         0.832643
# 4530    371    -488.37344  306.27026  200.0    16.309477         0.885826
# 4531    372    -619.02080  246.93744  200.0    13.395364         0.832424
# 4532    373    -373.66160  299.47742  200.0    20.674267         0.868175
# 4533    374    -567.29250  373.34628  200.0    18.558863         0.865130
# 4534    375    -488.79004  394.96466  200.0    26.323140         0.870442
# 4535    376    -548.76190  409.65347  200.0    24.538360         0.852294
# 4536    377    -620.24194  396.89750  200.0    21.521461         0.857811
# 4537    378    -575.50494  359.89642  200.0    12.168030         0.856287
# 4538    379    -625.03930  335.96423  200.0    12.773469         0.843189
# 4539    380    -612.04297  315.24838  200.0    16.019747         0.873682
# 4540    381    -348.00015  321.02914  200.0    39.991817         0.904131
# 4541    382    -503.67764  372.34940  200.0    25.209726         0.864644
# 4542    383    -417.24905  261.13855  200.0    23.092152         0.869115
# 4543    384    -443.14835  309.19812  200.0    17.746958         0.854165
# 4544    385    -562.02510  336.92563  200.0    22.765130         0.849974
# 4545    386    -473.68400  300.96283  200.0    17.713780         0.864951
# 4546    387    -480.22485  331.85892  200.0    25.506777         0.850570
# 4547    388    -409.30606  349.26453  200.0    22.859590         0.861859
# 4548    389    -460.50920  242.44273  200.0    22.935398         0.849392
# 4549    390    -486.83353  420.95910  200.0    18.838013         0.865121
# 4550    391    -494.86185  360.76328  200.0    20.528801         0.882538
# 4551    392    -680.06464  322.33707  200.0    16.451840         0.855472
# 4552    393    -459.99545  348.22867  200.0    30.670712         0.903009
# 4553    394    -523.16900  358.83707  200.0    22.549118         0.878332
# 4554    395    -398.32602  345.14047  200.0    36.512882         0.890740
# 4555    396    -274.35318  259.24933  200.0    35.806244         0.917073
# 4556    397    -568.20640  359.85600  200.0    21.064379         0.837093
# 4557    398    -793.38590  307.12344  200.0     8.839440         0.779771
# 4558    399    -555.36346  428.97925  200.0    25.965336         0.849363
#
#       StabilityActionError  StabilityGoalError  ForwardPreictionError  \
# 0                 0.451114            0.716979               0.269440
# 1                 0.352145            0.709987               0.224259
# 2                 0.255228            0.721992               0.202907
# 3                 0.305218            0.766445               0.169943
# 4                 0.250758            0.777930               0.163181
# 5                 0.223199            0.787669               0.143217
# 6                 0.192594            0.830898               0.115349
# 7                 0.427635            0.739036               0.135096
# 8                 0.332471            0.766003               0.115625
# 9                 0.297418            0.772474               0.103675
# 10                0.187607            0.792891               0.088190
# 11                0.426745            0.794284               0.075050
# 12                0.204267            0.735547               0.083523
# 13                0.255826            0.776536               0.072906
# 14                0.199088            0.771771               0.052739
# 15                0.178779            0.739076               0.055337
# 16                0.168075            0.722682               0.061725
# 17                0.156874            0.678802               0.070519
# 18                0.202126            0.745898               0.061081
# 19                0.141082            0.734831               0.056409
# 20                0.125924            0.745378               0.054642
# 21                0.127587            0.700091               0.048905
# 22                0.135013            0.724180               0.042766
# 23                0.118048            0.700625               0.037469
# 24                0.112486            0.696562               0.040145
# 25                0.183419            0.687031               0.040823
# 26                0.131190            0.681146               0.035738
# 27                0.112818            0.677617               0.032670
# 28                0.090117            0.688190               0.028465
# 29                0.202948            0.690417               0.026550
# ...                    ...                 ...                    ...
# 4529              0.002368            0.167370               0.000901
# 4530              0.002076            0.113164               0.000922
# 4531              0.001798            0.167435               0.001140
# 4532              0.001439            0.131380               0.000923
# 4533              0.029354            0.135013               0.001037
# 4534              0.001695            0.129297               0.000736
# 4535              0.007021            0.147474               0.000965
# 4536              0.002056            0.141081               0.001093
# 4537              0.002988            0.142487               0.001132
# 4538              0.002434            0.155599               0.000921
# 4539              0.002113            0.125443               0.001019
# 4540              0.001132            0.095273               0.000709
# 4541              0.001549            0.134635               0.000779
# 4542              0.001609            0.130182               0.000688
# 4543              0.002680            0.146068               0.000713
# 4544              0.003376            0.149062               0.000798
# 4545              0.001528            0.134766               0.000823
# 4546              0.001733            0.149362               0.000613
# 4547              0.001668            0.138320               0.000702
# 4548              0.001603            0.150703               0.000640
# 4549              0.002875            0.134701               0.000746
# 4550              0.001579            0.117161               0.000793
# 4551              0.002174            0.144206               0.000806
# 4552              0.003116            0.096745               0.000629
# 4553              0.003074            0.120898               0.000971
# 4554              0.007900            0.109909               0.000628
# 4555              0.000941            0.082643               0.000490
# 4556              0.002061            0.162695               0.001052
# 4557              0.003795            0.219492               0.001541
# 4558              0.001916            0.150286               0.000946
#
#       GoalDiscount     ...       ActionsClipFrac  ActionsStopIter  \
# 0         0.482715     ...              0.081667             79.0
# 1         0.476836     ...              0.105000             79.0
# 2         0.482472     ...              0.108750             79.0
# 3         0.479987     ...              0.128333             79.0
# 4         0.481045     ...              0.130000             79.0
# 5         0.470902     ...              0.116250             79.0
# 6         0.476987     ...              0.129167             79.0
# 7         0.456151     ...              0.141667             79.0
# 8         0.448359     ...              0.126250             79.0
# 9         0.451342     ...              0.140000             79.0
# 10        0.460075     ...              0.137500             79.0
# 11        0.456156     ...              0.151667             61.0
# 12        0.451311     ...              0.137500             79.0
# 13        0.449694     ...              0.156250             79.0
# 14        0.441462     ...              0.126250             37.0
# 15        0.438207     ...              0.167500             79.0
# 16        0.432139     ...              0.166250             79.0
# 17        0.429102     ...              0.157083             79.0
# 18        0.463627     ...              0.122500             79.0
# 19        0.458627     ...              0.135417             79.0
# 20        0.461239     ...              0.150417             79.0
# 21        0.432368     ...              0.145833             79.0
# 22        0.444701     ...              0.179167             79.0
# 23        0.431154     ...              0.145417             79.0
# 24        0.433148     ...              0.151250             79.0
# 25        0.431810     ...              0.125000             79.0
# 26        0.451660     ...              0.139167             79.0
# 27        0.438725     ...              0.134167             79.0
# 28        0.432701     ...              0.165417             79.0
# 29        0.427973     ...              0.156250             79.0
# ...            ...     ...                   ...              ...
# 4529      0.492188     ...              0.123750              5.0
# 4530      0.492188     ...              0.153333             79.0
# 4531      0.492188     ...              0.153750              6.0
# 4532      0.492188     ...              0.189583              3.0
# 4533      0.492188     ...              0.167917             79.0
# 4534      0.492188     ...              0.109167              4.0
# 4535      0.492188     ...              0.082917              7.0
# 4536      0.492188     ...              0.130417              4.0
# 4537      0.492188     ...              0.143333             79.0
# 4538      0.492188     ...              0.120000              3.0
# 4539      0.492188     ...              0.144167              7.0
# 4540      0.492188     ...              0.194167              2.0
# 4541      0.492188     ...              0.135417             79.0
# 4542      0.492188     ...              0.097917              6.0
# 4543      0.492188     ...              0.024583              1.0
# 4544      0.492188     ...              0.271667              4.0
# 4545      0.492188     ...              0.202917             13.0
# 4546      0.492188     ...              0.120000              4.0
# 4547      0.492188     ...              0.108333              2.0
# 4548      0.492188     ...              0.112083              7.0
# 4549      0.492188     ...              0.157500              7.0
# 4550      0.492188     ...              0.076250              6.0
# 4551      0.492188     ...              0.121250              6.0
# 4552      0.492188     ...              0.082500              5.0
# 4553      0.492188     ...              0.090000              7.0
# 4554      0.492188     ...              0.120417              5.0
# 4555      0.492188     ...              0.051250              1.0
# 4556      0.492188     ...              0.069167              1.0
# 4557      0.492188     ...              0.153750              4.0
# 4558      0.492188     ...              0.119167              5.0
#
#       LossActionInverse  DeltaLossActionInverse  LossGoalInverse  \
# 0              0.425399               -0.520111         0.206576
# 1              0.402674               -0.038755         0.161238
# 2              0.390574               -0.011062         0.126436
# 3              0.377552               -0.007796         0.118852
# 4              0.365797               -0.013225         0.086716
# 5              0.343339               -0.024565         0.069875
# 6              0.364535                0.000718         0.082227
# 7              0.338711               -0.020277         0.052215
# 8              0.325391               -0.025631         0.052572
# 9              0.331667               -0.013623         0.048225
# 10             0.335889               -0.005992         0.043207
# 11             0.325492               -0.011315         0.037918
# 12             0.348423                0.012208         0.032336
# 13             0.339569                0.000686         0.032091
# 14             0.355770                0.012292         0.026023
# 15             0.325877               -0.013152         0.025074
# 16             0.318935               -0.012425         0.025590
# 17             0.310195               -0.009689         0.025033
# 18             0.287950               -0.017972         0.025616
# 19             0.292422               -0.005588         0.023968
# 20             0.269017               -0.017509         0.023520
# 21             0.266088               -0.013544         0.021394
# 22             0.269861               -0.005830         0.020541
# 23             0.244147               -0.015674         0.019085
# 24             0.232747               -0.013424         0.022409
# 25             0.209896               -0.019770         0.020891
# 26             0.203557               -0.013431         0.019905
# 27             0.190660               -0.013107         0.019662
# 28             0.189469               -0.004167         0.017797
# 29             0.163911               -0.015113         0.017276
# ...                 ...                     ...              ...
# 4529           0.001449                0.000175         0.004812
# 4530           0.001484                0.000180         0.003671
# 4531           0.001497                0.000161         0.004922
# 4532           0.000915               -0.000253         0.003863
# 4533           0.001645                0.000328         0.004178
# 4534           0.001284               -0.000002         0.003744
# 4535           0.001839                0.000439         0.004149
# 4536           0.002288                0.000600         0.004529
# 4537           0.001346               -0.000243         0.004683
# 4538           0.001477               -0.000049         0.005159
# 4539           0.001976                0.000322         0.004316
# 4540           0.001656                0.000032         0.002671
# 4541           0.001343               -0.000265         0.003945
# 4542           0.001946                0.000345         0.003893
# 4543           0.002263                0.000453         0.004165
# 4544           0.002294                0.000322         0.004083
# 4545           0.002950                0.000666         0.004004
# 4546           0.001372               -0.000696         0.003907
# 4547           0.001709               -0.000306         0.004031
# 4548           0.001805               -0.000124         0.003791
# 4549           0.002627                0.000572         0.004103
# 4550           0.001580               -0.000386         0.003595
# 4551           0.001975               -0.000033         0.004704
# 4552           0.001974                0.000032         0.003517
# 4553           0.002152                0.000176         0.003963
# 4554           0.001510               -0.000378         0.003230
# 4555           0.001272               -0.000538         0.002552
# 4556           0.002509                0.000411         0.004484
# 4557           0.003079                0.000684         0.005895
# 4558           0.003231                0.000753         0.004076
#
#       DeltaLossGoalInverse  Unit                       Condition1  \
# 0                -0.068835     0   no_path_len_reward_pendulum-v0
# 1                -0.045217     0   no_path_len_reward_pendulum-v0
# 2                -0.033010     0   no_path_len_reward_pendulum-v0
# 3                -0.011704     0   no_path_len_reward_pendulum-v0
# 4                -0.019010     0   no_path_len_reward_pendulum-v0
# 5                -0.016270     0   no_path_len_reward_pendulum-v0
# 6                 0.002637     0   no_path_len_reward_pendulum-v0
# 7                -0.013403     0   no_path_len_reward_pendulum-v0
# 8                -0.005490     0   no_path_len_reward_pendulum-v0
# 9                -0.004244     0   no_path_len_reward_pendulum-v0
# 10               -0.004305     0   no_path_len_reward_pendulum-v0
# 11               -0.004483     0   no_path_len_reward_pendulum-v0
# 12               -0.004928     0   no_path_len_reward_pendulum-v0
# 13               -0.002134     0   no_path_len_reward_pendulum-v0
# 14               -0.004458     0   no_path_len_reward_pendulum-v0
# 15               -0.002919     0   no_path_len_reward_pendulum-v0
# 16               -0.000899     0   no_path_len_reward_pendulum-v0
# 17               -0.000248     0   no_path_len_reward_pendulum-v0
# 18                0.000647     0   no_path_len_reward_pendulum-v0
# 19               -0.000268     0   no_path_len_reward_pendulum-v0
# 20               -0.000098     0   no_path_len_reward_pendulum-v0
# 21               -0.001160     0   no_path_len_reward_pendulum-v0
# 22               -0.001092     0   no_path_len_reward_pendulum-v0
# 23               -0.001450     0   no_path_len_reward_pendulum-v0
# 24                0.001458     0   no_path_len_reward_pendulum-v0
# 25                0.000141     0   no_path_len_reward_pendulum-v0
# 26               -0.000430     0   no_path_len_reward_pendulum-v0
# 27               -0.000365     0   no_path_len_reward_pendulum-v0
# 28               -0.001310     0   no_path_len_reward_pendulum-v0
# 29               -0.001121     0   no_path_len_reward_pendulum-v0
# ...                    ...   ...                              ...
# 4529              0.000756     4  actions-step-reward_pendulum-v0
# 4530             -0.000286     4  actions-step-reward_pendulum-v0
# 4531              0.000692     4  actions-step-reward_pendulum-v0
# 4532             -0.000276     4  actions-step-reward_pendulum-v0
# 4533              0.000027     4  actions-step-reward_pendulum-v0
# 4534             -0.000279     4  actions-step-reward_pendulum-v0
# 4535              0.000084     4  actions-step-reward_pendulum-v0
# 4536              0.000310     4  actions-step-reward_pendulum-v0
# 4537              0.000365     4  actions-step-reward_pendulum-v0
# 4538              0.000631     4  actions-step-reward_pendulum-v0
# 4539             -0.000135     4  actions-step-reward_pendulum-v0
# 4540             -0.001287     4  actions-step-reward_pendulum-v0
# 4541             -0.000001     4  actions-step-reward_pendulum-v0
# 4542             -0.000020     4  actions-step-reward_pendulum-v0
# 4543              0.000214     4  actions-step-reward_pendulum-v0
# 4544              0.000073     4  actions-step-reward_pendulum-v0
# 4545             -0.000007     4  actions-step-reward_pendulum-v0
# 4546             -0.000102     4  actions-step-reward_pendulum-v0
# 4547              0.000032     4  actions-step-reward_pendulum-v0
# 4548             -0.000162     4  actions-step-reward_pendulum-v0
# 4549              0.000130     4  actions-step-reward_pendulum-v0
# 4550             -0.000258     4  actions-step-reward_pendulum-v0
# 4551              0.000617     4  actions-step-reward_pendulum-v0
# 4552             -0.000418     4  actions-step-reward_pendulum-v0
# 4553              0.000017     4  actions-step-reward_pendulum-v0
# 4554             -0.000516     4  actions-step-reward_pendulum-v0
# 4555             -0.000835     4  actions-step-reward_pendulum-v0
# 4556              0.000756     4  actions-step-reward_pendulum-v0
# 4557              0.001539     4  actions-step-reward_pendulum-v0
# 4558             -0.000149     4  actions-step-reward_pendulum-v0
#
#                               Condition2  Performance
# 0       no_path_len_reward_pendulum-v0-0  -1209.13880
# 1       no_path_len_reward_pendulum-v0-0  -1315.25650
# 2       no_path_len_reward_pendulum-v0-0  -1272.75430
# 3       no_path_len_reward_pendulum-v0-0  -1448.40900
# 4       no_path_len_reward_pendulum-v0-0  -1296.96090
# 5       no_path_len_reward_pendulum-v0-0  -1288.89390
# 6       no_path_len_reward_pendulum-v0-0  -1500.04900
# 7       no_path_len_reward_pendulum-v0-0  -1138.53080
# 8       no_path_len_reward_pendulum-v0-0  -1271.67540
# 9       no_path_len_reward_pendulum-v0-0  -1348.81460
# 10      no_path_len_reward_pendulum-v0-0  -1404.12550
# 11      no_path_len_reward_pendulum-v0-0  -1424.68260
# 12      no_path_len_reward_pendulum-v0-0  -1320.11230
# 13      no_path_len_reward_pendulum-v0-0  -1331.17080
# 14      no_path_len_reward_pendulum-v0-0  -1420.02150
# 15      no_path_len_reward_pendulum-v0-0  -1354.56410
# 16      no_path_len_reward_pendulum-v0-0  -1295.14840
# 17      no_path_len_reward_pendulum-v0-0  -1201.01800
# 18      no_path_len_reward_pendulum-v0-0  -1288.23990
# 19      no_path_len_reward_pendulum-v0-0  -1297.57420
# 20      no_path_len_reward_pendulum-v0-0  -1304.98250
# 21      no_path_len_reward_pendulum-v0-0  -1292.94580
# 22      no_path_len_reward_pendulum-v0-0  -1393.08640
# 23      no_path_len_reward_pendulum-v0-0  -1302.10410
# 24      no_path_len_reward_pendulum-v0-0  -1206.96890
# 25      no_path_len_reward_pendulum-v0-0  -1171.13230
# 26      no_path_len_reward_pendulum-v0-0  -1256.18080
# 27      no_path_len_reward_pendulum-v0-0  -1148.68770
# 28      no_path_len_reward_pendulum-v0-0  -1301.50010
# 29      no_path_len_reward_pendulum-v0-0  -1298.78040
# ...                                  ...          ...
# 4529  actions-step-reward_pendulum-v0-12   -639.90405
# 4530  actions-step-reward_pendulum-v0-12   -488.37344
# 4531  actions-step-reward_pendulum-v0-12   -619.02080
# 4532  actions-step-reward_pendulum-v0-12   -373.66160
# 4533  actions-step-reward_pendulum-v0-12   -567.29250
# 4534  actions-step-reward_pendulum-v0-12   -488.79004
# 4535  actions-step-reward_pendulum-v0-12   -548.76190
# 4536  actions-step-reward_pendulum-v0-12   -620.24194
# 4537  actions-step-reward_pendulum-v0-12   -575.50494
# 4538  actions-step-reward_pendulum-v0-12   -625.03930
# 4539  actions-step-reward_pendulum-v0-12   -612.04297
# 4540  actions-step-reward_pendulum-v0-12   -348.00015
# 4541  actions-step-reward_pendulum-v0-12   -503.67764
# 4542  actions-step-reward_pendulum-v0-12   -417.24905
# 4543  actions-step-reward_pendulum-v0-12   -443.14835
# 4544  actions-step-reward_pendulum-v0-12   -562.02510
# 4545  actions-step-reward_pendulum-v0-12   -473.68400
# 4546  actions-step-reward_pendulum-v0-12   -480.22485
# 4547  actions-step-reward_pendulum-v0-12   -409.30606
# 4548  actions-step-reward_pendulum-v0-12   -460.50920
# 4549  actions-step-reward_pendulum-v0-12   -486.83353
# 4550  actions-step-reward_pendulum-v0-12   -494.86185
# 4551  actions-step-reward_pendulum-v0-12   -680.06464
# 4552  actions-step-reward_pendulum-v0-12   -459.99545
# 4553  actions-step-reward_pendulum-v0-12   -523.16900
# 4554  actions-step-reward_pendulum-v0-12   -398.32602
# 4555  actions-step-reward_pendulum-v0-12   -274.35318
# 4556  actions-step-reward_pendulum-v0-12   -568.20640
# 4557  actions-step-reward_pendulum-v0-12   -793.38590
# 4558  actions-step-reward_pendulum-v0-12   -555.36346
#
# [4559 rows x 42 columns]

# %%
# Show table of parameters used in the experiment, used as guide to graph legends

def config_values(config, paths):
    values = []
    for path in paths:
        value = config
        for name in path.split(':'):
            value = value[name]
        values.append(value)
    return values

columns = ['exp_name', 
           'steps_per_epoch',
#           'use_reward_discount',
           'goal_octaves', 
#           'goal_discount_rate', 
#           'inverse_buffer_size',
#           'no_step_reward', 
           'actions_step_reward',  
#           'finish_action_path_on_new_goal', 
#            'ac_kwargs:hidden_sizes', 
#            'ac_kwargs:activation', 
#            'inverse_kwargs:hidden_sizes', 
#            'inverse_kwargs:activation', 
#            'inverse_kwargs:goals_output_activation'
          ]

data = list(map(lambda config: config_values(config, columns), configs))
df = pd.DataFrame(data=data, columns=columns)
df.drop_duplicates()
# Out:
#                            exp_name  steps_per_epoch  goal_octaves  \
# 0    no_path_len_reward_pendulum-v0             2400             6
# 1  actions-step-reward_pendulum-v0_             2400             6
# 7       no-step-reward_pendulum-v0_             4800             6
# 8   actions-step-reward_pendulum-v0             2400             6
#
#    actions_step_reward
# 0                 True
# 1                 True
# 7                False
# 8                False

# %%
plt.figure(figsize=(20, 15), dpi=150)

# To show individual runs, add arguments: units='Condition2, estimator=None
# To compare runs with different epoch lengts, use:xaxis='TotalEnvInteracts'

plot_data(datasets, smooth=5, xaxis='TotalEnvInteracts')
plt.show()
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityGoalError', smooth=1, show_legend=False, estimator='mean')
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityActionError', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalDiscount', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalsEntropy', smooth=1, show_legend=False)
plt.show()

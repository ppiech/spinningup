# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import os.path as osp
import numpy as np
from spinup.utils.plot import get_datasets, get_all_datasets, plot_data
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
datasets, configs = get_all_datasets(['/Users/ppiech/openaigym/spindata/discounts/'])

# Show a sample of the data
pd.concat(datasets, ignore_index=True)
# Out:
# Plotting from...
# ==================================================
#
# /Users/ppiech/openaigym/spindata/discounts/
#
# ==================================================
#        Epoch  AverageEpRet    StdEpRet  EpLen  GoalPathLen  StabilityReward  \
# 0          0   -1347.92070  181.248830  200.0     1.023241         0.321825
# 1          1   -1319.28500  186.491130  200.0     1.023236         0.278360
# 2          2   -1212.18580   98.557014  200.0     1.021739         0.305946
# 3          3   -1272.46250  137.121520  200.0     1.023875         0.245997
# 4          4   -1224.63390  127.758970  200.0     1.026873         0.285924
# 5          5   -1299.33630  174.081190  200.0     1.021106         0.298637
# 6          6   -1184.95760   86.422810  200.0     1.027519         0.305578
# 7          7   -1239.95590  131.978210  200.0     1.035282         0.331367
# 8          8   -1281.40880  221.484560  200.0     1.033758         0.341138
# 9          9   -1224.66930  172.071470  200.0     1.033985         0.360867
# 10        10   -1385.00680  243.060620  200.0     1.029873         0.362158
# 11        11   -1255.23440  140.770970  200.0     1.035039         0.366529
# 12        12   -1280.55210  169.885730  200.0     1.031170         0.370526
# 13        13   -1265.74880  187.261860  200.0     1.046249         0.389644
# 14        14   -1208.60950   55.784360  200.0     1.041534         0.381414
# 15        15   -1235.05380  119.270800  200.0     1.038061         0.403727
# 16        16   -1375.72410  265.806100  200.0     1.036998         0.446604
# 17        17   -1358.22570  209.039140  200.0     1.038928         0.392927
# 18        18   -1336.89610  250.969390  200.0     1.033319         0.418105
# 19        19   -1307.06770  184.085070  200.0     1.036801         0.351302
# 20        20   -1460.74160  288.366940  200.0     1.036557         0.362517
# 21        21   -1391.21250  290.103300  200.0     1.036982         0.435216
# 22        22   -1392.86680  250.932050  200.0     1.043933         0.387455
# 23        23   -1403.23930  306.514530  200.0     1.051979         0.394806
# 24        24   -1294.52840  284.146970  200.0     1.071552         0.387050
# 25        25   -1395.35070  290.843100  200.0     1.065750         0.403472
# 26        26   -1277.81350  281.695950  200.0     1.078783         0.367864
# 27        27   -1363.39780  350.784500  200.0     1.068921         0.379573
# 28        28   -1287.61900  257.257000  200.0     1.067155         0.388042
# 29        29   -1231.86830  287.168520  200.0     1.091699         0.380357
# ...      ...           ...         ...    ...          ...              ...
# 17587    770    -790.11224   97.149310  200.0     3.447561         0.841421
# 17588    771    -763.43085  118.759026  200.0     3.832906         0.838891
# 17589    772    -813.72490  150.871540  200.0     4.443592         0.872098
# 17590    773    -796.41235  113.342380  200.0     4.302868         0.863470
# 17591    774    -828.06323  105.434845  200.0     3.045525         0.796862
# 17592    775    -831.18585   93.582650  200.0     3.154691         0.754845
# 17593    776    -842.16583   68.001280  200.0     2.903116         0.795064
# 17594    777    -780.91280  141.721200  200.0     3.256170         0.816149
# 17595    778    -803.72530  109.753650  200.0     4.078038         0.829973
# 17596    779    -814.15380  133.989410  200.0     4.271877         0.809983
# 17597    780    -756.36176  112.053910  200.0     4.144715         0.814758
# 17598    781    -754.57590  124.165020  200.0     4.383855         0.810582
# 17599    782    -833.76410   72.246100  200.0     3.300435         0.777197
# 17600    783    -829.32200  133.383580  200.0     3.492163         0.829608
# 17601    784    -790.79565  112.142990  200.0     3.587941         0.835161
# 17602    785    -851.05100   89.439750  200.0     3.035561         0.780001
# 17603    786    -822.47906   92.080950  200.0     2.995763         0.793728
# 17604    787    -755.39120   55.994940  200.0     3.548922         0.827709
# 17605    788    -847.63226  116.356850  200.0     4.108379         0.798147
# 17606    789    -756.97440  124.605490  200.0     4.564839         0.765587
# 17607    790    -855.67770  137.874710  200.0     3.382852         0.780906
# 17608    791    -813.54280   78.434010  200.0     2.973978         0.766897
# 17609    792    -822.81810   73.524635  200.0     2.902679         0.784629
# 17610    793    -867.47680  120.353130  200.0     3.169770         0.837949
# 17611    794    -749.15290  119.738780  200.0     3.553695         0.804217
# 17612    795    -772.03046  122.534225  200.0     4.188243         0.852946
# 17613    796    -812.95264  103.745060  200.0     4.396321         0.823397
# 17614    797    -727.71387  122.213230  200.0     3.155274         0.787210
# 17615    798    -769.43335   98.009130  200.0     4.127099         0.853358
# 17616    799    -775.71590  104.721380  200.0     4.416116         0.848900
#
#        StabilityActionError  StabilityGoalError  ForwardPreictionError  \
# 0                  2.089015            0.807943               0.352052
# 1                  0.327731            0.807682               0.335224
# 2                  0.441802            0.800000               0.405425
# 3                  0.243141            0.805651               0.293580
# 4                  0.185555            0.773906               0.268783
# 5                  0.276480            0.745482               0.254813
# 6                  0.411550            0.739766               0.231797
# 7                  0.248245            0.705990               0.197121
# 8                  0.255664            0.699049               0.162917
# 9                  0.203012            0.681120               0.147148
# 10                 0.899666            0.671784               0.139070
# 11                 1.428684            0.667109               0.139486
# 12                 0.243769            0.655703               0.134699
# 13                 0.225959            0.632357               0.111130
# 14                 0.339528            0.645872               0.105252
# 15                 0.237534            0.627161               0.096705
# 16                 0.229654            0.571237               0.112632
# 17                 0.256005            0.641497               0.091349
# 18                 0.283820            0.602565               0.088686
# 19                 0.198108            0.694987               0.065364
# 20                 0.231341            0.675716               0.055949
# 21                 0.196028            0.585938               0.064879
# 22                 0.863696            0.653802               0.051412
# 23                 0.283115            0.639792               0.041782
# 24                 0.714345            0.652891               0.042141
# 25                 0.325230            0.631693               0.040750
# 26                 0.299361            0.676432               0.037715
# 27                 0.667336            0.664870               0.036873
# 28                 0.430131            0.655859               0.037526
# 29                 1.091388            0.661771               0.035278
# ...                     ...                 ...                    ...
# 17587              0.001493            0.158138               0.000249
# 17588              0.001855            0.159909               0.000153
# 17589              0.001352            0.127031               0.000430
# 17590              0.002312            0.134766               0.000325
# 17591              0.001233            0.202578               0.000321
# 17592              0.001166            0.244935               0.000723
# 17593              0.007119            0.202669               0.001232
# 17594              0.003739            0.182357               0.001316
# 17595              0.001859            0.169753               0.000416
# 17596              0.002116            0.188503               0.000352
# 17597              0.001437            0.184492               0.000260
# 17598              0.001731            0.188398               0.000272
# 17599              0.004217            0.220664               0.000207
# 17600              0.002094            0.169036               0.000280
# 17601              0.001268            0.164206               0.000294
# 17602              0.001314            0.219310               0.000332
# 17603              0.003453            0.204674               0.000651
# 17604              0.001244            0.171849               0.000614
# 17605              0.002591            0.200495               0.000688
# 17606              0.004711            0.233151               0.000315
# 17607              0.001237            0.218333               0.000467
# 17608              0.001207            0.232565               0.000299
# 17609              0.002193            0.213854               0.000571
# 17610              0.002245            0.162201               0.000710
# 17611              0.003285            0.196888               0.000410
# 17612              0.001470            0.146354               0.000445
# 17613              0.001187            0.175820               0.000597
# 17614              0.002982            0.213034               0.000282
# 17615              0.001847            0.145911               0.000202
# 17616              0.002261            0.149193               0.000245
#
#        GoalDiscount  RewardDiscount  GoalsStepReward  ActionsReward  \
# 0          0.457752        0.488269         0.157631      -6.393657
# 1          0.464912        0.468135         0.143349      -6.292215
# 2          0.466238        0.229888         0.154247      -5.751463
# 3          0.453996        0.300856         0.122402      -6.091275
# 4          0.462458        0.260614         0.149279      -5.826041
# 5          0.460659        0.378386         0.150377      -6.171533
# 6          0.468591        0.170381         0.155948      -5.591960
# 7          0.468122        0.234761         0.171259      -5.835768
# 8          0.457675        0.406513         0.174182      -6.035612
# 9          0.468053        0.212466         0.186222      -5.743863
# 10         0.468569        0.601094         0.188451      -6.541230
# 11         0.466413        0.344953         0.191301      -5.886047
# 12         0.472009        0.442941         0.189494      -6.007261
# 13         0.464227        0.300273         0.201580      -5.913306
# 14         0.475676        0.238099         0.201728      -5.625694
# 15         0.469826        0.286661         0.211551      -5.735425
# 16         0.454748        0.505686         0.221412      -6.398136
# 17         0.444662        0.639222         0.190132      -6.372838
# 18         0.468196        0.502193         0.212279      -6.234669
# 19         0.465219        0.500876         0.184995      -6.162207
# 20         0.471011        0.615359         0.194069      -6.902628
# 21         0.472412        0.444018         0.224823      -6.489764
# 22         0.467866        0.525741         0.205628      -6.536369
# 23         0.451117        0.566261         0.207574      -6.588153
# 24         0.459678        0.448164         0.214643      -6.041939
# 25         0.469545        0.530734         0.218902      -6.541471
# 26         0.452897        0.346518         0.201480      -5.966805
# 27         0.475754        0.510376         0.216626      -6.408865
# 28         0.474233        0.523674         0.216273      -5.994651
# 29         0.452440        0.288347         0.218836      -5.718657
# ...             ...             ...              ...            ...
# 17587      0.494830        0.015783         1.620012      -3.114628
# 17588      0.490981        0.016371         1.851902      -2.986003
# 17589      0.491732        0.018171         2.161296      -3.266731
# 17590      0.486472        0.016640         2.045582      -3.068559
# 17591      0.473038        0.017846         1.424646      -3.405188
# 17592      0.499791        0.017641         1.547025      -3.476348
# 17593      0.489924        0.016652         1.382369      -3.456315
# 17594      0.499539        0.015727         1.567222      -3.097343
# 17595      0.486937        0.015563         1.875655      -3.178300
# 17596      0.492397        0.016399         1.975165      -3.220202
# 17597      0.492286        0.015745         1.974503      -2.848830
# 17598      0.489160        0.016069         2.081682      -2.945216
# 17599      0.496128        0.015768         1.593607      -3.378508
# 17600      0.492471        0.017094         1.720687      -3.348011
# 17601      0.494102        0.016507         1.812398      -3.184756
# 17602      0.491508        0.016428         1.435924      -3.551626
# 17603      0.491438        0.016216         1.465971      -3.460234
# 17604      0.491126        0.015396         1.748641      -3.075066
# 17605      0.492174        0.017476         1.957345      -3.431899
# 17606      0.486424        0.015678         2.101027      -2.965894
# 17607      0.485519        0.020704         1.616349      -3.476201
# 17608      0.484176        0.015993         1.381822      -3.425084
# 17609      0.498732        0.016611         1.382965      -3.417335
# 17610      0.495430        0.018257         1.530629      -3.521343
# 17611      0.492473        0.015456         1.683430      -2.932752
# 17612      0.492559        0.015974         1.985812      -2.961706
# 17613      0.488983        0.016337         2.077595      -3.189455
# 17614      0.493305        0.015838         1.494179      -2.859850
# 17615      0.490741        0.015225         1.999250      -3.041774
# 17616      0.491487        0.015913         2.152932      -3.003619
#
#        TotalEnvInteracts  Unit                     Condition1  \
# 0                   2400     0   discounts_pendulum-v0_goa0-1
# 1                   4800     0   discounts_pendulum-v0_goa0-1
# 2                   7200     0   discounts_pendulum-v0_goa0-1
# 3                   9600     0   discounts_pendulum-v0_goa0-1
# 4                  12000     0   discounts_pendulum-v0_goa0-1
# 5                  14400     0   discounts_pendulum-v0_goa0-1
# 6                  16800     0   discounts_pendulum-v0_goa0-1
# 7                  19200     0   discounts_pendulum-v0_goa0-1
# 8                  21600     0   discounts_pendulum-v0_goa0-1
# 9                  24000     0   discounts_pendulum-v0_goa0-1
# 10                 26400     0   discounts_pendulum-v0_goa0-1
# 11                 28800     0   discounts_pendulum-v0_goa0-1
# 12                 31200     0   discounts_pendulum-v0_goa0-1
# 13                 33600     0   discounts_pendulum-v0_goa0-1
# 14                 36000     0   discounts_pendulum-v0_goa0-1
# 15                 38400     0   discounts_pendulum-v0_goa0-1
# 16                 40800     0   discounts_pendulum-v0_goa0-1
# 17                 43200     0   discounts_pendulum-v0_goa0-1
# 18                 45600     0   discounts_pendulum-v0_goa0-1
# 19                 48000     0   discounts_pendulum-v0_goa0-1
# 20                 50400     0   discounts_pendulum-v0_goa0-1
# 21                 52800     0   discounts_pendulum-v0_goa0-1
# 22                 55200     0   discounts_pendulum-v0_goa0-1
# 23                 57600     0   discounts_pendulum-v0_goa0-1
# 24                 60000     0   discounts_pendulum-v0_goa0-1
# 25                 62400     0   discounts_pendulum-v0_goa0-1
# 26                 64800     0   discounts_pendulum-v0_goa0-1
# 27                 67200     0   discounts_pendulum-v0_goa0-1
# 28                 69600     0   discounts_pendulum-v0_goa0-1
# 29                 72000     0   discounts_pendulum-v0_goa0-1
# ...                  ...   ...                            ...
# 17587            1850400     6  discounts_pendulum-v0_goa0-01
# 17588            1852800     6  discounts_pendulum-v0_goa0-01
# 17589            1855200     6  discounts_pendulum-v0_goa0-01
# 17590            1857600     6  discounts_pendulum-v0_goa0-01
# 17591            1860000     6  discounts_pendulum-v0_goa0-01
# 17592            1862400     6  discounts_pendulum-v0_goa0-01
# 17593            1864800     6  discounts_pendulum-v0_goa0-01
# 17594            1867200     6  discounts_pendulum-v0_goa0-01
# 17595            1869600     6  discounts_pendulum-v0_goa0-01
# 17596            1872000     6  discounts_pendulum-v0_goa0-01
# 17597            1874400     6  discounts_pendulum-v0_goa0-01
# 17598            1876800     6  discounts_pendulum-v0_goa0-01
# 17599            1879200     6  discounts_pendulum-v0_goa0-01
# 17600            1881600     6  discounts_pendulum-v0_goa0-01
# 17601            1884000     6  discounts_pendulum-v0_goa0-01
# 17602            1886400     6  discounts_pendulum-v0_goa0-01
# 17603            1888800     6  discounts_pendulum-v0_goa0-01
# 17604            1891200     6  discounts_pendulum-v0_goa0-01
# 17605            1893600     6  discounts_pendulum-v0_goa0-01
# 17606            1896000     6  discounts_pendulum-v0_goa0-01
# 17607            1898400     6  discounts_pendulum-v0_goa0-01
# 17608            1900800     6  discounts_pendulum-v0_goa0-01
# 17609            1903200     6  discounts_pendulum-v0_goa0-01
# 17610            1905600     6  discounts_pendulum-v0_goa0-01
# 17611            1908000     6  discounts_pendulum-v0_goa0-01
# 17612            1910400     6  discounts_pendulum-v0_goa0-01
# 17613            1912800     6  discounts_pendulum-v0_goa0-01
# 17614            1915200     6  discounts_pendulum-v0_goa0-01
# 17615            1917600     6  discounts_pendulum-v0_goa0-01
# 17616            1920000     6  discounts_pendulum-v0_goa0-01
#
#                              Condition2  Performance
# 0        discounts_pendulum-v0_goa0-1-0  -1347.92070
# 1        discounts_pendulum-v0_goa0-1-0  -1319.28500
# 2        discounts_pendulum-v0_goa0-1-0  -1212.18580
# 3        discounts_pendulum-v0_goa0-1-0  -1272.46250
# 4        discounts_pendulum-v0_goa0-1-0  -1224.63390
# 5        discounts_pendulum-v0_goa0-1-0  -1299.33630
# 6        discounts_pendulum-v0_goa0-1-0  -1184.95760
# 7        discounts_pendulum-v0_goa0-1-0  -1239.95590
# 8        discounts_pendulum-v0_goa0-1-0  -1281.40880
# 9        discounts_pendulum-v0_goa0-1-0  -1224.66930
# 10       discounts_pendulum-v0_goa0-1-0  -1385.00680
# 11       discounts_pendulum-v0_goa0-1-0  -1255.23440
# 12       discounts_pendulum-v0_goa0-1-0  -1280.55210
# 13       discounts_pendulum-v0_goa0-1-0  -1265.74880
# 14       discounts_pendulum-v0_goa0-1-0  -1208.60950
# 15       discounts_pendulum-v0_goa0-1-0  -1235.05380
# 16       discounts_pendulum-v0_goa0-1-0  -1375.72410
# 17       discounts_pendulum-v0_goa0-1-0  -1358.22570
# 18       discounts_pendulum-v0_goa0-1-0  -1336.89610
# 19       discounts_pendulum-v0_goa0-1-0  -1307.06770
# 20       discounts_pendulum-v0_goa0-1-0  -1460.74160
# 21       discounts_pendulum-v0_goa0-1-0  -1391.21250
# 22       discounts_pendulum-v0_goa0-1-0  -1392.86680
# 23       discounts_pendulum-v0_goa0-1-0  -1403.23930
# 24       discounts_pendulum-v0_goa0-1-0  -1294.52840
# 25       discounts_pendulum-v0_goa0-1-0  -1395.35070
# 26       discounts_pendulum-v0_goa0-1-0  -1277.81350
# 27       discounts_pendulum-v0_goa0-1-0  -1363.39780
# 28       discounts_pendulum-v0_goa0-1-0  -1287.61900
# 29       discounts_pendulum-v0_goa0-1-0  -1231.86830
# ...                                 ...          ...
# 17587  discounts_pendulum-v0_goa0-01-22   -790.11224
# 17588  discounts_pendulum-v0_goa0-01-22   -763.43085
# 17589  discounts_pendulum-v0_goa0-01-22   -813.72490
# 17590  discounts_pendulum-v0_goa0-01-22   -796.41235
# 17591  discounts_pendulum-v0_goa0-01-22   -828.06323
# 17592  discounts_pendulum-v0_goa0-01-22   -831.18585
# 17593  discounts_pendulum-v0_goa0-01-22   -842.16583
# 17594  discounts_pendulum-v0_goa0-01-22   -780.91280
# 17595  discounts_pendulum-v0_goa0-01-22   -803.72530
# 17596  discounts_pendulum-v0_goa0-01-22   -814.15380
# 17597  discounts_pendulum-v0_goa0-01-22   -756.36176
# 17598  discounts_pendulum-v0_goa0-01-22   -754.57590
# 17599  discounts_pendulum-v0_goa0-01-22   -833.76410
# 17600  discounts_pendulum-v0_goa0-01-22   -829.32200
# 17601  discounts_pendulum-v0_goa0-01-22   -790.79565
# 17602  discounts_pendulum-v0_goa0-01-22   -851.05100
# 17603  discounts_pendulum-v0_goa0-01-22   -822.47906
# 17604  discounts_pendulum-v0_goa0-01-22   -755.39120
# 17605  discounts_pendulum-v0_goa0-01-22   -847.63226
# 17606  discounts_pendulum-v0_goa0-01-22   -756.97440
# 17607  discounts_pendulum-v0_goa0-01-22   -855.67770
# 17608  discounts_pendulum-v0_goa0-01-22   -813.54280
# 17609  discounts_pendulum-v0_goa0-01-22   -822.81810
# 17610  discounts_pendulum-v0_goa0-01-22   -867.47680
# 17611  discounts_pendulum-v0_goa0-01-22   -749.15290
# 17612  discounts_pendulum-v0_goa0-01-22   -772.03046
# 17613  discounts_pendulum-v0_goa0-01-22   -812.95264
# 17614  discounts_pendulum-v0_goa0-01-22   -727.71387
# 17615  discounts_pendulum-v0_goa0-01-22   -769.43335
# 17616  discounts_pendulum-v0_goa0-01-22   -775.71590
#
# [17617 rows x 18 columns]

# %%
# Show table of parameters used in the experiment, used as guide to graph legends

def config_values(config, paths):
    values = []
    for path in paths:
        value = config
        for name in path.split(':'):
            value = value[name]
        values.append(value)
    return values

columns = ['exp_name', 
           'steps_per_epoch',
#           'use_reward_discount',
           'goal_octaves', 
            'goal_discount_rate', 
#           'no_step_reward', 
#           'finish_action_path_on_new_goal', 
#            'ac_kwargs:hidden_sizes', 
#            'ac_kwargs:activation', 
#            'inverse_kwargs:hidden_sizes', 
#            'inverse_kwargs:activation', 
#            'inverse_kwargs:goals_output_activation'
          ]

data = list(map(lambda config: config_values(config, columns), configs))
df = pd.DataFrame(data=data, columns=columns)
df.drop_duplicates()
# Out:
#                           exp_name  steps_per_epoch  goal_octaves  \
# 0     discounts_pendulum-v0_goa0-1             2400             6
# 8   discounts_pendulum-v0_goa0-001             2400             6
# 15           octaves-4_pendulum-v0             1200             4
# 16   discounts_pendulum-v0_goa0-01             2400             6
#
#     goal_discount_rate
# 0                0.100
# 8                0.001
# 15               0.010
# 16               0.010

# %%
plt.figure(figsize=(20, 15), dpi=150)

# To show individual runs, add arguments: units='Condition2, estimator=None
# To compare runs with different epoch lengts, use:xaxis='TotalEnvInteracts'

plot_data(datasets, smooth=5, xaxis='TotalEnvInteracts')
plt.show()
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityGoalError', smooth=1, show_legend=False, estimator='mean')
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityActionError', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalDiscount', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-469ac8f2fb4e> in <module>
#       1 plt.figure(figsize=(14, 8), dpi=150)
# ----> 2 plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
#       3 plt.show()
#
# ~/openaigym/spinningup/spinup/utils/plot.py in plot_data(data, xaxis, value, condition, smooth, show_legend, **kwargs)
#      32     sns.set(style="darkgrid", font_scale=1.5)
#      33     # sns.tsplot(data=data, time=xaxis, value=value, unit="Unit", condition=condition, ci='sd', **kwargs)
# ---> 34     sns.lineplot(data=data, x=xaxis, y=value, hue=condition, legend=show_legend, **kwargs)
#      35     """
#      36     If you upgrade to any version of Seaborn greater than 0.8.1, switch from
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend)
#     661
#     662         plot_data = self.establish_variables(
# --> 663             x, y, hue, size, style, units, data
#     664         )
#     665
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     140                 if isinstance(var, string_types):
#     141                     err = "Could not interpret input '{}'".format(var)
# --> 142                     raise ValueError(err)
#     143
#     144             # Extract variable names
#
# ValueError: Could not interpret input 'ActionsEntropy'

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalsEntropy', smooth=1, show_legend=False)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import os.path as osp
import numpy as np
from spinup.utils.plot import get_datasets, get_all_datasets, plot_data
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
datasets, configs = get_all_datasets(['/Users/ppiech/openaigym/spindata/mountaincar-bin_goal/'])

# Show a sample of the data
pd.concat(datasets, ignore_index=True)
# Out:
# Plotting from...
# ==================================================
#
# /Users/ppiech/openaigym/spindata/mountaincar-bin_goal/
#
# ==================================================
#       Epoch  AverageEpRet  StdEpRet  EpLen  GoalPathLen  StabilityReward  \
# 0         0        -200.0       0.0  200.0     1.040102         0.497044
# 1         1        -200.0       0.0  200.0     1.034922         0.504570
# 2         2        -200.0       0.0  200.0     1.033104         0.513623
# 3         3        -200.0       0.0  200.0     1.035168         0.515292
# 4         4        -200.0       0.0  200.0     1.029741         0.536912
# 5         5        -200.0       0.0  200.0     1.040644         0.548319
# 6         6        -200.0       0.0  200.0     1.039316         0.559575
# 7         7        -200.0       0.0  200.0     1.047387         0.572884
# 8         8        -200.0       0.0  200.0     1.052361         0.586861
# 9         9        -200.0       0.0  200.0     1.041677         0.597843
# 10       10        -200.0       0.0  200.0     1.045850         0.614626
# 11       11        -200.0       0.0  200.0     1.053727         0.611249
# 12       12        -200.0       0.0  200.0     1.071207         0.623243
# 13       13        -200.0       0.0  200.0     1.056356         0.675646
# 14       14        -200.0       0.0  200.0     1.062919         0.690297
# 15       15        -200.0       0.0  200.0     1.080062         0.709457
# 16       16        -200.0       0.0  200.0     1.085394         0.725631
# 17       17        -200.0       0.0  200.0     1.110760         0.732591
# 18       18        -200.0       0.0  200.0     1.117957         0.733748
# 19       19        -200.0       0.0  200.0     1.081165         0.713722
# 20       20        -200.0       0.0  200.0     1.081144         0.710464
# 21       21        -200.0       0.0  200.0     1.063226         0.711765
# 22       22        -200.0       0.0  200.0     1.089225         0.725939
# 23       23        -200.0       0.0  200.0     1.105194         0.717584
# 24       24        -200.0       0.0  200.0     1.109564         0.723521
# 25       25        -200.0       0.0  200.0     1.123581         0.720878
# 26       26        -200.0       0.0  200.0     1.113834         0.716669
# 27       27        -200.0       0.0  200.0     1.091242         0.714365
# 28       28        -200.0       0.0  200.0     1.108890         0.710264
# 29       29        -200.0       0.0  200.0     1.129870         0.710216
# ...     ...           ...       ...    ...          ...              ...
# 4976     70        -200.0       0.0  200.0    95.549450         0.986754
# 4977     71        -200.0       0.0  200.0    96.016980         0.987333
# 4978     72        -200.0       0.0  200.0    96.328674         0.986809
# 4979     73        -200.0       0.0  200.0   100.500000         0.987266
# 4980     74        -200.0       0.0  200.0   100.500000         0.988494
# 4981     75        -200.0       0.0  200.0   100.500000         0.988876
# 4982     76        -200.0       0.0  200.0    96.861640         0.988808
# 4983     77        -200.0       0.0  200.0    95.445560         0.989314
# 4984     78        -200.0       0.0  200.0   100.500000         0.989325
# 4985     79        -200.0       0.0  200.0    98.601900         0.988665
# 4986     80        -200.0       0.0  200.0   100.500000         0.989597
# 4987     81        -200.0       0.0  200.0   100.500000         0.989883
# 4988     82        -200.0       0.0  200.0   100.500000         0.990563
# 4989     83        -200.0       0.0  200.0    96.016980         0.989753
# 4990     84        -200.0       0.0  200.0    97.714780         0.990507
# 4991     85        -200.0       0.0  200.0   100.500000         0.990216
# 4992     86        -200.0       0.0  200.0    98.682320         0.990846
# 4993     87        -200.0       0.0  200.0   100.500000         0.990913
# 4994     88        -200.0       0.0  200.0   100.500000         0.990983
# 4995     89        -200.0       0.0  200.0   100.500000         0.990727
# 4996     90        -200.0       0.0  200.0   100.500000         0.991193
# 4997     91        -200.0       0.0  200.0   100.500000         0.991595
# 4998     92        -200.0       0.0  200.0   100.500000         0.991737
# 4999     93        -200.0       0.0  200.0   100.500000         0.991823
# 5000     94        -200.0       0.0  200.0   100.500000         0.991326
# 5001     95        -200.0       0.0  200.0   100.500000         0.992252
# 5002     96        -200.0       0.0  200.0   100.350820         0.991800
# 5003     97        -200.0       0.0  200.0    97.143860         0.992105
# 5004     98        -200.0       0.0  200.0   100.500000         0.992675
# 5005     99        -200.0       0.0  200.0   100.500000         0.992783
#
#       StabilityActionError  StabilityGoalError  ForwardPredictionError  \
# 0                 0.504432            0.353484                0.260515
# 1                 0.491447            0.332328                0.059687
# 2                 0.476509            0.366063                0.043107
# 3                 0.454837            0.295156                0.028256
# 4                 0.426161            0.252656                0.021017
# 5                 0.401414            0.263531                0.015854
# 6                 0.373541            0.263547                0.011137
# 7                 0.346836            0.262609                0.014302
# 8                 0.319383            0.261078                0.011739
# 9                 0.294608            0.264750                0.013117
# 10                0.258970            0.260531                0.016040
# 11                0.224125            0.294063                0.019222
# 12                0.201307            0.287547                0.010588
# 13                0.196899            0.208375                0.008585
# 14                0.199152            0.188047                0.008718
# 15                0.189824            0.158172                0.010534
# 16                0.187947            0.137031                0.010712
# 17                0.187402            0.130156                0.010180
# 18                0.187905            0.126547                0.008558
# 19                0.188050            0.158172                0.006476
# 20                0.193016            0.149547                0.011233
# 21                0.193056            0.147531                0.007974
# 22                0.190217            0.131219                0.006895
# 23                0.196644            0.136016                0.008620
# 24                0.198391            0.125391                0.006107
# 25                0.206696            0.119594                0.003957
# 26                0.213635            0.117359                0.003578
# 27                0.216562            0.117078                0.004441
# 28                0.223438            0.113406                0.004421
# 29                0.224119            0.113203                0.004488
# ...                    ...                 ...                     ...
# 4976              0.013127            0.000125                0.000721
# 4977              0.012544            0.000125                0.000702
# 4978              0.013115            0.000078                0.001120
# 4979              0.012734            0.000000                0.001336
# 4980              0.011506            0.000000                0.000404
# 4981              0.011124            0.000000                0.000466
# 4982              0.011192            0.000266                0.000262
# 4983              0.010626            0.000063                0.000461
# 4984              0.010675            0.000000                0.000666
# 4985              0.011213            0.000125                0.000997
# 4986              0.010403            0.000000                0.000580
# 4987              0.010117            0.000000                0.000771
# 4988              0.009437            0.000000                0.000361
# 4989              0.010154            0.000094                0.000870
# 4990              0.009371            0.000125                0.000393
# 4991              0.009784            0.000000                0.000644
# 4992              0.009092            0.000063                0.001002
# 4993              0.009087            0.000000                0.000677
# 4994              0.009017            0.000000                0.000659
# 4995              0.009273            0.000000                0.000797
# 4996              0.008807            0.000000                0.000382
# 4997              0.008405            0.000000                0.000353
# 4998              0.008263            0.000000                0.000641
# 4999              0.008177            0.000000                0.000476
# 5000              0.008674            0.000000                0.000633
# 5001              0.007748            0.000000                0.000265
# 5002              0.008200            0.000266                0.000400
# 5003              0.007670            0.000234                0.000679
# 5004              0.007325            0.000000                0.000300
# 5005              0.007217            0.000000                0.000243
#
#       GoalsStepReward     ...       ActionsEntropy  ActionsAdvantageMean  \
# 0            0.542565     ...         1.058600e+00              0.420488
# 1            0.545362     ...         1.064622e+00              0.504492
# 2            0.551917     ...         1.028751e+00              0.514336
# 3            0.556079     ...         1.020965e+00              0.505322
# 4            0.572123     ...         9.997976e-01              0.548686
# 5            0.596571     ...         9.657989e-01              0.541726
# 6            0.604869     ...         9.070556e-01              0.560753
# 7            0.627056     ...         8.483563e-01              0.571211
# 8            0.646583     ...         7.687200e-01              0.589246
# 9            0.644503     ...         7.099962e-01              0.602572
# 10           0.665991     ...         6.141766e-01              0.617993
# 11           0.669986     ...         4.764376e-01              0.592378
# 12           0.701327     ...         5.053867e-01              0.611845
# 13           0.738886     ...         4.534254e-01              0.714564
# 14           0.761279     ...         3.813365e-01              0.687706
# 15           0.796752     ...         2.879853e-01              0.709159
# 16           0.821613     ...         2.401348e-01              0.716573
# 17           0.854750     ...         1.810839e-01              0.707892
# 18           0.865868     ...         1.784697e-01              0.706087
# 19           0.801063     ...         1.709866e-01              0.676275
# 20           0.798308     ...         1.432422e-01              0.688332
# 21           0.782394     ...         1.407185e-01              0.698650
# 22           0.823831     ...         1.358613e-01              0.716292
# 23           0.833290     ...         1.119487e-01              0.685369
# 24           0.845322     ...         1.018008e-01              0.707558
# 25           0.857526     ...         9.029719e-02              0.692146
# 26           0.839622     ...         8.417647e-02              0.693498
# 27           0.811790     ...         6.865417e-02              0.697557
# 28           0.831711     ...         6.296045e-02              0.680298
# 29           0.852770     ...         5.200519e-02              0.686813
# ...               ...     ...                  ...                   ...
# 4976        96.039450     ...         2.705930e-06             -0.022965
# 4977        96.487800     ...         2.710400e-06             -0.009751
# 4978        96.875330     ...         2.675711e-06             -0.032258
# 4979       100.987210     ...         2.677261e-06             -0.029923
# 4980       100.988470     ...         2.669453e-06             -0.003901
# 4981       100.988846     ...         2.675414e-06             -0.019027
# 4982        97.419136     ...         5.779838e-04             -0.009565
# 4983        95.946495     ...         3.467261e-06             -0.001530
# 4984       100.989300     ...         3.476798e-06             -0.036324
# 4985        99.018974     ...         3.517148e-06             -0.018794
# 4986       100.989570     ...         3.470599e-06             -0.015898
# 4987       100.989845     ...         3.466605e-06             -0.018903
# 4988       100.990550     ...         3.466366e-06             -0.014217
# 4989        96.559870     ...         3.663859e-06             -0.009518
# 4990        98.284515     ...         3.470239e-06             -0.007896
# 4991       100.990180     ...         3.414511e-06             -0.023941
# 4992        99.100266     ...         3.414034e-06             -0.001063
# 4993       100.990880     ...         3.413498e-06             -0.022783
# 4994       100.990950     ...         3.415464e-06             -0.017524
# 4995       100.990700     ...         3.417431e-06             -0.020257
# 4996       100.991150     ...         3.413557e-06             -0.014998
# 4997       100.991580     ...         3.410815e-06             -0.017338
# 4998       100.991714     ...         3.413438e-06             -0.016554
# 4999       100.991800     ...         3.413736e-06             -0.016760
# 5000       100.991295     ...         3.416239e-06             -0.017797
# 5001       100.992230     ...         3.410696e-06             -0.015104
# 5002       100.892030     ...         4.328303e-04             -0.022009
# 5003        97.708500     ...         1.220796e-04             -0.004009
# 5004       100.992650     ...         7.159113e-07             -0.016790
# 5005       100.992760     ...         7.160305e-07             -0.014052
#
#          ActionsKL  ActionsStopIter  LossActionInverse  LossGoalInverse  Unit  \
# 0     1.367508e-02             79.0           0.240479         0.249596     0
# 1     9.700316e-03             79.0           0.233229         0.248968     0
# 2     1.517926e-02             54.0           0.227045         0.248121     0
# 3     1.795781e-02             13.0           0.219066         0.246804     0
# 4     1.785574e-02             12.0           0.202632         0.245806     0
# 5     1.720691e-02             17.0           0.185024         0.246454     0
# 6     1.868783e-02             14.0           0.167323         0.246535     0
# 7     1.866071e-02              9.0           0.151860         0.246848     0
# 8     1.717058e-02             11.0           0.136784         0.245150     0
# 9     1.936280e-02             12.0           0.121660         0.247340     0
# 10    1.612543e-02             14.0           0.104741         0.246334     0
# 11    1.581010e-02             31.0           0.078568         0.245671     0
# 12    1.575305e-02             34.0           0.086470         0.241752     0
# 13    1.543945e-02             52.0           0.089440         0.235812     0
# 14    1.085409e-02             79.0           0.093060         0.228875     0
# 15    7.393024e-03             79.0           0.081830         0.224673     0
# 16    3.256922e-03             79.0           0.083931         0.219971     0
# 17    2.302384e-03             79.0           0.081055         0.215698     0
# 18    1.131935e-03             79.0           0.082977         0.214705     0
# 19    4.253502e-03             79.0           0.080469         0.214595     0
# 20    6.419772e-03             79.0           0.087682         0.214931     0
# 21    6.901622e-03             79.0           0.087496         0.212773     0
# 22    4.842667e-03             79.0           0.084300         0.208841     0
# 23    5.943865e-04             79.0           0.087996         0.206197     0
# 24    2.746380e-03             79.0           0.086973         0.204533     0
# 25    5.458948e-04             79.0           0.094516         0.202053     0
# 26    1.739854e-04             79.0           0.099888         0.201094     0
# 27    2.857923e-03             79.0           0.100661         0.197745     0
# 28    1.978275e-03             79.0           0.105722         0.197885     0
# 29    1.362191e-03             79.0           0.105744         0.196161     0
# ...            ...              ...                ...              ...   ...
# 4976 -1.549713e-09             79.0           0.000205         0.000412     0
# 4977 -2.205366e-09             79.0           0.000185         0.000385     0
# 4978 -4.172316e-10             79.0           0.000217         0.000503     0
# 4979  0.000000e+00             79.0           0.000207         0.000191     0
# 4980 -2.384178e-10             79.0           0.000155         0.000135     0
# 4981 -5.960442e-11             79.0           0.000145         0.000121     0
# 4982 -1.502166e-04             79.0           0.000385         0.000407     0
# 4983  9.536709e-10             79.0           0.000134         0.000296     0
# 4984  1.788134e-10             79.0           0.000140         0.000106     0
# 4985 -5.781620e-09             79.0           0.000164         0.000317     0
# 4986 -8.344619e-10             79.0           0.000134         0.000095     0
# 4987  1.192088e-10             79.0           0.000127         0.000088     0
# 4988  2.384177e-10             79.0           0.000105         0.000070     0
# 4989 -4.464298e-08             79.0           0.000135         0.000288     0
# 4990 -1.734487e-08             79.0           0.000108         0.000266     0
# 4991 -1.728529e-09             79.0           0.000124         0.000078     0
# 4992  7.152532e-10             79.0           0.000106         0.000261     0
# 4993  2.980222e-10             79.0           0.000105         0.000063     0
# 4994  1.788135e-10             79.0           0.000104         0.000062     0
# 4995  1.192089e-10             79.0           0.000115         0.000068     0
# 4996  4.172315e-10             79.0           0.000099         0.000056     0
# 4997  2.384179e-10             79.0           0.000089         0.000049     0
# 4998  5.364398e-10             79.0           0.000086         0.000047     0
# 4999  7.152534e-10             79.0           0.000085         0.000046     0
# 5000  1.013276e-09             79.0           0.000102         0.000055     0
# 5001  4.172310e-10             79.0           0.000074         0.000039     0
# 5002 -1.164026e-04             79.0           0.000325         0.000337     0
# 5003 -1.117937e-04             79.0           0.000077         0.000234     0
# 5004 -3.576277e-10             79.0           0.000066         0.000033     0
# 5005  0.000000e+00             79.0           0.000064         0.000031     0
#
#                                      Condition1  \
# 0     bin_goals_by_section_split_mountaincar-v0
# 1     bin_goals_by_section_split_mountaincar-v0
# 2     bin_goals_by_section_split_mountaincar-v0
# 3     bin_goals_by_section_split_mountaincar-v0
# 4     bin_goals_by_section_split_mountaincar-v0
# 5     bin_goals_by_section_split_mountaincar-v0
# 6     bin_goals_by_section_split_mountaincar-v0
# 7     bin_goals_by_section_split_mountaincar-v0
# 8     bin_goals_by_section_split_mountaincar-v0
# 9     bin_goals_by_section_split_mountaincar-v0
# 10    bin_goals_by_section_split_mountaincar-v0
# 11    bin_goals_by_section_split_mountaincar-v0
# 12    bin_goals_by_section_split_mountaincar-v0
# 13    bin_goals_by_section_split_mountaincar-v0
# 14    bin_goals_by_section_split_mountaincar-v0
# 15    bin_goals_by_section_split_mountaincar-v0
# 16    bin_goals_by_section_split_mountaincar-v0
# 17    bin_goals_by_section_split_mountaincar-v0
# 18    bin_goals_by_section_split_mountaincar-v0
# 19    bin_goals_by_section_split_mountaincar-v0
# 20    bin_goals_by_section_split_mountaincar-v0
# 21    bin_goals_by_section_split_mountaincar-v0
# 22    bin_goals_by_section_split_mountaincar-v0
# 23    bin_goals_by_section_split_mountaincar-v0
# 24    bin_goals_by_section_split_mountaincar-v0
# 25    bin_goals_by_section_split_mountaincar-v0
# 26    bin_goals_by_section_split_mountaincar-v0
# 27    bin_goals_by_section_split_mountaincar-v0
# 28    bin_goals_by_section_split_mountaincar-v0
# 29    bin_goals_by_section_split_mountaincar-v0
# ...                                         ...
# 4976        forward_error_reward_mountaincar-v0
# 4977        forward_error_reward_mountaincar-v0
# 4978        forward_error_reward_mountaincar-v0
# 4979        forward_error_reward_mountaincar-v0
# 4980        forward_error_reward_mountaincar-v0
# 4981        forward_error_reward_mountaincar-v0
# 4982        forward_error_reward_mountaincar-v0
# 4983        forward_error_reward_mountaincar-v0
# 4984        forward_error_reward_mountaincar-v0
# 4985        forward_error_reward_mountaincar-v0
# 4986        forward_error_reward_mountaincar-v0
# 4987        forward_error_reward_mountaincar-v0
# 4988        forward_error_reward_mountaincar-v0
# 4989        forward_error_reward_mountaincar-v0
# 4990        forward_error_reward_mountaincar-v0
# 4991        forward_error_reward_mountaincar-v0
# 4992        forward_error_reward_mountaincar-v0
# 4993        forward_error_reward_mountaincar-v0
# 4994        forward_error_reward_mountaincar-v0
# 4995        forward_error_reward_mountaincar-v0
# 4996        forward_error_reward_mountaincar-v0
# 4997        forward_error_reward_mountaincar-v0
# 4998        forward_error_reward_mountaincar-v0
# 4999        forward_error_reward_mountaincar-v0
# 5000        forward_error_reward_mountaincar-v0
# 5001        forward_error_reward_mountaincar-v0
# 5002        forward_error_reward_mountaincar-v0
# 5003        forward_error_reward_mountaincar-v0
# 5004        forward_error_reward_mountaincar-v0
# 5005        forward_error_reward_mountaincar-v0
#
#                                        Condition2  Performance
# 0     bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 1     bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 2     bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 3     bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 4     bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 5     bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 6     bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 7     bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 8     bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 9     bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 10    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 11    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 12    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 13    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 14    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 15    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 16    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 17    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 18    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 19    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 20    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 21    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 22    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 23    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 24    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 25    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 26    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 27    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 28    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# 29    bin_goals_by_section_split_mountaincar-v0-0       -200.0
# ...                                           ...          ...
# 4976        forward_error_reward_mountaincar-v0-3       -200.0
# 4977        forward_error_reward_mountaincar-v0-3       -200.0
# 4978        forward_error_reward_mountaincar-v0-3       -200.0
# 4979        forward_error_reward_mountaincar-v0-3       -200.0
# 4980        forward_error_reward_mountaincar-v0-3       -200.0
# 4981        forward_error_reward_mountaincar-v0-3       -200.0
# 4982        forward_error_reward_mountaincar-v0-3       -200.0
# 4983        forward_error_reward_mountaincar-v0-3       -200.0
# 4984        forward_error_reward_mountaincar-v0-3       -200.0
# 4985        forward_error_reward_mountaincar-v0-3       -200.0
# 4986        forward_error_reward_mountaincar-v0-3       -200.0
# 4987        forward_error_reward_mountaincar-v0-3       -200.0
# 4988        forward_error_reward_mountaincar-v0-3       -200.0
# 4989        forward_error_reward_mountaincar-v0-3       -200.0
# 4990        forward_error_reward_mountaincar-v0-3       -200.0
# 4991        forward_error_reward_mountaincar-v0-3       -200.0
# 4992        forward_error_reward_mountaincar-v0-3       -200.0
# 4993        forward_error_reward_mountaincar-v0-3       -200.0
# 4994        forward_error_reward_mountaincar-v0-3       -200.0
# 4995        forward_error_reward_mountaincar-v0-3       -200.0
# 4996        forward_error_reward_mountaincar-v0-3       -200.0
# 4997        forward_error_reward_mountaincar-v0-3       -200.0
# 4998        forward_error_reward_mountaincar-v0-3       -200.0
# 4999        forward_error_reward_mountaincar-v0-3       -200.0
# 5000        forward_error_reward_mountaincar-v0-3       -200.0
# 5001        forward_error_reward_mountaincar-v0-3       -200.0
# 5002        forward_error_reward_mountaincar-v0-3       -200.0
# 5003        forward_error_reward_mountaincar-v0-3       -200.0
# 5004        forward_error_reward_mountaincar-v0-3       -200.0
# 5005        forward_error_reward_mountaincar-v0-3       -200.0
#
# [5006 rows x 28 columns]

# %%
# Show table of parameters used in the experiment, used as guide to graph legends

def config_values(config, paths):
    values = []
    for path in paths:
        value = config
        for name in path.split(':'):
            value = value[name]
        values.append(value)
    return values

columns = ['exp_name', 
           'steps_per_epoch',
#           'use_reward_discount',
#           'goal_octaves', 
#            'goal_discount_rate', 
#           'no_step_reward', 
#           'finish_action_path_on_new_goal', 
#            'ac_kwargs:hidden_sizes', 
#            'ac_kwargs:activation', 
#            'inverse_kwargs:hidden_sizes', 
#            'inverse_kwargs:activation', 
#            'inverse_kwargs:goals_output_activation'
          ]

data = list(map(lambda config: config_values(config, columns), configs))
df = pd.DataFrame(data=data, columns=columns)
df.drop_duplicates()
# Out:
#                                     exp_name  steps_per_epoch
# 0  bin_goals_by_section_split_mountaincar-v0             2000
# 3        forward_error_reward_mountaincar-v0             2000

# %%
plt.figure(figsize=(20, 15), dpi=150)

# To show individual runs, add arguments: units='Condition2, estimator=None
# To compare runs with different epoch lengts, use:xaxis='TotalEnvInteracts'

plot_data(datasets, smooth=5, units='Condition2', estimator=None)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityGoalError', smooth=1, show_legend=False, estimator='mean')
plt.show()
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityActionError', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalPathLen', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalsEntropy', smooth=1, show_legend=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-019df62264b8> in <module>
#       1 plt.figure(figsize=(14, 8), dpi=150)
# ----> 2 plot_data(datasets, value='GoalsEntropy', smooth=1, show_legend=False)
#       3 plt.show()
#
# ~/openaigym/spinningup/spinup/utils/plot.py in plot_data(data, xaxis, value, condition, smooth, show_legend, **kwargs)
#      32     sns.set(style="darkgrid", font_scale=1.5)
#      33     # sns.tsplot(data=data, time=xaxis, value=value, unit="Unit", condition=condition, ci='sd', **kwargs)
# ---> 34     sns.lineplot(data=data, x=xaxis, y=value, hue=condition, legend=show_legend, **kwargs)
#      35     """
#      36     If you upgrade to any version of Seaborn greater than 0.8.1, switch from
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1082         ax = plt.gca()
#    1083
# -> 1084     p.plot(ax, kwargs)
#    1085
#    1086     return ax
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     773                     err = "estimator must be None when specifying units"
#     774                     raise ValueError(err)
# --> 775                 x, y, y_ci = self.aggregate(y, x, units)
#     776             else:
#     777                 y_ci = None
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in aggregate(self, vals, grouper, units)
#     716                                columns=["low", "high"]).stack()
#     717         else:
# --> 718             cis = grouped.apply(bootstrapped_cis)
#     719
#     720         # Unpack the CIs into "wide" format for plotting
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    3467                       examples=_apply_docs['series_examples']))
#    3468     def apply(self, func, *args, **kwargs):
# -> 3469         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#    3470
#    3471     @Appender(_agg_doc)
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     916         with option_context('mode.chained_assignment', None):
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#     920
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/relational.py in bootstrapped_cis(vals)
#     697                 return null_ci
#     698
# --> 699             boots = bootstrap(vals, func=func, n_boot=n_boot)
#     700             cis = utils.ci(boots, ci)
#     701             return pd.Series(cis, ["low", "high"])
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/algorithms.py in bootstrap(*args, **kwargs)
#      86         resampler = rs.randint(0, n, n)
#      87         sample = [a.take(resampler, axis=0) for a in args]
# ---> 88         boot_dist.append(f(*sample, **func_kwargs))
#      89     return np.array(boot_dist)
#      90
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/seaborn/algorithms.py in f(x)
#      68     if isinstance(func, string_types):
#      69         def f(x):
# ---> 70             return getattr(x, func)()
#      71     else:
#      72         f = func
#
# ~/openaigym/spinningup/env/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# KeyboardInterrupt:

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import os.path as osp
import numpy as np
from spinup.utils.plot import get_datasets, get_all_datasets, plot_data
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
datasets, configs = get_all_datasets(['/Users/ppiech/openaigym/spindata/mountaincar-bin_goal/'])

# Show a sample of the data
pd.concat(datasets, ignore_index=True)
# Out:
# Plotting from...
# ==================================================
#
# /Users/ppiech/openaigym/spindata/mountaincar-bin_goal/
#
# ==================================================
#     Epoch  AverageEpRet  StdEpRet  EpLen  GoalPathLen  StabilityReward  \
# 0       0        -200.0       0.0  200.0     1.036735         0.500467
# 1       1        -200.0       0.0  200.0     1.026149         0.505188
# 2       2        -200.0       0.0  200.0     1.037009         0.510941
# 3       3        -200.0       0.0  200.0     1.035696         0.519267
# 4       4        -200.0       0.0  200.0     1.036461         0.529541
# 5       5        -200.0       0.0  200.0     1.032603         0.543509
# 6       6        -200.0       0.0  200.0     1.033121         0.561709
# 7       7        -200.0       0.0  200.0     1.032858         0.564647
# 8       8        -200.0       0.0  200.0     1.035450         0.605022
# 9       9        -200.0       0.0  200.0     1.034931         0.624539
# 10     10        -200.0       0.0  200.0     1.043779         0.642097
# 11     11        -200.0       0.0  200.0     1.046923         0.666103
# 12     12        -200.0       0.0  200.0     1.048499         0.673098
# 13     13        -200.0       0.0  200.0     1.052442         0.689250
# 14     14        -200.0       0.0  200.0     1.045862         0.700902
# 15     15        -200.0       0.0  200.0     1.055556         0.704425
# 16     16        -200.0       0.0  200.0     1.054012         0.712876
# 17     17        -200.0       0.0  200.0     1.055584         0.728439
# 18     18        -200.0       0.0  200.0     1.076143         0.730345
# 19     19        -200.0       0.0  200.0     1.074708         0.736107
# 20     20        -200.0       0.0  200.0     1.094665         0.752447
# 21     21        -200.0       0.0  200.0     1.141452         0.768675
# 22     22        -200.0       0.0  200.0     1.167830         0.787722
# 23     23        -200.0       0.0  200.0     1.189949         0.787990
# 24     24        -200.0       0.0  200.0     1.241341         0.802763
# 25     25        -200.0       0.0  200.0     1.279237         0.806260
# 26     26        -200.0       0.0  200.0     1.343035         0.819739
# 27     27        -200.0       0.0  200.0     1.496934         0.831268
# 28     28        -200.0       0.0  200.0     1.418129         0.831950
# 29     29        -200.0       0.0  200.0     1.281467         0.818012
# ..    ...           ...       ...    ...          ...              ...
# 70     70        -200.0       0.0  200.0    95.549450         0.986754
# 71     71        -200.0       0.0  200.0    96.016980         0.987333
# 72     72        -200.0       0.0  200.0    96.328674         0.986809
# 73     73        -200.0       0.0  200.0   100.500000         0.987266
# 74     74        -200.0       0.0  200.0   100.500000         0.988494
# 75     75        -200.0       0.0  200.0   100.500000         0.988876
# 76     76        -200.0       0.0  200.0    96.861640         0.988808
# 77     77        -200.0       0.0  200.0    95.445560         0.989314
# 78     78        -200.0       0.0  200.0   100.500000         0.989325
# 79     79        -200.0       0.0  200.0    98.601900         0.988665
# 80     80        -200.0       0.0  200.0   100.500000         0.989597
# 81     81        -200.0       0.0  200.0   100.500000         0.989883
# 82     82        -200.0       0.0  200.0   100.500000         0.990563
# 83     83        -200.0       0.0  200.0    96.016980         0.989753
# 84     84        -200.0       0.0  200.0    97.714780         0.990507
# 85     85        -200.0       0.0  200.0   100.500000         0.990216
# 86     86        -200.0       0.0  200.0    98.682320         0.990846
# 87     87        -200.0       0.0  200.0   100.500000         0.990913
# 88     88        -200.0       0.0  200.0   100.500000         0.990983
# 89     89        -200.0       0.0  200.0   100.500000         0.990727
# 90     90        -200.0       0.0  200.0   100.500000         0.991193
# 91     91        -200.0       0.0  200.0   100.500000         0.991595
# 92     92        -200.0       0.0  200.0   100.500000         0.991737
# 93     93        -200.0       0.0  200.0   100.500000         0.991823
# 94     94        -200.0       0.0  200.0   100.500000         0.991326
# 95     95        -200.0       0.0  200.0   100.500000         0.992252
# 96     96        -200.0       0.0  200.0   100.350820         0.991800
# 97     97        -200.0       0.0  200.0    97.143860         0.992105
# 98     98        -200.0       0.0  200.0   100.500000         0.992675
# 99     99        -200.0       0.0  200.0   100.500000         0.992783
#
#     StabilityActionError  StabilityGoalError  ForwardPredictionError  \
# 0               0.498944            0.266937                0.336544
# 1               0.489083            0.263781                0.259413
# 2               0.477760            0.257328                0.180932
# 3               0.460815            0.253281                0.145055
# 4               0.439850            0.257094                0.117061
# 5               0.412118            0.255750                0.093992
# 6               0.375840            0.255031                0.075492
# 7               0.337779            0.314484                0.062042
# 8               0.294404            0.249797                0.048188
# 9               0.249388            0.255203                0.033312
# 10              0.208789            0.259281                0.036213
# 11              0.177497            0.246391                0.029272
# 12              0.152715            0.254109                0.037756
# 13              0.130945            0.246453                0.039229
# 14              0.114681            0.244344                0.028658
# 15              0.099670            0.247359                0.033670
# 16              0.092205            0.242688                0.040859
# 17              0.077681            0.231578                0.023029
# 18              0.078374            0.231828                0.032619
# 19              0.068134            0.230078                0.024059
# 20              0.065521            0.215016                0.030911
# 21              0.067740            0.201531                0.024964
# 22              0.077308            0.184922                0.027525
# 23              0.079922            0.185562                0.037083
# 24              0.087915            0.170016                0.037583
# 25              0.092480            0.169125                0.032395
# 26              0.083830            0.155922                0.022979
# 27              0.089398            0.143672                0.023693
# 28              0.083558            0.141109                0.019726
# 29              0.087487            0.157719                0.014277
# ..                   ...                 ...                     ...
# 70              0.013127            0.000125                0.000721
# 71              0.012544            0.000125                0.000702
# 72              0.013115            0.000078                0.001120
# 73              0.012734            0.000000                0.001336
# 74              0.011506            0.000000                0.000404
# 75              0.011124            0.000000                0.000466
# 76              0.011192            0.000266                0.000262
# 77              0.010626            0.000063                0.000461
# 78              0.010675            0.000000                0.000666
# 79              0.011213            0.000125                0.000997
# 80              0.010403            0.000000                0.000580
# 81              0.010117            0.000000                0.000771
# 82              0.009437            0.000000                0.000361
# 83              0.010154            0.000094                0.000870
# 84              0.009371            0.000125                0.000393
# 85              0.009784            0.000000                0.000644
# 86              0.009092            0.000063                0.001002
# 87              0.009087            0.000000                0.000677
# 88              0.009017            0.000000                0.000659
# 89              0.009273            0.000000                0.000797
# 90              0.008807            0.000000                0.000382
# 91              0.008405            0.000000                0.000353
# 92              0.008263            0.000000                0.000641
# 93              0.008177            0.000000                0.000476
# 94              0.008674            0.000000                0.000633
# 95              0.007748            0.000000                0.000265
# 96              0.008200            0.000266                0.000400
# 97              0.007670            0.000234                0.000679
# 98              0.007325            0.000000                0.000300
# 99              0.007217            0.000000                0.000243
#
#     GoalsStepReward     ...       ActionsEntropy  ActionsAdvantageMean  \
# 0          0.543007     ...         1.084256e+00             -0.342276
# 1          0.536012     ...         1.091934e+00              0.486677
# 2          0.552222     ...         1.081583e+00              0.487954
# 3          0.560145     ...         1.040667e+00              0.509404
# 4          0.571845     ...         9.674242e-01              0.525703
# 5          0.580416     ...         8.526738e-01              0.543808
# 6          0.601072     ...         6.925396e-01              0.565221
# 7          0.601873     ...         5.712618e-01              0.553594
# 8          0.644751     ...         4.421587e-01              0.632231
# 9          0.663936     ...         2.854191e-01              0.631521
# 10         0.692164     ...         1.750415e-01              0.643049
# 11         0.718254     ...         1.483160e-01              0.676160
# 12         0.725619     ...         1.150771e-01              0.668030
# 13         0.745672     ...         7.682666e-02              0.691152
# 14         0.753568     ...         8.390155e-02              0.698586
# 15         0.766247     ...         5.901141e-02              0.692036
# 16         0.772325     ...         5.687672e-02              0.704050
# 17         0.790205     ...         3.106724e-02              0.728167
# 18         0.812001     ...         9.651928e-02              0.710987
# 19         0.817205     ...         5.603315e-02              0.724595
# 20         0.855975     ...         6.952340e-02              0.742763
# 21         0.924179     ...         1.133391e-01              0.748407
# 22         0.970906     ...         1.575725e-01              0.764463
# 23         1.000576     ...         1.760270e-01              0.740322
# 24         1.073485     ...         1.909753e-01              0.756854
# 25         1.127909     ...         1.967821e-01              0.747198
# 26         1.210964     ...         1.632155e-01              0.758338
# 27         1.402330     ...         1.502599e-01              0.746669
# 28         1.307624     ...         1.435529e-01              0.751940
# 29         1.135468     ...         1.650969e-01              0.747647
# ..              ...     ...                  ...                   ...
# 70        96.039450     ...         2.705930e-06             -0.022965
# 71        96.487800     ...         2.710400e-06             -0.009751
# 72        96.875330     ...         2.675711e-06             -0.032258
# 73       100.987210     ...         2.677261e-06             -0.029923
# 74       100.988470     ...         2.669453e-06             -0.003901
# 75       100.988846     ...         2.675414e-06             -0.019027
# 76        97.419136     ...         5.779838e-04             -0.009565
# 77        95.946495     ...         3.467261e-06             -0.001530
# 78       100.989300     ...         3.476798e-06             -0.036324
# 79        99.018974     ...         3.517148e-06             -0.018794
# 80       100.989570     ...         3.470599e-06             -0.015898
# 81       100.989845     ...         3.466605e-06             -0.018903
# 82       100.990550     ...         3.466366e-06             -0.014217
# 83        96.559870     ...         3.663859e-06             -0.009518
# 84        98.284515     ...         3.470239e-06             -0.007896
# 85       100.990180     ...         3.414511e-06             -0.023941
# 86        99.100266     ...         3.414034e-06             -0.001063
# 87       100.990880     ...         3.413498e-06             -0.022783
# 88       100.990950     ...         3.415464e-06             -0.017524
# 89       100.990700     ...         3.417431e-06             -0.020257
# 90       100.991150     ...         3.413557e-06             -0.014998
# 91       100.991580     ...         3.410815e-06             -0.017338
# 92       100.991714     ...         3.413438e-06             -0.016554
# 93       100.991800     ...         3.413736e-06             -0.016760
# 94       100.991295     ...         3.416239e-06             -0.017797
# 95       100.992230     ...         3.410696e-06             -0.015104
# 96       100.892030     ...         4.328303e-04             -0.022009
# 97        97.708500     ...         1.220796e-04             -0.004009
# 98       100.992650     ...         7.159113e-07             -0.016790
# 99       100.992760     ...         7.160305e-07             -0.014052
#
#        ActionsKL  ActionsStopIter  LossActionInverse  LossGoalInverse  Unit  \
# 0   9.164023e-03             79.0           0.239042         0.250316     0
# 1   1.075478e-02             79.0           0.232809         0.250174     0
# 2   1.609010e-02             19.0           0.224137         0.249643     0
# 3   1.810724e-02             16.0           0.208954         0.249415     0
# 4   1.829275e-02             11.0           0.191043         0.249564     0
# 5   2.003786e-02             11.0           0.167530         0.249841     0
# 6   1.862355e-02             13.0           0.138269         0.249579     0
# 7   1.711370e-02             14.0           0.112647         0.249686     0
# 8   1.655515e-02             17.0           0.086513         0.248388     0
# 9   1.346375e-02             79.0           0.061511         0.247715     0
# 10  3.473981e-03             79.0           0.041053         0.247802     0
# 11  2.151617e-03             79.0           0.032385         0.246528     0
# 12  1.816530e-03             79.0           0.025689         0.245440     0
# 13  8.391673e-04             79.0           0.018947         0.244791     0
# 14  2.027931e-03             79.0           0.018046         0.242770     0
# 15  8.553470e-04             79.0           0.012446         0.243546     0
# 16  4.583077e-04             79.0           0.012743         0.242661     0
# 17  4.849262e-03             79.0           0.007960         0.240420     0
# 18  3.211329e-03             79.0           0.014003         0.236879     0
# 19  2.301125e-03             79.0           0.009910         0.232929     0
# 20  1.656974e-02             40.0           0.010137         0.234028     0
# 21  1.722581e-02             18.0           0.017505         0.224729     0
# 22  8.085058e-03             79.0           0.030869         0.215930     0
# 23  1.571767e-02             44.0           0.034031         0.214308     0
# 24  8.571563e-03             79.0           0.044332         0.202528     0
# 25  8.075649e-03             79.0           0.051212         0.201377     0
# 26  8.874094e-03             79.0           0.043845         0.190748     0
# 27  5.678460e-03             79.0           0.049093         0.178321     0
# 28  8.783668e-03             79.0           0.043307         0.179033     0
# 29  9.473352e-03             79.0           0.048332         0.195109     0
# ..           ...              ...                ...              ...   ...
# 70 -1.549713e-09             79.0           0.000205         0.000412     0
# 71 -2.205366e-09             79.0           0.000185         0.000385     0
# 72 -4.172316e-10             79.0           0.000217         0.000503     0
# 73  0.000000e+00             79.0           0.000207         0.000191     0
# 74 -2.384178e-10             79.0           0.000155         0.000135     0
# 75 -5.960442e-11             79.0           0.000145         0.000121     0
# 76 -1.502166e-04             79.0           0.000385         0.000407     0
# 77  9.536709e-10             79.0           0.000134         0.000296     0
# 78  1.788134e-10             79.0           0.000140         0.000106     0
# 79 -5.781620e-09             79.0           0.000164         0.000317     0
# 80 -8.344619e-10             79.0           0.000134         0.000095     0
# 81  1.192088e-10             79.0           0.000127         0.000088     0
# 82  2.384177e-10             79.0           0.000105         0.000070     0
# 83 -4.464298e-08             79.0           0.000135         0.000288     0
# 84 -1.734487e-08             79.0           0.000108         0.000266     0
# 85 -1.728529e-09             79.0           0.000124         0.000078     0
# 86  7.152532e-10             79.0           0.000106         0.000261     0
# 87  2.980222e-10             79.0           0.000105         0.000063     0
# 88  1.788135e-10             79.0           0.000104         0.000062     0
# 89  1.192089e-10             79.0           0.000115         0.000068     0
# 90  4.172315e-10             79.0           0.000099         0.000056     0
# 91  2.384179e-10             79.0           0.000089         0.000049     0
# 92  5.364398e-10             79.0           0.000086         0.000047     0
# 93  7.152534e-10             79.0           0.000085         0.000046     0
# 94  1.013276e-09             79.0           0.000102         0.000055     0
# 95  4.172310e-10             79.0           0.000074         0.000039     0
# 96 -1.164026e-04             79.0           0.000325         0.000337     0
# 97 -1.117937e-04             79.0           0.000077         0.000234     0
# 98 -3.576277e-10             79.0           0.000066         0.000033     0
# 99  0.000000e+00             79.0           0.000064         0.000031     0
#
#                              Condition1  \
# 0   forward_error_reward_mountaincar-v0
# 1   forward_error_reward_mountaincar-v0
# 2   forward_error_reward_mountaincar-v0
# 3   forward_error_reward_mountaincar-v0
# 4   forward_error_reward_mountaincar-v0
# 5   forward_error_reward_mountaincar-v0
# 6   forward_error_reward_mountaincar-v0
# 7   forward_error_reward_mountaincar-v0
# 8   forward_error_reward_mountaincar-v0
# 9   forward_error_reward_mountaincar-v0
# 10  forward_error_reward_mountaincar-v0
# 11  forward_error_reward_mountaincar-v0
# 12  forward_error_reward_mountaincar-v0
# 13  forward_error_reward_mountaincar-v0
# 14  forward_error_reward_mountaincar-v0
# 15  forward_error_reward_mountaincar-v0
# 16  forward_error_reward_mountaincar-v0
# 17  forward_error_reward_mountaincar-v0
# 18  forward_error_reward_mountaincar-v0
# 19  forward_error_reward_mountaincar-v0
# 20  forward_error_reward_mountaincar-v0
# 21  forward_error_reward_mountaincar-v0
# 22  forward_error_reward_mountaincar-v0
# 23  forward_error_reward_mountaincar-v0
# 24  forward_error_reward_mountaincar-v0
# 25  forward_error_reward_mountaincar-v0
# 26  forward_error_reward_mountaincar-v0
# 27  forward_error_reward_mountaincar-v0
# 28  forward_error_reward_mountaincar-v0
# 29  forward_error_reward_mountaincar-v0
# ..                                  ...
# 70  forward_error_reward_mountaincar-v0
# 71  forward_error_reward_mountaincar-v0
# 72  forward_error_reward_mountaincar-v0
# 73  forward_error_reward_mountaincar-v0
# 74  forward_error_reward_mountaincar-v0
# 75  forward_error_reward_mountaincar-v0
# 76  forward_error_reward_mountaincar-v0
# 77  forward_error_reward_mountaincar-v0
# 78  forward_error_reward_mountaincar-v0
# 79  forward_error_reward_mountaincar-v0
# 80  forward_error_reward_mountaincar-v0
# 81  forward_error_reward_mountaincar-v0
# 82  forward_error_reward_mountaincar-v0
# 83  forward_error_reward_mountaincar-v0
# 84  forward_error_reward_mountaincar-v0
# 85  forward_error_reward_mountaincar-v0
# 86  forward_error_reward_mountaincar-v0
# 87  forward_error_reward_mountaincar-v0
# 88  forward_error_reward_mountaincar-v0
# 89  forward_error_reward_mountaincar-v0
# 90  forward_error_reward_mountaincar-v0
# 91  forward_error_reward_mountaincar-v0
# 92  forward_error_reward_mountaincar-v0
# 93  forward_error_reward_mountaincar-v0
# 94  forward_error_reward_mountaincar-v0
# 95  forward_error_reward_mountaincar-v0
# 96  forward_error_reward_mountaincar-v0
# 97  forward_error_reward_mountaincar-v0
# 98  forward_error_reward_mountaincar-v0
# 99  forward_error_reward_mountaincar-v0
#
#                                Condition2  Performance
# 0   forward_error_reward_mountaincar-v0-0       -200.0
# 1   forward_error_reward_mountaincar-v0-0       -200.0
# 2   forward_error_reward_mountaincar-v0-0       -200.0
# 3   forward_error_reward_mountaincar-v0-0       -200.0
# 4   forward_error_reward_mountaincar-v0-0       -200.0
# 5   forward_error_reward_mountaincar-v0-0       -200.0
# 6   forward_error_reward_mountaincar-v0-0       -200.0
# 7   forward_error_reward_mountaincar-v0-0       -200.0
# 8   forward_error_reward_mountaincar-v0-0       -200.0
# 9   forward_error_reward_mountaincar-v0-0       -200.0
# 10  forward_error_reward_mountaincar-v0-0       -200.0
# 11  forward_error_reward_mountaincar-v0-0       -200.0
# 12  forward_error_reward_mountaincar-v0-0       -200.0
# 13  forward_error_reward_mountaincar-v0-0       -200.0
# 14  forward_error_reward_mountaincar-v0-0       -200.0
# 15  forward_error_reward_mountaincar-v0-0       -200.0
# 16  forward_error_reward_mountaincar-v0-0       -200.0
# 17  forward_error_reward_mountaincar-v0-0       -200.0
# 18  forward_error_reward_mountaincar-v0-0       -200.0
# 19  forward_error_reward_mountaincar-v0-0       -200.0
# 20  forward_error_reward_mountaincar-v0-0       -200.0
# 21  forward_error_reward_mountaincar-v0-0       -200.0
# 22  forward_error_reward_mountaincar-v0-0       -200.0
# 23  forward_error_reward_mountaincar-v0-0       -200.0
# 24  forward_error_reward_mountaincar-v0-0       -200.0
# 25  forward_error_reward_mountaincar-v0-0       -200.0
# 26  forward_error_reward_mountaincar-v0-0       -200.0
# 27  forward_error_reward_mountaincar-v0-0       -200.0
# 28  forward_error_reward_mountaincar-v0-0       -200.0
# 29  forward_error_reward_mountaincar-v0-0       -200.0
# ..                                    ...          ...
# 70  forward_error_reward_mountaincar-v0-0       -200.0
# 71  forward_error_reward_mountaincar-v0-0       -200.0
# 72  forward_error_reward_mountaincar-v0-0       -200.0
# 73  forward_error_reward_mountaincar-v0-0       -200.0
# 74  forward_error_reward_mountaincar-v0-0       -200.0
# 75  forward_error_reward_mountaincar-v0-0       -200.0
# 76  forward_error_reward_mountaincar-v0-0       -200.0
# 77  forward_error_reward_mountaincar-v0-0       -200.0
# 78  forward_error_reward_mountaincar-v0-0       -200.0
# 79  forward_error_reward_mountaincar-v0-0       -200.0
# 80  forward_error_reward_mountaincar-v0-0       -200.0
# 81  forward_error_reward_mountaincar-v0-0       -200.0
# 82  forward_error_reward_mountaincar-v0-0       -200.0
# 83  forward_error_reward_mountaincar-v0-0       -200.0
# 84  forward_error_reward_mountaincar-v0-0       -200.0
# 85  forward_error_reward_mountaincar-v0-0       -200.0
# 86  forward_error_reward_mountaincar-v0-0       -200.0
# 87  forward_error_reward_mountaincar-v0-0       -200.0
# 88  forward_error_reward_mountaincar-v0-0       -200.0
# 89  forward_error_reward_mountaincar-v0-0       -200.0
# 90  forward_error_reward_mountaincar-v0-0       -200.0
# 91  forward_error_reward_mountaincar-v0-0       -200.0
# 92  forward_error_reward_mountaincar-v0-0       -200.0
# 93  forward_error_reward_mountaincar-v0-0       -200.0
# 94  forward_error_reward_mountaincar-v0-0       -200.0
# 95  forward_error_reward_mountaincar-v0-0       -200.0
# 96  forward_error_reward_mountaincar-v0-0       -200.0
# 97  forward_error_reward_mountaincar-v0-0       -200.0
# 98  forward_error_reward_mountaincar-v0-0       -200.0
# 99  forward_error_reward_mountaincar-v0-0       -200.0
#
# [100 rows x 28 columns]

# %%
# Show table of parameters used in the experiment, used as guide to graph legends

def config_values(config, paths):
    values = []
    for path in paths:
        value = config
        for name in path.split(':'):
            value = value[name]
        values.append(value)
    return values

columns = ['exp_name', 
           'steps_per_epoch',
#           'use_reward_discount',
#           'goal_octaves', 
#            'goal_discount_rate', 
#           'no_step_reward', 
#           'finish_action_path_on_new_goal', 
#            'ac_kwargs:hidden_sizes', 
#            'ac_kwargs:activation', 
#            'inverse_kwargs:hidden_sizes', 
#            'inverse_kwargs:activation', 
#            'inverse_kwargs:goals_output_activation'
          ]

data = list(map(lambda config: config_values(config, columns), configs))
df = pd.DataFrame(data=data, columns=columns)
df.drop_duplicates()
# Out:
#                               exp_name  steps_per_epoch
# 0  forward_error_reward_mountaincar-v0             2000

# %%
plt.figure(figsize=(20, 15), dpi=150)

# To show individual runs, add arguments: units='Condition2, estimator=None
# To compare runs with different epoch lengts, use:xaxis='TotalEnvInteracts'

plot_data(datasets, smooth=5, units='Condition2', estimator=None)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityGoalError', smooth=1, show_legend=False, estimator='mean')
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityActionError', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalPathLen', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalsEntropy', smooth=1, show_legend=False)
plt.show()

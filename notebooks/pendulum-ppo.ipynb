# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import os.path as osp
import numpy as np
from spinup.utils.plot import get_datasets, get_all_datasets, plot_data
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
datasets, configs = get_all_datasets(['/Users/ppiech/openaigym/spindata/ppo/'])

# Show a sample of the data
pd.concat(datasets, ignore_index=True)
# Out:
# Plotting from...
# ==================================================
#
# /Users/ppiech/openaigym/spindata/ppo/
#
# ==================================================
#        Epoch  AverageEpRet    StdEpRet    MaxEpRet   MinEpRet  EpLen  \
# 0          0    -1508.9056   70.718400 -1337.37280 -1641.6399  200.0
# 1          1    -1544.7690   50.079254 -1469.77360 -1636.9300  200.0
# 2          2    -1535.7059   59.219640 -1441.37100 -1635.4851  200.0
# 3          3    -1508.2319   55.866127 -1392.73180 -1623.6885  200.0
# 4          4    -1524.4869   65.224920 -1418.34200 -1639.6946  200.0
# 5          5    -1525.3336   60.786392 -1409.95410 -1641.3657  200.0
# 6          6    -1558.1836   56.486225 -1450.71100 -1645.2734  200.0
# 7          7    -1474.9462   98.811230 -1213.04640 -1598.0999  200.0
# 8          8    -1548.9200   74.720150 -1366.44170 -1637.4044  200.0
# 9          9    -1538.0045   45.790142 -1470.54820 -1646.2200  200.0
# 10        10    -1543.1221   70.128395 -1404.82130 -1645.7268  200.0
# 11        11    -1517.0382   74.149635 -1413.34970 -1644.5785  200.0
# 12        12    -1552.2075   59.770580 -1472.91350 -1647.5063  200.0
# 13        13    -1553.4291   73.745960 -1403.60380 -1645.6540  200.0
# 14        14    -1504.5912   55.260868 -1377.04210 -1588.4276  200.0
# 15        15    -1501.9427   77.531530 -1406.73580 -1643.4336  200.0
# 16        16    -1539.8695   86.698360 -1302.72510 -1648.0209  200.0
# 17        17    -1564.3467   64.501030 -1441.42130 -1646.7633  200.0
# 18        18    -1559.1215   48.309690 -1506.80360 -1640.1357  200.0
# 19        19    -1537.7201   56.498783 -1435.75950 -1631.6091  200.0
# 20        20    -1511.0883  139.643400 -1080.97950 -1645.8195  200.0
# 21        21    -1572.0646   45.245964 -1492.38620 -1640.0590  200.0
# 22        22    -1533.4424   57.025196 -1449.35800 -1638.5151  200.0
# 23        23    -1541.0446   58.507336 -1447.33450 -1646.9847  200.0
# 24        24    -1462.9183  206.801530  -877.92694 -1646.9545  200.0
# 25        25    -1525.9857   56.381977 -1440.50100 -1646.9385  200.0
# 26        26    -1513.2467  146.400740 -1053.03530 -1645.8735  200.0
# 27        27    -1516.1727   84.510210 -1369.90760 -1631.7114  200.0
# 28        28    -1543.1576   67.184670 -1417.47750 -1647.9849  200.0
# 29        29    -1564.4746   65.626070 -1470.33020 -1650.7502  200.0
# ...      ...           ...         ...         ...        ...    ...
# 15797    770    -1187.8528   45.821815 -1157.58030 -1287.6794  200.0
# 15798    771    -1255.9707   48.797184 -1165.36790 -1313.8497  200.0
# 15799    772    -1223.3663   51.439140 -1153.28700 -1303.3672  200.0
# 15800    773    -1228.3231  102.188910 -1066.52100 -1398.7684  200.0
# 15801    774    -1222.7888   69.425220 -1084.73390 -1279.8147  200.0
# 15802    775    -1241.6090   51.658890 -1165.27440 -1295.3676  200.0
# 15803    776    -1235.6298   38.212170 -1176.69130 -1276.8484  200.0
# 15804    777    -1258.4877   62.254997 -1168.52200 -1317.0731  200.0
# 15805    778    -1258.7681   30.806484 -1194.44140 -1289.0356  200.0
# 15806    779    -1163.9183   69.790480 -1058.87370 -1256.7435  200.0
# 15807    780    -1235.4794   55.383660 -1181.36240 -1320.6865  200.0
# 15808    781    -1261.3539   71.878040 -1157.65040 -1367.6199  200.0
# 15809    782    -1262.0640   40.156810 -1177.89330 -1297.4932  200.0
# 15810    783    -1267.4369   63.118416 -1201.83450 -1377.0328  200.0
# 15811    784    -1265.4626   32.643715 -1214.73540 -1320.4343  200.0
# 15812    785    -1252.6777   56.802376 -1184.24850 -1316.4023  200.0
# 15813    786    -1230.2782   73.482570 -1097.80140 -1328.8131  200.0
# 15814    787    -1202.8407   49.937650 -1146.28330 -1307.5420  200.0
# 15815    788    -1265.4833   42.839935 -1194.83560 -1318.2897  200.0
# 15816    789    -1234.6205   56.254253 -1161.95580 -1307.4375  200.0
# 15817    790    -1254.3168   50.530678 -1195.28880 -1318.2365  200.0
# 15818    791    -1224.2426   48.042862 -1172.24930 -1323.8517  200.0
# 15819    792    -1246.8131   58.918830 -1182.85530 -1340.7914  200.0
# 15820    793    -1250.4833   79.914340 -1145.15310 -1385.1396  200.0
# 15821    794    -1242.8789   51.791600 -1156.16920 -1311.9780  200.0
# 15822    795    -1244.7831   29.732029 -1207.36510 -1283.7850  200.0
# 15823    796    -1263.0615   60.103565 -1178.46420 -1356.5627  200.0
# 15824    797    -1286.7528   27.518345 -1249.84130 -1320.1765  200.0
# 15825    798    -1259.8026   42.304134 -1175.63710 -1314.3342  200.0
# 15826    799    -1275.0288   23.234188 -1236.54970 -1308.8687  200.0
#
#        AverageVVals    StdVVals    MaxVVals    MinVVals     ...       \
# 0         -1.837698    0.643064   -0.047698   -3.321919     ...
# 1        -24.633701    7.195400   -3.306061  -30.810171     ...
# 2       -102.215675   40.489742  -17.597984 -140.268550     ...
# 3       -253.211870   81.478610  -38.260230 -334.092960     ...
# 4       -370.105000  113.265990  -47.938408 -587.701200     ...
# 5       -410.682430  104.424040  -72.500050 -796.198300     ...
# 6       -416.800900   93.952760  -87.242170 -833.380430     ...
# 7       -417.609280  127.924400 -105.078514 -980.152900     ...
# 8       -407.712250   85.763960 -118.150920 -884.084960     ...
# 9       -434.200400  101.777750 -148.583980 -983.644400     ...
# 10      -426.128500   86.881790 -159.352870 -985.023100     ...
# 11      -434.210570   93.033600 -171.861150 -961.040600     ...
# 12      -432.049100   76.230354 -215.315600 -887.712900     ...
# 13      -443.103550   70.652374 -225.732710 -887.282170     ...
# 14      -448.822360   91.920790 -245.339360 -936.611400     ...
# 15      -427.162500   72.992770 -250.915070 -828.181000     ...
# 16      -427.981660   61.489580 -270.898500 -776.399700     ...
# 17      -452.196560   53.314835 -325.941800 -749.833560     ...
# 18      -451.130100   58.771355 -334.309140 -801.423200     ...
# 19      -463.894600   63.222656 -364.797820 -822.193300     ...
# 20      -453.586460   59.605217 -380.406000 -804.790100     ...
# 21      -455.947660   41.469060 -397.858550 -682.861150     ...
# 22      -470.832300   53.370213 -419.869400 -769.989300     ...
# 23      -456.268950   65.952690 -403.329000 -797.094900     ...
# 24      -485.065830   74.525246 -422.200900 -768.898700     ...
# 25      -432.748320   29.413599 -382.711460 -508.477400     ...
# 26      -464.956940   55.817753 -416.154360 -696.687100     ...
# 27      -443.609470   30.757700 -400.522950 -570.794700     ...
# 28      -460.090820   55.312252 -416.983280 -684.029300     ...
# 29      -460.645720   59.605450 -412.636630 -697.245000     ...
# ...             ...         ...         ...         ...     ...
# 15797   -334.374800   82.507645 -178.859310 -528.577700     ...
# 15798   -355.836330   74.701460 -234.769240 -559.729250     ...
# 15799   -310.302500   95.959790 -154.007920 -529.309300     ...
# 15800   -388.632450   94.152596 -248.227260 -600.921500     ...
# 15801   -356.420960   80.008310 -254.471600 -539.628000     ...
# 15802   -344.519560   91.791970 -235.290100 -582.037500     ...
# 15803   -366.470920   78.716194 -203.326320 -545.283600     ...
# 15804   -339.464900   66.174034 -235.657300 -537.121030     ...
# 15805   -415.588870   85.163360 -287.857540 -615.196700     ...
# 15806   -298.915830  103.196780 -146.910350 -504.405800     ...
# 15807   -347.883500   79.479080 -252.554800 -568.823500     ...
# 15808   -391.076320   86.826810 -228.967640 -577.795170     ...
# 15809   -330.949500   71.690030 -232.717480 -522.542900     ...
# 15810   -390.075680   85.674194 -292.877380 -610.960630     ...
# 15811   -370.648600   48.372852 -266.997470 -512.774800     ...
# 15812   -383.541300   91.403550 -273.712830 -592.956360     ...
# 15813   -352.219300  100.843670 -213.541690 -562.105040     ...
# 15814   -338.949600   57.471813 -243.097380 -500.055420     ...
# 15815   -357.332600   62.008904 -243.785600 -526.137800     ...
# 15816   -402.942870   91.663190 -259.081150 -607.596100     ...
# 15817   -320.556000   74.437430 -198.488720 -492.822940     ...
# 15818   -383.876920   81.673540 -259.238560 -576.810300     ...
# 15819   -388.761300   92.675560 -230.700240 -566.056900     ...
# 15820   -347.092500   83.454360 -199.720430 -532.459500     ...
# 15821   -373.332730   69.378490 -227.436860 -536.779900     ...
# 15822   -322.713800   74.906790 -209.364350 -511.790600     ...
# 15823   -401.345830   95.583725 -299.968080 -616.955700     ...
# 15824   -354.639500   85.357060 -263.878230 -558.198200     ...
# 15825   -354.748660   69.864820 -267.018500 -542.117250     ...
# 15826   -386.785950   81.752680 -259.175100 -594.171100     ...
#
#          DeltaLossV   Entropy        KL  ClipFrac  StopIter        Time  Unit  \
# 0     -18555.453000  0.917220  0.001042  0.035833      79.0    0.911681     0
# 1     -64658.547000  0.907069  0.005734  0.037917      79.0    1.232403     0
# 2     -65343.082000  0.858100  0.009147  0.048333      79.0    1.552543     0
# 3     -22863.125000  0.888592  0.011955  0.046250      79.0    1.867768     0
# 4      -5183.034700  0.865176  0.009934  0.055417      79.0    4.631739     0
# 5      -2572.761000  0.889370  0.002763  0.012917      79.0    6.855370     0
# 6      -1427.731100  0.931600  0.009713  0.064167      79.0    7.780007     0
# 7      -3072.980500  0.886593  0.007121  0.059167      79.0   10.153877     0
# 8      -2083.977300  0.842158  0.002971  0.029583      79.0   12.101025     0
# 9      -1974.701800  0.835128  0.005294  0.061667      79.0   12.417099     0
# 10     -1579.029300  0.861524  0.009768  0.040417      79.0   12.889153     0
# 11     -2624.486300  0.848704  0.008575  0.073750      79.0   15.234224     0
# 12     -2906.082800  0.810548  0.007585  0.065000      79.0   15.550244     0
# 13     -2044.941400  0.804347  0.009009  0.045000      79.0   15.865945     0
# 14     -4153.439000  0.794556  0.008791  0.052917      79.0   16.185266     0
# 15     -3411.139600  0.792660  0.009768  0.056667      79.0   16.505548     0
# 16     -1638.894500  0.762947  0.005083  0.046667      79.0   16.821879     0
# 17      -820.710630  0.779996  0.004283  0.045000      79.0   17.137558     0
# 18      -813.216100  0.752311  0.003664  0.024167      79.0   17.455944     0
# 19      -792.479500  0.752127  0.007310  0.052917      79.0   17.774176     0
# 20      -719.719400  0.729438  0.001501  0.045000      79.0   20.830467     0
# 21      -741.901060  0.720079  0.003015  0.021667      79.0   23.202854     0
# 22      -633.365230  0.755876  0.007058  0.048750      79.0   25.096481     0
# 23      -483.630520  0.711998  0.003703  0.054583      79.0   25.412249     0
# 24     -7675.570300  0.699038  0.001864  0.055000      79.0   25.728086     0
# 25     -3749.734400  0.665365  0.006430  0.047917      79.0   26.045556     0
# 26     -2025.585300  0.676606  0.003130  0.036250      79.0   26.361886     0
# 27     -1812.835600  0.638112  0.008105  0.062917      79.0   26.677215     0
# 28      -204.057620  0.635723  0.001749  0.037083      79.0   26.994451     0
# 29       -79.967125  0.626302  0.003946  0.031250      79.0   27.311292     0
# ...             ...       ...       ...       ...       ...         ...   ...
# 15797  -2762.557000 -2.302828  0.031426  0.274167       1.0  252.005902     6
# 15798  -1000.573700 -2.305104  0.077434  0.177500       2.0  252.154849     6
# 15799  -4904.182000 -2.274972  0.010894  0.094167       1.0  252.302589     6
# 15800  -1720.049300 -2.302361  0.007999  0.071667       2.0  252.453845     6
# 15801   -335.685880 -2.280394  0.009058  0.185833      25.0  252.628734     6
# 15802  -3979.187500 -2.339966  0.012673  0.158333       1.0  252.779014     6
# 15803  -1877.215700 -2.293559  0.014292  0.138333       2.0  252.927814     6
# 15804  -1619.136600 -2.302396  0.001659  0.050000       4.0  253.078529     6
# 15805  -3045.807400 -2.317177  0.017631  0.235000       1.0  253.228365     6
# 15806  -5713.427200 -2.317608  0.014574  0.133333       1.0  253.376113     6
# 15807  -1679.776400 -2.339828  0.026926  0.240000       3.0  254.278322     6
# 15808  -2015.974500 -2.296374  0.016788  0.240833       6.0  254.431472     6
# 15809  -1947.692300 -2.310985  0.019655  0.105000       2.0  254.580512     6
# 15810  -2266.500700 -2.308925  0.008194  0.190833       1.0  254.729941     6
# 15811  -2565.116500 -2.335986  0.039475  0.265000       1.0  254.878331     6
# 15812  -2535.370000 -2.311713  0.007628  0.097500       1.0  255.026428     6
# 15813  -2018.947900 -2.303967  0.009751  0.103333       6.0  255.179875     6
# 15814   -886.573060 -2.309473  0.029956  0.197500       1.0  255.329671     6
# 15815   -735.619600 -2.299810  0.115376  0.291667       1.0  255.478650     6
# 15816  -2405.869100 -2.352071  0.010966  0.108333       4.0  255.629771     6
# 15817  -2680.415800 -2.307559  0.004518  0.082500       1.0  256.534871     6
# 15818   -723.067930 -2.298187  0.012869  0.127500       1.0  256.684293     6
# 15819  -1423.566300 -2.285757  0.010090  0.152500       1.0  256.832631     6
# 15820   -394.979100 -2.313784  0.018247  0.177500       2.0  256.981731     6
# 15821   -790.663500 -2.350995  0.017613  0.153333       3.0  257.131959     6
# 15822  -4148.756300 -2.307529  0.007802  0.069167       1.0  257.283244     6
# 15823  -1453.445300 -2.334434  0.002963  0.075000       1.0  257.431233     6
# 15824   -581.915040 -2.327714  0.019219  0.265833       1.0  257.581396     6
# 15825  -1898.071200 -2.335537  0.051230  0.410833       1.0  257.731264     6
# 15826   -260.438140 -2.333998  0.014291  0.135833       1.0  258.647438     6
#
#                           Condition1                        Condition2  \
# 0      ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 1      ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 2      ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 3      ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 4      ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 5      ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 6      ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 7      ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 8      ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 9      ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 10     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 11     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 12     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 13     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 14     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 15     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 16     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 17     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 18     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 19     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 20     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 21     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 22     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 23     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 24     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 25     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 26     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 27     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 28     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# 29     ppo-bench_pendulum-v0_ste2400   ppo-bench_pendulum-v0_ste2400-0
# ...                              ...                               ...
# 15797  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15798  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15799  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15800  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15801  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15802  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15803  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15804  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15805  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15806  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15807  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15808  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15809  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15810  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15811  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15812  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15813  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15814  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15815  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15816  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15817  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15818  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15819  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15820  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15821  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15822  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15823  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15824  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15825  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
# 15826  ppo-bench_pendulum-v0_ste1200  ppo-bench_pendulum-v0_ste1200-19
#
#        Performance
# 0       -1508.9056
# 1       -1544.7690
# 2       -1535.7059
# 3       -1508.2319
# 4       -1524.4869
# 5       -1525.3336
# 6       -1558.1836
# 7       -1474.9462
# 8       -1548.9200
# 9       -1538.0045
# 10      -1543.1221
# 11      -1517.0382
# 12      -1552.2075
# 13      -1553.4291
# 14      -1504.5912
# 15      -1501.9427
# 16      -1539.8695
# 17      -1564.3467
# 18      -1559.1215
# 19      -1537.7201
# 20      -1511.0883
# 21      -1572.0646
# 22      -1533.4424
# 23      -1541.0446
# 24      -1462.9183
# 25      -1525.9857
# 26      -1513.2467
# 27      -1516.1727
# 28      -1543.1576
# 29      -1564.4746
# ...            ...
# 15797   -1187.8528
# 15798   -1255.9707
# 15799   -1223.3663
# 15800   -1228.3231
# 15801   -1222.7888
# 15802   -1241.6090
# 15803   -1235.6298
# 15804   -1258.4877
# 15805   -1258.7681
# 15806   -1163.9183
# 15807   -1235.4794
# 15808   -1261.3539
# 15809   -1262.0640
# 15810   -1267.4369
# 15811   -1265.4626
# 15812   -1252.6777
# 15813   -1230.2782
# 15814   -1202.8407
# 15815   -1265.4833
# 15816   -1234.6205
# 15817   -1254.3168
# 15818   -1224.2426
# 15819   -1246.8131
# 15820   -1250.4833
# 15821   -1242.8789
# 15822   -1244.7831
# 15823   -1263.0615
# 15824   -1286.7528
# 15825   -1259.8026
# 15826   -1275.0288
#
# [15827 rows x 24 columns]

# %%
# Show table of parameters used in the experiment, used as guide to graph legends

def config_values(config, paths):
    values = []
    for path in paths:
        value = config
        for name in path.split(':'):
            value = value[name]
        values.append(value)
    return values

columns = ['exp_name', 
           'steps_per_epoch',
#           'use_reward_discount',
#           'goal_octaves', 
#            'goal_discount_rate', 
#           'no_step_reward', 
#           'finish_action_path_on_new_goal', 
#            'ac_kwargs:hidden_sizes', 
#            'ac_kwargs:activation', 
#            'inverse_kwargs:hidden_sizes', 
#            'inverse_kwargs:activation', 
#            'inverse_kwargs:goals_output_activation'
          ]

data = list(map(lambda config: config_values(config, columns), configs))
df = pd.DataFrame(data=data, columns=columns)
df.drop_duplicates()
# Out:
#                          exp_name  steps_per_epoch
# 0   ppo-bench_pendulum-v0_ste2400             2400
# 7   ppo-bench_pendulum-v0_ste4800             4800
# 13  ppo-bench_pendulum-v0_ste1200             1200

# %%
plt.figure(figsize=(20, 15), dpi=150)

# To show individual runs, add arguments: units='Condition2, estimator=None
# To compare runs with different epoch lengts, use:xaxis='TotalEnvInteracts'

plot_data(datasets, smooth=5, xaxis='TotalEnvInteracts')
plt.show()
# Out:
# /Users/ppiech/openaigym/spinningup/env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityGoalError', smooth=1, show_legend=False, estimator='mean')
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='StabilityActionError', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalDiscount', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='ActionsEntropy', smooth=1, show_legend=False)
plt.show()

# %%
plt.figure(figsize=(14, 8), dpi=150)
plot_data(datasets, value='GoalsEntropy', smooth=1, show_legend=False)
plt.show()
